# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
from psl.coupled_systems import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'widget')
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2369, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2367     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2368 with self.builtin_trap:
# -> 2369     result = fn(*args, **kwargs)
#    2370 return result
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/IPython/core/magics/pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100     self._show_matplotlib_backend(args.gui, backend)
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3537, in InteractiveShell.enable_matplotlib(self, gui)
#    3533         print('Warning: Cannot change to a different GUI toolkit: %s.'
#    3534                 ' Using %s instead.' % (gui, self.pylab_gui_select))
#    3535         gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
# -> 3537 pt.activate_matplotlib(backend)
#    3538 configure_inline_support(self, backend)
#    3540 # Now we must activate the gui pylab wants to use, and fix %run to take
#    3541 # plot updates into account
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/IPython/core/pylabtools.py:360, in activate_matplotlib(backend)
#     355 # Due to circular imports, pyplot may be only partially initialised
#     356 # when this function runs.
#     357 # So avoid needing matplotlib attribute-lookup to access pyplot.
#     358 from matplotlib import pyplot as plt
# --> 360 plt.switch_backend(backend)
#     362 plt.show._needmain = False
#     363 # We need to detect at runtime whether show() is called by the user.
#     364 # For this, we wrap it into a decorator which adds a 'called' flag.
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/pyplot.py:265, in switch_backend(newbackend)
#     262         rcParamsOrig["backend"] = "agg"
#     263         return
# --> 265 backend_mod = importlib.import_module(
#     266     cbook._backend_module_name(newbackend))
#     268 required_framework = _get_required_interactive_framework(backend_mod)
#     269 if required_framework is not None:
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:992, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'ipympl'

# %% [markdown]
# # Thermal RC Network

# %%
#RC Network
adj = np.array([[0,1],[0,2],[0,3],[1,0],[1,3],[1,4],[2,0],[2,3],[3,0],[3,1],[3,2],[3,4],[4,1],[4,3]]).T
network = RC_Network(nsim=10000, nx=5, adj=adj)
sim = network.simulate(show_progress=True)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(1,2)
fig.text(0.5, 0.03, 'Time')
ax=ax.flatten()
ax[0].plot(network.U[:,0])
ax[0].set_title('Outdoor Temperature')
ax[0].set_ylabel('Kelvin')
ax[1].plot(network.U[:,1])
ax[1].set_title('An Internal Heat Source');

# %%
fig = plt.figure()
fig.text(0.35, 0.9, 'Room Temperatures Over Time')
locs = [(0,0),(0,2),(1,0),(1,1),(1,3)]
spans = [2,2,1,2,1]
ax = [plt.subplot2grid((2,4), l, colspan=s) for l,s in zip(locs, spans)]
[ax[i].plot(sim['X'][:,i]) for i in range(len(locs))];
miny = np.floor(np.min(sim['X']))
maxy = np.ceil(np.max(sim['X']))
[a.set_ylim(miny, maxy) for a in ax]
[a.tick_params(labelbottom=False) for a in ax]
[ax[i].tick_params(labelleft=False) for i in [1,3,4]]
fig.subplots_adjust(hspace=0.1,wspace=0.1)
plt.show()

# %% [markdown]
# # Gravitational System

# %%
#adj = np.array([[0,1],[0,2],[0,3],[1,0],[2,0],[3,0]]).T #
nsim = 10000
network = Gravitational_System(G=6.67e-11, nx=4)
ninit = np.array([[1000000, 0, 0, 0, 0],
         [1, 1, 0, 0, 8.167e-3],
         [1, 0, 2, 4.0835e-3, 0],
         [1, -1, -1, 4e-3, -4e-3]])
Sim = network.simulate(nsim=nsim, x0=ninit, show_progress=True)
sim=Sim['Y']
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
# %%capture
fig, ax = plt.subplots()
ax.set_xlim(-2.2,2.2)
ax.set_xticks([])
ax.set_ylim(-2.2,2.2)
ax.set_yticks([])
colors = ['red','blue','orange','green']
ax.scatter([0], [0], c=colors[0])
pts = [ax.plot([],[], c=colors[i], alpha=0.5) for i in range(1,sim.shape[1])]
scts = [ax.scatter(sim[0,i,1], sim[0,i,2], c=colors[i]) for i in range(1,sim.shape[1])]

# %%
def drawframe(n):
    start = np.minimum(n - 10,0)
    end = n
    for i in range(3):
        scts[i].set_offsets(sim[end, i+1, [1,2]])
        pts[i][0].set_data(sim[start:end, i+1, 1], sim[start:end, i+1, 2])
    return pts

# %%
anim = FuncAnimation(fig, drawframe, frames=np.arange(0, nsim, 10), interval=5, blit=True)
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 anim = FuncAnimation(fig, drawframe, frames=np.arange(0, nsim, 10), interval=5, blit=True)
#       2 HTML(anim.to_html5_video())
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/animation.py:1659, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1656 # Needs to be initialized so the draw functions work without checking
#    1657 self._save_seq = []
# -> 1659 super().__init__(fig, **kwargs)
#    1661 # Need to reset the saved seq, since right now it will contain data
#    1662 # for a single frame from init, which is not what we want.
#    1663 self._save_seq = []
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/animation.py:1394, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1392 if event_source is None:
#    1393     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1394 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/animation.py:875, in Animation.__init__(self, fig, event_source, blit)
#     872 self._close_id = self._fig.canvas.mpl_connect('close_event',
#     873                                               self._stop)
#     874 if self._blit:
# --> 875     self._setup_blit()
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/animation.py:1187, in Animation._setup_blit(self)
#    1185 self._drawn_artists = []
#    1186 # _post_draw needs to be called first to initialize the renderer
# -> 1187 self._post_draw(None, self._blit)
#    1188 # Then we need to clear the Frame for the initial draw
#    1189 # This is typically handled in _on_resize because QT and Tk
#    1190 # emit a resize event on launch, but the macosx backend does not,
#    1191 # thus we force it here for everyone for consistency
#    1192 self._init_draw()
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/animation.py:1142, in Animation._post_draw(self, framedata, blit)
#    1140     self._blit_draw(self._drawn_artists)
#    1141 else:
# -> 1142     self._fig.canvas.draw_idle()
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/figure.py:3081, in Figure.draw(self, renderer)
#    3078 finally:
#    3079     self.stale = False
# -> 3081 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/backend_bases.py:1230, in Event._process(self)
#    1228 def _process(self):
#    1229     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1230     self.canvas.callbacks.process(self.name, self)
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:312, in CallbackRegistry.process(self, s, *args, **kwargs)
#     310 except Exception as exc:
#     311     if self.exception_handler is not None:
# --> 312         self.exception_handler(exc)
#     313     else:
#     314         raise
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:307, in CallbackRegistry.process(self, s, *args, **kwargs)
#     305 if func is not None:
#     306     try:
# --> 307         func(*args, **kwargs)
#     308     # this does not capture KeyboardInterrupt, SystemExit,
#     309     # and GeneratorExit
#     310     except Exception as exc:
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/animation.py:899, in Animation._start(self, *args)
#     896 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     898 # Now do any initial draw
# --> 899 self._init_draw()
#     901 # Add our callback for stepping the animation and
#     902 # actually start the event_source.
#     903 self.event_source.add_callback(self._step)
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/animation.py:1721, in FuncAnimation._init_draw(self)
#    1713         warnings.warn(
#    1714             "Can not start iterating the frames for the initial draw. "
#    1715             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1718             "it may be exhausted due to a previous display or save."
#    1719         )
#    1720         return
# -> 1721     self._draw_frame(frame_data)
#    1722 else:
#    1723     self._drawn_artists = self._init_func()
#
# File ~/opt/anaconda3/envs/neuro_exp/lib/python3.10/site-packages/matplotlib/animation.py:1758, in FuncAnimation._draw_frame(self, framedata)
#    1756 for i in self._drawn_artists:
#    1757     if not isinstance(i, mpl.artist.Artist):
# -> 1758         raise err
#    1760 self._drawn_artists = sorted(self._drawn_artists,
#    1761                              key=lambda x: x.get_zorder())
#    1763 for a in self._drawn_artists:
#
# RuntimeError: The animation function must return a sequence of Artist objects.

# %% [markdown]
# # Boid's System

# %%
nx=50
nsim=2000
network = Boids(nx=nx, visual_range = 0.3)
pos_init = np.random.rand(nx,2) * 3 + np.array([[3,1]])
vel_init = np.random.rand(nx,2) * 0.06
x0 = np.hstack([pos_init,vel_init])
sim = network.simulate(x0 = x0, nsim=nsim, show_progress=True)
# Out:
#   0%|          | 0/1999 [00:00<?, ?it/s]

# %%
# %%capture
fig, ax = plt.subplots()
ax.set_xlim(0,10)
ax.set_ylim(0,10)
pos=sim['Y']
scatters = ax.scatter(pos[0,:,0], pos[0,:,1], s=4)

# %%
def drawframe(n):
    scatters.set_offsets(pos[n,:,:2])

# %%
anim = FuncAnimation(fig, drawframe, frames=np.arange(0, nsim), interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...
