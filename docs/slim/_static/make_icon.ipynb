# %%
# load and show an image with Pillow
from PIL import Image
# Open the image form working directory
image = Image.open('slim.png')
# summarize some details about the image
print(image.format)
print(image.size)
print(image.mode)
# show the image
image
# Out:
# PNG
# (128, 128)
# RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=128x128 at 0x7FFCDC0CE550>

# %%
from matplotlib import image
icon = image.imread('draw.png')

# %%
plt.imshow(icon)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(icon)

# %%
noise = np.random.uniform(0, 1, [128, 128])

# %%
plt.imshow(icon[:, :, 3])

# %%
plt.imshow(icon[: , :, 3] + noise)

# %%
img = plt.imshow(icon[: , :, 3] + noise)
plt.axis('off')
plt.savefig("slim.png", bbox_inches='tight')
