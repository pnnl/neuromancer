# %% [markdown]
# # Learning Swing Equation Dynamics using Neural ODEs in NeuroMANCER
#
#
# This tutorial demonstrates the use of [Neural Ordinary Differential Equations](https://arxiv.org/abs/1806.07366) (NODE) for system identificaiton of [swing equation dynamics](https://en.wikipedia.org/wiki/Swing_equation).
#
#
# ## Rotary Electric Motors and Swing Equation Background
#
# A [synchronous electric motor](https://en.wikipedia.org/wiki/Synchronous_motor) is an [AC electric motor](https://en.wikipedia.org/wiki/AC_motor) that represents a core component of electricity generators in the current [electrical grid](https://en.wikipedia.org/wiki/Electrical_grid).
# Simply put, Synchronous AC electric motors transform rotary motion into the AC electric current.
#
#
# <img src="./figs/3phase.gif" width="500">
#
# [Swing equation](https://en.wikipedia.org/wiki/Swing_equation) is a non-linear second order [differential equation](https://en.wikipedia.org/wiki/Differential_equation) that describes the swing of the [rotor](https://en.wikipedia.org/wiki/Rotor_(electric)) of synchronous electric motor.
# Swing equation is mathematically defined as:
# $$
# J \frac{d^2\theta_m}{dt^2} = T_a = T_m - T_e
# $$
#
# where:
# - $J$ is the total moment of inertia of the [rotor](https://en.wikipedia.org/wiki/Rotor_(electric)) mass in $kg m^2$
# - $\theta_m$ is the angular position of the [rotor](https://en.wikipedia.org/wiki/Rotor_(electric)) with respect to a [stationary axis](https://en.wikipedia.org/wiki/Stator) in $rad$
# - $t$ is time in seconds $s$
# - $T_m$ is the mechanical [torque](https://en.wikipedia.org/wiki/Torque) supplied by the prime mover in $N m$
# - $T_e$ is the electrical [torque](https://en.wikipedia.org/wiki/Torque) output of the [alternator](https://en.wikipedia.org/wiki/Alternator) in $N m$
# - $T_{a}$ is the net accelerating [torque](https://en.wikipedia.org/wiki/Torque), in $Nm$
#
# The swing equation can be schematically represented as:
# <img src="./figs/swing_equation.PNG" width="500">
#
#
#
#
# ## System Identification Problem Setup
#
# The objective of [system identification](https://en.wikipedia.org/wiki/System_identification) is to learn or 'identify' a model of a dynamical system from measured time-series data.
# In NODE, this model is parametrized by neural network defining a continuous-time system $\dot{x} = N_{\theta}(x, u)$ to be solver using an ODE integration scheme $\int$. In system identification, the loss $\mathcal{L}$ is evaluated by comparing the  trajectory generated by the model with the training trajectory. The process can be repeated for multiple trajectories to improve the generalization of the model.
#
# <img src="../figs/NODE.PNG" width="600">
#
#
# A special case of NODE models  are [Neural Controlled Differential Equations](https://arxiv.org/abs/2005.08926), that allow us to model system that include exogenous.
# Then starting from a given initial condition  $x_{0}$, the next state of the system  $x_{k+1}$
# is obtained by feeding the current state $x_{k}$ and current input $u_{k}$  into the model $S$.
#
# <img src="../figs/nonauto_ODE.PNG" width="500">
#
#
# ### NODE References
#
# [1] [Ricky T. Q. Chen, Yulia Rubanova, Jesse Bettencourt, David Duvenaud, Neural Ordinary Differential Equations, NeurIPS 2018](https://arxiv.org/abs/1806.07366)
# [2] [Patrick Kidger, James Morrill, James Foster, Terry Lyons, Neural Controlled Differential Equations for Irregular Time Series, NeurIPS 2020](https://arxiv.org/abs/2005.08926)
# [3] http://implicit-layers-tutorial.org/neural_odes/
# [4] https://github.com/Zymrael/awesome-neural-ode
# [5] [Christian Legaard, Thomas Schranz, Gerald Schweiger, Ján Drgoňa, Basak Falay, Cláudio Gomes, Alexandros Iosifidis, Mahdi Abkar, and Peter Larsen. 2023. Constructing Neural Network Based Models for Simulating Dynamical Systems. ACM Comput. Surv. 55, 11, Article 236 (November 2023), 34 pages.](https://dl.acm.org/doi/10.1145/3567591)
#
# ### Power Systems References
# [1] https://en.wikipedia.org/wiki/Swing_equation
# [2] https://electricalworkbook.com/swing-equation/
# [3] https://electricalacademia.com/electric-power/swing-equation-power-system/
# [4] [Y. Baghzouz, Electromechanical Dynamics](http://www.egr.unlv.edu/~eebag/EE%20742%20-%20Chapter%205.pdf)

# %% [markdown]
# ## NeuroMANCER and Dependencies

# %% [markdown]
# ### Install (Colab only)
# Skip this step when running locally.

# %%
# !pip install "neuromancer[examples] @ git+https://github.com/pnnl/neuromancer.git@master"

# %%
import torch
from neuromancer.psl import plot
from neuromancer import psl
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

from neuromancer.system import Node, System
from neuromancer.dynamics import integrators, ode
from neuromancer.trainer import Trainer
from neuromancer.problem import Problem
from neuromancer.loggers import BasicLogger
from neuromancer.dataset import DictDataset
from neuromancer.constraint import variable
from neuromancer.loss import PenaltyLoss
from neuromancer.modules import blocks

torch.manual_seed(0)

# %% [markdown]
# ## Generate trajectories from ODE system
#
# In this example we don't assume any prior knowledge on the system dynamics of the swing equation. We will only have access to limited measurements of the system states $x$ of an unknown [ordinary differential equations](https://en.wikipedia.org/wiki/Ordinary_differential_equation) (ODE).

# %%
# %%  ground truth system
system_name = 'SwingEquation'
system = psl.systems[system_name]
modelSystem = system()
ts = modelSystem.ts
nx = modelSystem.nx
nu = modelSystem.nu
raw = modelSystem.simulate(nsim=1000, ts=ts)
plot.pltOL(Y=raw['Y'], U=raw['U'])
plot.pltPhase(X=raw['Y'])

# %% [markdown]
# ## Create training data of sampled trajectories
#
# We will obtain a dataset of sampled trajectories of the system dynamics in the form of input-state tuples:
# $$D = \big[(u^i_0, \hat{x}^i_0), ..., (u^i_N, \hat{x}^i_{N}) \big], \, \, i \in [1, ..., m]$$
# where $N$ represents the prediction horizon, $m$ represents number of measured trajectories, and $i$ represents an index of the sampled trajectory.
# Variables $x_k$ represent system states, and $u_k$ are exogenous inputs at time $k$.

# %%
def get_data(sys, nsim, nsteps, ts, bs):
    """
    :param nsteps: (int) Number of timesteps for each batch of training data
    :param sys: (psl.system)
    :param ts: (float) step size
    :param bs: (int) batch size

    """
    train_sim, dev_sim, test_sim = [sys.simulate(nsim=nsim, ts=ts) for i in range(3)]
    nx = sys.nx
    nu = sys.nu
    nbatch = nsim//nsteps
    length = (nsim//nsteps) * nsteps

    # for systems with out of scale variables it is important to normalize the data before training
    mean_x = modelSystem.stats['X']['mean']
    std_x = modelSystem.stats['X']['std']
    mean_u = modelSystem.stats['U']['mean']
    std_u = modelSystem.stats['U']['std']
    def normalize(x, mean, std):
        return (x - mean) / std

    trainX = normalize(train_sim['X'][:length], mean_x, std_x)
    trainX = trainX.reshape(nbatch, nsteps, nx)
    trainX = torch.tensor(trainX, dtype=torch.float32)
    trainU = normalize(train_sim['U'][:length], mean_u, std_u)
    trainU = trainU.reshape(nbatch, nsteps, nu)
    trainU = torch.tensor(trainU, dtype=torch.float32)
    train_data = DictDataset({'X': trainX, 'xn': trainX[:, 0:1, :],
                              'U': trainU}, name='train')
    train_loader = DataLoader(train_data, batch_size=bs,
                              collate_fn=train_data.collate_fn, shuffle=True)

    devX = normalize(dev_sim['X'][:length], mean_x, std_x)
    devX = devX.reshape(nbatch, nsteps, nx)
    devX = torch.tensor(devX, dtype=torch.float32)
    devU = normalize(dev_sim['U'][:length], mean_u, std_u)
    devU = devU[:length].reshape(nbatch, nsteps, nu)
    devU = torch.tensor(devU, dtype=torch.float32)
    dev_data = DictDataset({'X': devX, 'xn': devX[:, 0:1, :],
                            'U': devU}, name='dev')
    dev_loader = DataLoader(dev_data, batch_size=bs,
                            collate_fn=dev_data.collate_fn, shuffle=True)

    testX = normalize(test_sim['X'][:length], mean_x, std_x)
    testX = testX.reshape(1, nbatch*nsteps, nx)
    testX = torch.tensor(testX, dtype=torch.float32)
    testU = normalize(test_sim['U'][:length], mean_u, std_u)
    testU = testU.reshape(1, nbatch*nsteps, nu)
    testU = torch.tensor(testU, dtype=torch.float32)
    test_data = {'X': testX, 'xn': testX[:, 0:1, :],
                 'U': testU}

    return train_loader, dev_loader, test_data

# %%
nsim = 2000   # number of simulation steps in the dataset
nsteps = 10   # number of prediction horizon steps in the loss function
bs = 100      # minibatching batch size
train_loader, dev_loader, test_data = get_data(modelSystem, nsim, nsteps, ts, bs)

# %% [markdown]
# ## NODE system model in Neuromancer
#
# Here we construct a non-autonomous NODE model  $\dot{x} = f_{\theta}(x, u)$ with trainable parameters $\theta$.

# %%
# define neural network of the NODE
fx = blocks.MLP(nx+nu, nx, bias=True,
                 linear_map=torch.nn.Linear,
                 nonlin=torch.nn.ReLU,
                 hsizes=[80, 80, 80])

# %% [markdown]
# Next we need to solve the continuous-time NODE model with suitable ODE solver, e.g., [Runge–Kutta integrator](https://en.wikipedia.org/wiki/Runge%E2%80%93Kutta_methods).
# $x_{k+1} = \text{ODESolve}(f_{\theta}(x_k))$
#
# For training we need to obtain accurate reverse-mode gradients of the integrated ODE system. This can be done in two ways, either by unrolling the operations of the ODE solver and using the [backpropagation through time](https://en.wikipedia.org/wiki/Backpropagation_through_time) (BPTT) algorithm, or via [Adjoint state method](https://en.wikipedia.org/wiki/Adjoint_state_method).
#
# Schematics illustrating the adjoing method used in the [Neural Ordinary Differential Equations](https://arxiv.org/abs/1806.07366) paper:
# <img src="../figs/NODE_backprop.png" width="500">
#
# Neuromancer provides a set of ODE solvers implemented in [integrators.py](https://github.com/pnnl/neuromancer/blob/master/src/neuromancer/dynamics/integrators.py).
# For adjoint method we provide the interface to the [open-source implementation](https://github.com/rtqichen/torchdiffeq) via DiffEqIntegrator class. In this example we will use BPTT algorithm through unrolled RK4 solver.

# %%
# integrate NODE with adjoint-based solver
fxRK4 = integrators.RK4(fx, h=ts)

# %% [markdown]
# Next we construct an open-loop system composed of a smbolic NODE model

# %%
# create symbolic system model in Neuromancer
model = Node(fxRK4, ['xn', 'U'], ['xn'], name='NODE')
dynamics_model = System([model], name='system', nsteps=nsteps)

# %%
# visualize the system
# dynamics_model.show()

# %% [markdown]
# ## Define system identification loss function terms
#
# Here we define loss function terms to fit the ODE parameters from given time-series data.
#
# **Tracking loss:**
# $$\ell_x = Q_N||x^i_k - \hat{x}^i_k||_2^2$$
# **One-step loss:**
# $$\ell_x = Q_1||x^i_1 - \hat{x}^i_1||_2^2$$

# %%
# %% Constraints + losses:
x = variable("X")
xhat = variable('xn')[:, :-1, :]

# trajectory tracking loss
reference_loss = 5.*(xhat == x)^2
reference_loss.name = "ref_loss"

# one step tracking loss
onestep_loss = 1.*(xhat[:, 1, :] == x[:, 1, :])^2
onestep_loss.name = "onestep_loss"

# %% [markdown]
# ## Construct System ID learning problem
#
# Given the training dataset $D$ we want to solve the following problem:
#
# $$
# \begin{align}
# &\underset{\theta}{\text{minimize}}     && \sum_{i=1}^m \Big(Q_1||x^i_1 - \hat{x}^i_1||_2^2 + \sum_{k=1}^{N}  Q_N||x^i_k - \hat{x}^i_k||_2^2   \Big) \\
# &\text{subject to}    && x^i_{k+1} =  \text{ODESolve}(f_{\theta}(x^i_k, u^i_k)) \\
# \end{align}
# $$

# %%
# aggregate list of objective terms and constraints
objectives = [reference_loss, onestep_loss]
constraints = []
# create constrained optimization loss
loss = PenaltyLoss(objectives, constraints)
# construct constrained optimization problem
problem = Problem([dynamics_model], loss)

# %%
# plot computational graph
problem.show()

# %% [markdown]
# ## Solve the problem
#
# We fit the unknown NODE parameters $\theta$ using stochastic gradient descent.

# %%
optimizer = torch.optim.Adam(problem.parameters(),
                             lr=0.003)
logger = BasicLogger(args=None, savedir='test', verbosity=1,
                     stdout=['dev_loss', 'train_loss'])

trainer = Trainer(
    problem,
    train_loader,
    dev_loader,
    test_data,
    optimizer,
    patience=100,
    warmup=100,
    epochs=1000,
    eval_metric="dev_loss",
    train_metric="train_loss",
    dev_metric="dev_loss",
    test_metric="dev_loss",
    logger=logger,
)
# Out:
# None
# Number of parameters: 13442

# %%
# %% train
best_model = trainer.train()
problem.load_state_dict(best_model)
# Out:
# epoch: 0	train_loss: 12.00822	dev_loss: 6.85817	eltime:  0.55623
# epoch: 1	train_loss: 9.15057	dev_loss: 5.50923	eltime:  0.62822
# epoch: 2	train_loss: 11.41666	dev_loss: 10.18896	eltime:  0.67510
# epoch: 3	train_loss: 10.33906	dev_loss: 6.41451	eltime:  0.74989
# epoch: 4	train_loss: 9.93736	dev_loss: 7.95866	eltime:  0.82799
# epoch: 5	train_loss: 8.18993	dev_loss: 6.59667	eltime:  0.89348
# epoch: 6	train_loss: 7.03422	dev_loss: 8.03113	eltime:  0.95956
# epoch: 7	train_loss: 8.00260	dev_loss: 6.62821	eltime:  1.02428
# epoch: 8	train_loss: 7.60398	dev_loss: 7.33404	eltime:  1.09583
# epoch: 9	train_loss: 4.63643	dev_loss: 6.85798	eltime:  1.17106
# epoch: 10	train_loss: 4.68001	dev_loss: 5.04861	eltime:  1.24117
# epoch: 11	train_loss: 3.91790	dev_loss: 5.15658	eltime:  1.30708
# epoch: 12	train_loss: 4.57813	dev_loss: 4.46589	eltime:  1.38779
# epoch: 13	train_loss: 4.25862	dev_loss: 4.55964	eltime:  1.46052
# epoch: 14	train_loss: 3.38353	dev_loss: 4.41488	eltime:  1.53842
# epoch: 15	train_loss: 3.43508	dev_loss: 2.79168	eltime:  1.61860
# epoch: 16	train_loss: 2.69404	dev_loss: 2.34596	eltime:  1.69387
# epoch: 17	train_loss: 3.01212	dev_loss: 1.52542	eltime:  1.77481
# epoch: 18	train_loss: 2.13959	dev_loss: 1.50852	eltime:  1.84762
# epoch: 19	train_loss: 2.32243	dev_loss: 2.48429	eltime:  1.92863
# epoch: 20	train_loss: 1.88702	dev_loss: 1.46857	eltime:  1.99802
# epoch: 21	train_loss: 2.20088	dev_loss: 1.85041	eltime:  2.06056
# epoch: 22	train_loss: 1.82263	dev_loss: 1.78704	eltime:  2.14149
# epoch: 23	train_loss: 1.52536	dev_loss: 1.20954	eltime:  2.21059
# epoch: 24	train_loss: 1.06533	dev_loss: 1.02956	eltime:  2.28176
# epoch: 25	train_loss: 1.12136	dev_loss: 0.77397	eltime:  2.34467
# epoch: 26	train_loss: 0.69832	dev_loss: 0.53569	eltime:  2.40529
# epoch: 27	train_loss: 0.63324	dev_loss: 0.46296	eltime:  2.47187
# epoch: 28	train_loss: 0.38202	dev_loss: 0.32325	eltime:  2.53607
# epoch: 29	train_loss: 0.29627	dev_loss: 0.21627	eltime:  2.60137
# epoch: 30	train_loss: 0.23221	dev_loss: 0.19384	eltime:  2.65870
# epoch: 31	train_loss: 0.17830	dev_loss: 0.15434	eltime:  2.73220
# epoch: 32	train_loss: 0.11642	dev_loss: 0.08584	eltime:  2.81064
# epoch: 33	train_loss: 0.14305	dev_loss: 0.10504	eltime:  2.88832
# epoch: 34	train_loss: 0.14541	dev_loss: 0.16511	eltime:  2.96509
# epoch: 35	train_loss: 0.09710	dev_loss: 0.07211	eltime:  3.03443
# epoch: 36	train_loss: 0.11862	dev_loss: 0.07660	eltime:  3.09558
# epoch: 37	train_loss: 0.06774	dev_loss: 0.06162	eltime:  3.17057
# epoch: 38	train_loss: 0.06704	dev_loss: 0.06994	eltime:  3.23929
# epoch: 39	train_loss: 0.06486	dev_loss: 0.06006	eltime:  3.30636
# epoch: 40	train_loss: 0.05827	dev_loss: 0.05253	eltime:  3.36842
# epoch: 41	train_loss: 0.05135	dev_loss: 0.05329	eltime:  3.43991
# epoch: 42	train_loss: 0.05468	dev_loss: 0.03737	eltime:  3.51804
# epoch: 43	train_loss: 0.03586	dev_loss: 0.03372	eltime:  3.59040
# epoch: 44	train_loss: 0.03155	dev_loss: 0.03150	eltime:  3.66160
# epoch: 45	train_loss: 0.02905	dev_loss: 0.03447	eltime:  3.73246
# epoch: 46	train_loss: 0.03081	dev_loss: 0.03347	eltime:  3.80590
# epoch: 47	train_loss: 0.03149	dev_loss: 0.02398	eltime:  3.90691
# epoch: 48	train_loss: 0.03161	dev_loss: 0.03149	eltime:  3.97843
# epoch: 49	train_loss: 0.02495	dev_loss: 0.03374	eltime:  4.04883
# epoch: 50	train_loss: 0.02143	dev_loss: 0.02530	eltime:  4.11783
# epoch: 51	train_loss: 0.02736	dev_loss: 0.02814	eltime:  4.17808
# epoch: 52	train_loss: 0.01335	dev_loss: 0.02494	eltime:  4.26192
# epoch: 53	train_loss: 0.02012	dev_loss: 0.02603	eltime:  4.33147
# epoch: 54	train_loss: 0.01641	dev_loss: 0.01201	eltime:  4.40588
# epoch: 55	train_loss: 0.01917	dev_loss: 0.02875	eltime:  4.47332
# epoch: 56	train_loss: 0.02327	dev_loss: 0.01002	eltime:  4.56304
# epoch: 57	train_loss: 0.01571	dev_loss: 0.01688	eltime:  4.62532
# epoch: 58	train_loss: 0.01446	dev_loss: 0.01539	eltime:  4.70898
# epoch: 59	train_loss: 0.01311	dev_loss: 0.02058	eltime:  4.77582
# epoch: 60	train_loss: 0.01679	dev_loss: 0.00963	eltime:  4.82837
# epoch: 61	train_loss: 0.01247	dev_loss: 0.01545	eltime:  4.89920
# epoch: 62	train_loss: 0.01769	dev_loss: 0.03507	eltime:  4.98023
# epoch: 63	train_loss: 0.01408	dev_loss: 0.01622	eltime:  5.04202
# epoch: 64	train_loss: 0.01630	dev_loss: 0.02089	eltime:  5.11153
# epoch: 65	train_loss: 0.01154	dev_loss: 0.01712	eltime:  5.17318
# epoch: 66	train_loss: 0.01337	dev_loss: 0.01192	eltime:  5.24234
# epoch: 67	train_loss: 0.01216	dev_loss: 0.02103	eltime:  5.31384
# epoch: 68	train_loss: 0.01543	dev_loss: 0.01052	eltime:  5.38410
# epoch: 69	train_loss: 0.01182	dev_loss: 0.01441	eltime:  5.44739
# epoch: 70	train_loss: 0.01544	dev_loss: 0.00907	eltime:  5.52628
# epoch: 71	train_loss: 0.01306	dev_loss: 0.01424	eltime:  5.60059
# epoch: 72	train_loss: 0.01254	dev_loss: 0.01956	eltime:  5.67839
# epoch: 73	train_loss: 0.01051	dev_loss: 0.01748	eltime:  5.74678
# epoch: 74	train_loss: 0.01629	dev_loss: 0.01295	eltime:  5.80331
# epoch: 75	train_loss: 0.01260	dev_loss: 0.02338	eltime:  5.90434
# epoch: 76	train_loss: 0.01032	dev_loss: 0.01886	eltime:  5.96758
# epoch: 77	train_loss: 0.01347	dev_loss: 0.02078	eltime:  6.03456
# epoch: 78	train_loss: 0.02327	dev_loss: 0.02672	eltime:  6.10648
# epoch: 79	train_loss: 0.01359	dev_loss: 0.01070	eltime:  6.18032
# epoch: 80	train_loss: 0.01038	dev_loss: 0.02064	eltime:  6.25483
# epoch: 81	train_loss: 0.01204	dev_loss: 0.01449	eltime:  6.32230
# epoch: 82	train_loss: 0.00919	dev_loss: 0.00732	eltime:  6.40762
# epoch: 83	train_loss: 0.01002	dev_loss: 0.00737	eltime:  6.48748
# epoch: 84	train_loss: 0.00799	dev_loss: 0.01618	eltime:  6.56715
# epoch: 85	train_loss: 0.00601	dev_loss: 0.01443	eltime:  6.63902
# epoch: 86	train_loss: 0.00885	dev_loss: 0.01328	eltime:  6.71074
# epoch: 87	train_loss: 0.00803	dev_loss: 0.00570	eltime:  6.78242
# epoch: 88	train_loss: 0.01002	dev_loss: 0.01491	eltime:  6.85319
# epoch: 89	train_loss: 0.00802	dev_loss: 0.00603	eltime:  6.93094
# epoch: 90	train_loss: 0.00764	dev_loss: 0.01036	eltime:  6.99560
# epoch: 91	train_loss: 0.00821	dev_loss: 0.00977	eltime:  7.06313
# epoch: 92	train_loss: 0.00939	dev_loss: 0.00890	eltime:  7.13621
# epoch: 93	train_loss: 0.00749	dev_loss: 0.01094	eltime:  7.20744
# epoch: 94	train_loss: 0.00807	dev_loss: 0.00596	eltime:  7.28955
# epoch: 95	train_loss: 0.00711	dev_loss: 0.01678	eltime:  7.36376
# epoch: 96	train_loss: 0.00543	dev_loss: 0.01083	eltime:  7.44695
# epoch: 97	train_loss: 0.00599	dev_loss: 0.00973	eltime:  7.51711
# epoch: 98	train_loss: 0.00882	dev_loss: 0.01023	eltime:  7.59017
# epoch: 99	train_loss: 0.00608	dev_loss: 0.00825	eltime:  7.65288
# epoch: 100	train_loss: 0.00712	dev_loss: 0.01517	eltime:  7.71427
# epoch: 101	train_loss: 0.00538	dev_loss: 0.00676	eltime:  7.78442
# epoch: 102	train_loss: 0.00690	dev_loss: 0.01014	eltime:  7.87686
# epoch: 103	train_loss: 0.00577	dev_loss: 0.01562	eltime:  7.94357
# epoch: 104	train_loss: 0.00636	dev_loss: 0.01376	eltime:  8.00857
# epoch: 105	train_loss: 0.00803	dev_loss: 0.01109	eltime:  8.08039
# epoch: 106	train_loss: 0.00663	dev_loss: 0.01299	eltime:  8.15245
# epoch: 107	train_loss: 0.01360	dev_loss: 0.01080	eltime:  8.22688
# epoch: 108	train_loss: 0.00697	dev_loss: 0.01155	eltime:  8.31082
# epoch: 109	train_loss: 0.00769	dev_loss: 0.01065	eltime:  8.37729
# epoch: 110	train_loss: 0.01013	dev_loss: 0.01282	eltime:  8.44285
# epoch: 111	train_loss: 0.00641	dev_loss: 0.00548	eltime:  8.51287
# epoch: 112	train_loss: 0.00652	dev_loss: 0.01077	eltime:  8.58398
# epoch: 113	train_loss: 0.00769	dev_loss: 0.01221	eltime:  8.65640
# epoch: 114	train_loss: 0.00598	dev_loss: 0.01502	eltime:  8.72446
# epoch: 115	train_loss: 0.00674	dev_loss: 0.01192	eltime:  8.79025
# epoch: 116	train_loss: 0.00468	dev_loss: 0.00711	eltime:  8.84793
# epoch: 117	train_loss: 0.00547	dev_loss: 0.01174	eltime:  8.92317
# epoch: 118	train_loss: 0.00560	dev_loss: 0.01208	eltime:  8.99227
# epoch: 119	train_loss: 0.00574	dev_loss: 0.01196	eltime:  9.06344
# epoch: 120	train_loss: 0.00506	dev_loss: 0.00733	eltime:  9.13953
# epoch: 121	train_loss: 0.00465	dev_loss: 0.00957	eltime:  9.20729
# epoch: 122	train_loss: 0.00572	dev_loss: 0.00959	eltime:  9.27916
# epoch: 123	train_loss: 0.00651	dev_loss: 0.01334	eltime:  9.34075
# epoch: 124	train_loss: 0.00491	dev_loss: 0.00803	eltime:  9.41200
# epoch: 125	train_loss: 0.00563	dev_loss: 0.01247	eltime:  9.49354
# epoch: 126	train_loss: 0.00444	dev_loss: 0.01246	eltime:  9.56455
# epoch: 127	train_loss: 0.00557	dev_loss: 0.01238	eltime:  9.63762
# epoch: 128	train_loss: 0.00689	dev_loss: 0.00801	eltime:  9.70739
# epoch: 129	train_loss: 0.00405	dev_loss: 0.00491	eltime:  9.77902
# epoch: 130	train_loss: 0.00613	dev_loss: 0.01098	eltime:  9.87013
# epoch: 131	train_loss: 0.00375	dev_loss: 0.00670	eltime:  9.94852
# epoch: 132	train_loss: 0.00708	dev_loss: 0.01081	eltime:  10.02178
# epoch: 133	train_loss: 0.00344	dev_loss: 0.01157	eltime:  10.09267
# epoch: 134	train_loss: 0.01018	dev_loss: 0.00675	eltime:  10.16331
# epoch: 135	train_loss: 0.00456	dev_loss: 0.00809	eltime:  10.23546
# epoch: 136	train_loss: 0.00448	dev_loss: 0.01019	eltime:  10.29865
# epoch: 137	train_loss: 0.00424	dev_loss: 0.00978	eltime:  10.37323
# epoch: 138	train_loss: 0.00364	dev_loss: 0.00896	eltime:  10.43635
# epoch: 139	train_loss: 0.00315	dev_loss: 0.00975	eltime:  10.53062
# epoch: 140	train_loss: 0.00354	dev_loss: 0.00739	eltime:  10.61982
# epoch: 141	train_loss: 0.00365	dev_loss: 0.00301	eltime:  10.69973
# epoch: 142	train_loss: 0.00566	dev_loss: 0.00818	eltime:  10.77095
# epoch: 143	train_loss: 0.00401	dev_loss: 0.00614	eltime:  10.83987
# epoch: 144	train_loss: 0.00469	dev_loss: 0.00759	eltime:  10.90635
# epoch: 145	train_loss: 0.00336	dev_loss: 0.00687	eltime:  10.97571
# epoch: 146	train_loss: 0.00307	dev_loss: 0.00287	eltime:  11.04654
# epoch: 147	train_loss: 0.00395	dev_loss: 0.00699	eltime:  11.11716
# epoch: 148	train_loss: 0.00321	dev_loss: 0.00728	eltime:  11.20637
# epoch: 149	train_loss: 0.00569	dev_loss: 0.00651	eltime:  11.27733
# epoch: 150	train_loss: 0.00297	dev_loss: 0.00418	eltime:  11.34470
# epoch: 151	train_loss: 0.00404	dev_loss: 0.00772	eltime:  11.42370
# epoch: 152	train_loss: 0.00318	dev_loss: 0.00250	eltime:  11.51049
# epoch: 153	train_loss: 0.00275	dev_loss: 0.00588	eltime:  11.58966
# epoch: 154	train_loss: 0.00351	dev_loss: 0.00754	eltime:  11.66758
# epoch: 155	train_loss: 0.00245	dev_loss: 0.00342	eltime:  11.74513
# epoch: 156	train_loss: 0.00362	dev_loss: 0.00553	eltime:  11.83412
# epoch: 157	train_loss: 0.00330	dev_loss: 0.01029	eltime:  11.92433
# epoch: 158	train_loss: 0.00443	dev_loss: 0.00330	eltime:  11.98908
# epoch: 159	train_loss: 0.00383	dev_loss: 0.00357	eltime:  12.19278
# epoch: 160	train_loss: 0.00359	dev_loss: 0.00358	eltime:  12.30262
# epoch: 161	train_loss: 0.00378	dev_loss: 0.00589	eltime:  12.45650
# epoch: 162	train_loss: 0.00217	dev_loss: 0.00636	eltime:  12.54411
# epoch: 163	train_loss: 0.00426	dev_loss: 0.00760	eltime:  12.62518
# epoch: 164	train_loss: 0.00350	dev_loss: 0.00439	eltime:  12.69656
# epoch: 165	train_loss: 0.00361	dev_loss: 0.00663	eltime:  12.77721
# epoch: 166	train_loss: 0.00316	dev_loss: 0.00583	eltime:  12.84588
# epoch: 167	train_loss: 0.00345	dev_loss: 0.01044	eltime:  12.90714
# epoch: 168	train_loss: 0.00484	dev_loss: 0.00436	eltime:  12.96950
# epoch: 169	train_loss: 0.00426	dev_loss: 0.00883	eltime:  13.02792
# epoch: 170	train_loss: 0.00724	dev_loss: 0.00515	eltime:  13.09809
# epoch: 171	train_loss: 0.00319	dev_loss: 0.01078	eltime:  13.16180
# epoch: 172	train_loss: 0.00685	dev_loss: 0.00377	eltime:  13.23096
# epoch: 173	train_loss: 0.00297	dev_loss: 0.00539	eltime:  13.30180
# epoch: 174	train_loss: 0.00253	dev_loss: 0.00631	eltime:  13.37520
# epoch: 175	train_loss: 0.00355	dev_loss: 0.00832	eltime:  13.44331
# epoch: 176	train_loss: 0.00316	dev_loss: 0.00239	eltime:  13.51856
# epoch: 177	train_loss: 0.00309	dev_loss: 0.01055	eltime:  13.57722
# epoch: 178	train_loss: 0.00489	dev_loss: 0.00335	eltime:  13.64807
# epoch: 179	train_loss: 0.00323	dev_loss: 0.00568	eltime:  13.71676
# epoch: 180	train_loss: 0.00480	dev_loss: 0.00489	eltime:  13.77352
# epoch: 181	train_loss: 0.00360	dev_loss: 0.00882	eltime:  13.84133
# epoch: 182	train_loss: 0.00325	dev_loss: 0.00567	eltime:  13.94708
# epoch: 183	train_loss: 0.00431	dev_loss: 0.00920	eltime:  14.00722
# epoch: 184	train_loss: 0.00779	dev_loss: 0.00512	eltime:  14.09002
# epoch: 185	train_loss: 0.00430	dev_loss: 0.00928	eltime:  14.15686
# epoch: 186	train_loss: 0.00432	dev_loss: 0.00457	eltime:  14.22266
# epoch: 187	train_loss: 0.00365	dev_loss: 0.00392	eltime:  14.28635
# epoch: 188	train_loss: 0.00297	dev_loss: 0.00621	eltime:  14.36775
# epoch: 189	train_loss: 0.00313	dev_loss: 0.00382	eltime:  14.42382
# epoch: 190	train_loss: 0.00233	dev_loss: 0.00186	eltime:  14.49016
# epoch: 191	train_loss: 0.00395	dev_loss: 0.00603	eltime:  14.58076
# epoch: 192	train_loss: 0.00316	dev_loss: 0.00456	eltime:  14.65978
# epoch: 193	train_loss: 0.00254	dev_loss: 0.00793	eltime:  14.72349
# epoch: 194	train_loss: 0.00246	dev_loss: 0.00428	eltime:  14.80600
# epoch: 195	train_loss: 0.00363	dev_loss: 0.00692	eltime:  14.88443
# epoch: 196	train_loss: 0.00245	dev_loss: 0.00728	eltime:  14.95932
# epoch: 197	train_loss: 0.00309	dev_loss: 0.00729	eltime:  15.04017
# epoch: 198	train_loss: 0.00182	dev_loss: 0.00635	eltime:  15.13408
# epoch: 199	train_loss: 0.00454	dev_loss: 0.00628	eltime:  15.21058
# epoch: 200	train_loss: 0.00206	dev_loss: 0.00849	eltime:  15.27625
# epoch: 201	train_loss: 0.00533	dev_loss: 0.00554	eltime:  15.36563
# epoch: 202	train_loss: 0.00238	dev_loss: 0.00473	eltime:  15.42433
# epoch: 203	train_loss: 0.00328	dev_loss: 0.00260	eltime:  15.50635
# epoch: 204	train_loss: 0.00164	dev_loss: 0.00667	eltime:  15.57999
# epoch: 205	train_loss: 0.00370	dev_loss: 0.00379	eltime:  15.64421
# epoch: 206	train_loss: 0.00151	dev_loss: 0.00443	eltime:  15.70640
# epoch: 207	train_loss: 0.00195	dev_loss: 0.00720	eltime:  15.76046
# epoch: 208	train_loss: 0.00238	dev_loss: 0.00494	eltime:  15.84072
# epoch: 209	train_loss: 0.00252	dev_loss: 0.00355	eltime:  15.91554
# epoch: 210	train_loss: 0.00282	dev_loss: 0.00489	eltime:  15.97661
# epoch: 211	train_loss: 0.00240	dev_loss: 0.00685	eltime:  16.05118
# epoch: 212	train_loss: 0.00245	dev_loss: 0.00569	eltime:  16.10988
# epoch: 213	train_loss: 0.00147	dev_loss: 0.00216	eltime:  16.17782
# epoch: 214	train_loss: 0.00355	dev_loss: 0.00568	eltime:  16.24459
# epoch: 215	train_loss: 0.00285	dev_loss: 0.00402	eltime:  16.31413
# epoch: 216	train_loss: 0.00263	dev_loss: 0.00827	eltime:  16.39518
# epoch: 217	train_loss: 0.00386	dev_loss: 0.00631	eltime:  16.45588
# epoch: 218	train_loss: 0.00293	dev_loss: 0.00619	eltime:  16.52667
# epoch: 219	train_loss: 0.00430	dev_loss: 0.00192	eltime:  16.58716
# epoch: 220	train_loss: 0.00235	dev_loss: 0.00469	eltime:  16.65708
# epoch: 221	train_loss: 0.00252	dev_loss: 0.00606	eltime:  16.72747
# epoch: 222	train_loss: 0.00411	dev_loss: 0.00724	eltime:  16.78912
# epoch: 223	train_loss: 0.00728	dev_loss: 0.00184	eltime:  16.85164
# epoch: 224	train_loss: 0.00227	dev_loss: 0.01186	eltime:  16.93253
# epoch: 225	train_loss: 0.00512	dev_loss: 0.00270	eltime:  17.01211
# epoch: 226	train_loss: 0.00250	dev_loss: 0.00482	eltime:  17.08510
# epoch: 227	train_loss: 0.00573	dev_loss: 0.00766	eltime:  17.14570
# epoch: 228	train_loss: 0.00238	dev_loss: 0.00627	eltime:  17.20873
# epoch: 229	train_loss: 0.00730	dev_loss: 0.00489	eltime:  17.26824
# epoch: 230	train_loss: 0.00231	dev_loss: 0.00355	eltime:  17.33922
# epoch: 231	train_loss: 0.00563	dev_loss: 0.00539	eltime:  17.41360
# epoch: 232	train_loss: 0.00260	dev_loss: 0.00844	eltime:  17.49068
# epoch: 233	train_loss: 0.00446	dev_loss: 0.00515	eltime:  17.56028
# epoch: 234	train_loss: 0.00201	dev_loss: 0.00416	eltime:  17.62658
# epoch: 235	train_loss: 0.00220	dev_loss: 0.00307	eltime:  17.69450
# epoch: 236	train_loss: 0.00143	dev_loss: 0.00444	eltime:  17.77600
# epoch: 237	train_loss: 0.00213	dev_loss: 0.00353	eltime:  17.87386
# epoch: 238	train_loss: 0.00113	dev_loss: 0.00549	eltime:  17.93768
# epoch: 239	train_loss: 0.00214	dev_loss: 0.00341	eltime:  18.00910
# epoch: 240	train_loss: 0.00151	dev_loss: 0.00351	eltime:  18.07758
# epoch: 241	train_loss: 0.00195	dev_loss: 0.00173	eltime:  18.14028
# epoch: 242	train_loss: 0.00158	dev_loss: 0.00494	eltime:  18.21165
# epoch: 243	train_loss: 0.00159	dev_loss: 0.00534	eltime:  18.29541
# epoch: 244	train_loss: 0.00162	dev_loss: 0.00132	eltime:  18.37402
# epoch: 245	train_loss: 0.00108	dev_loss: 0.00485	eltime:  18.49451
# epoch: 246	train_loss: 0.00291	dev_loss: 0.00397	eltime:  18.60768
# epoch: 247	train_loss: 0.00116	dev_loss: 0.00633	eltime:  18.68122
# epoch: 248	train_loss: 0.00264	dev_loss: 0.00503	eltime:  18.74358
# epoch: 249	train_loss: 0.00139	dev_loss: 0.00372	eltime:  18.81422
# epoch: 250	train_loss: 0.00246	dev_loss: 0.00234	eltime:  18.88212
# epoch: 251	train_loss: 0.00132	dev_loss: 0.00430	eltime:  18.96429
# epoch: 252	train_loss: 0.00252	dev_loss: 0.00541	eltime:  19.03883
# epoch: 253	train_loss: 0.00144	dev_loss: 0.00097	eltime:  19.11230
# epoch: 254	train_loss: 0.00190	dev_loss: 0.00634	eltime:  19.17456
# epoch: 255	train_loss: 0.00220	dev_loss: 0.00289	eltime:  19.24121
# epoch: 256	train_loss: 0.00181	dev_loss: 0.00960	eltime:  19.33748
# epoch: 257	train_loss: 0.00675	dev_loss: 0.00576	eltime:  19.42218
# epoch: 258	train_loss: 0.00126	dev_loss: 0.00528	eltime:  19.52805
# epoch: 259	train_loss: 0.00524	dev_loss: 0.00659	eltime:  19.62389
# epoch: 260	train_loss: 0.00160	dev_loss: 0.00957	eltime:  19.69028
# epoch: 261	train_loss: 0.00747	dev_loss: 0.00654	eltime:  19.76131
# epoch: 262	train_loss: 0.00146	dev_loss: 0.00722	eltime:  19.85322
# epoch: 263	train_loss: 0.00984	dev_loss: 0.00795	eltime:  19.92430
# epoch: 264	train_loss: 0.00243	dev_loss: 0.00637	eltime:  19.99530
# epoch: 265	train_loss: 0.00224	dev_loss: 0.00689	eltime:  20.05574
# epoch: 266	train_loss: 0.00157	dev_loss: 0.00360	eltime:  20.12642
# epoch: 267	train_loss: 0.00128	dev_loss: 0.00164	eltime:  20.18693
# epoch: 268	train_loss: 0.00154	dev_loss: 0.00510	eltime:  20.25255
# epoch: 269	train_loss: 0.00110	dev_loss: 0.00332	eltime:  20.32836
# epoch: 270	train_loss: 0.00097	dev_loss: 0.00331	eltime:  20.40120
# epoch: 271	train_loss: 0.00101	dev_loss: 0.00584	eltime:  20.47326
# epoch: 272	train_loss: 0.00196	dev_loss: 0.00592	eltime:  20.55326
# epoch: 273	train_loss: 0.00193	dev_loss: 0.00140	eltime:  20.62427
# epoch: 274	train_loss: 0.00175	dev_loss: 0.00375	eltime:  20.70459
# epoch: 275	train_loss: 0.00262	dev_loss: 0.00321	eltime:  20.77610
# epoch: 276	train_loss: 0.00125	dev_loss: 0.00540	eltime:  20.85728
# epoch: 277	train_loss: 0.00209	dev_loss: 0.00534	eltime:  20.92744
# epoch: 278	train_loss: 0.00137	dev_loss: 0.00121	eltime:  21.00430
# epoch: 279	train_loss: 0.00193	dev_loss: 0.00324	eltime:  21.07627
# epoch: 280	train_loss: 0.00107	dev_loss: 0.00478	eltime:  21.14034
# epoch: 281	train_loss: 0.00282	dev_loss: 0.00422	eltime:  21.20740
# epoch: 282	train_loss: 0.00093	dev_loss: 0.00142	eltime:  21.29022
# epoch: 283	train_loss: 0.00253	dev_loss: 0.00368	eltime:  21.37347
# epoch: 284	train_loss: 0.00128	dev_loss: 0.00287	eltime:  21.45677
# epoch: 285	train_loss: 0.00169	dev_loss: 0.00581	eltime:  21.53901
# epoch: 286	train_loss: 0.00204	dev_loss: 0.00377	eltime:  21.61449
# epoch: 287	train_loss: 0.00119	dev_loss: 0.00247	eltime:  21.68865
# epoch: 288	train_loss: 0.00115	dev_loss: 0.00393	eltime:  21.76145
# epoch: 289	train_loss: 0.00144	dev_loss: 0.00350	eltime:  21.84925
# epoch: 290	train_loss: 0.00124	dev_loss: 0.00355	eltime:  21.96201
# epoch: 291	train_loss: 0.00265	dev_loss: 0.00263	eltime:  22.04010
# epoch: 292	train_loss: 0.00109	dev_loss: 0.00322	eltime:  22.12534
# epoch: 293	train_loss: 0.00183	dev_loss: 0.00352	eltime:  22.20738
# epoch: 294	train_loss: 0.00127	dev_loss: 0.00294	eltime:  22.28955
# epoch: 295	train_loss: 0.00176	dev_loss: 0.00467	eltime:  22.35017
# epoch: 296	train_loss: 0.00189	dev_loss: 0.00172	eltime:  22.42059
# epoch: 297	train_loss: 0.00111	dev_loss: 0.00328	eltime:  22.49171
# epoch: 298	train_loss: 0.00202	dev_loss: 0.00351	eltime:  22.55720
# epoch: 299	train_loss: 0.00159	dev_loss: 0.00260	eltime:  22.62159
# epoch: 300	train_loss: 0.00100	dev_loss: 0.00275	eltime:  22.69000
# epoch: 301	train_loss: 0.00150	dev_loss: 0.00489	eltime:  22.76835
# epoch: 302	train_loss: 0.00080	dev_loss: 0.00154	eltime:  22.84136
# epoch: 303	train_loss: 0.00153	dev_loss: 0.00501	eltime:  22.90594
# epoch: 304	train_loss: 0.00134	dev_loss: 0.00147	eltime:  22.95657
# epoch: 305	train_loss: 0.00139	dev_loss: 0.00575	eltime:  23.04143
# epoch: 306	train_loss: 0.00282	dev_loss: 0.00531	eltime:  23.10640
# epoch: 307	train_loss: 0.00095	dev_loss: 0.00581	eltime:  23.17451
# epoch: 308	train_loss: 0.00468	dev_loss: 0.00472	eltime:  23.24361
# epoch: 309	train_loss: 0.00202	dev_loss: 0.00144	eltime:  23.31205
# epoch: 310	train_loss: 0.00155	dev_loss: 0.00467	eltime:  23.37698
# epoch: 311	train_loss: 0.00236	dev_loss: 0.00616	eltime:  23.44842
# epoch: 312	train_loss: 0.00099	dev_loss: 0.00256	eltime:  23.51781
# epoch: 313	train_loss: 0.00177	dev_loss: 0.00379	eltime:  23.58181
# epoch: 314	train_loss: 0.00127	dev_loss: 0.00270	eltime:  23.64840
# epoch: 315	train_loss: 0.00102	dev_loss: 0.00566	eltime:  23.72359
# epoch: 316	train_loss: 0.00102	dev_loss: 0.00254	eltime:  23.80277
# epoch: 317	train_loss: 0.00098	dev_loss: 0.00139	eltime:  23.90113
# epoch: 318	train_loss: 0.00118	dev_loss: 0.00463	eltime:  23.97506
# epoch: 319	train_loss: 0.00107	dev_loss: 0.00260	eltime:  24.04798
# epoch: 320	train_loss: 0.00062	dev_loss: 0.00294	eltime:  24.11176
# epoch: 321	train_loss: 0.00147	dev_loss: 0.00314	eltime:  24.20514
# epoch: 322	train_loss: 0.00139	dev_loss: 0.00455	eltime:  24.31563
# epoch: 323	train_loss: 0.00093	dev_loss: 0.00303	eltime:  24.42002
# epoch: 324	train_loss: 0.00126	dev_loss: 0.00304	eltime:  24.48754
# epoch: 325	train_loss: 0.00105	dev_loss: 0.00353	eltime:  24.55628
# epoch: 326	train_loss: 0.00086	dev_loss: 0.00311	eltime:  24.61896
# epoch: 327	train_loss: 0.00090	dev_loss: 0.00246	eltime:  24.68969
# epoch: 328	train_loss: 0.00105	dev_loss: 0.00106	eltime:  24.76730
# epoch: 329	train_loss: 0.00094	dev_loss: 0.00285	eltime:  24.83700
# epoch: 330	train_loss: 0.00067	dev_loss: 0.00463	eltime:  24.90674
# epoch: 331	train_loss: 0.00080	dev_loss: 0.00421	eltime:  24.97200
# epoch: 332	train_loss: 0.00078	dev_loss: 0.00306	eltime:  25.03847
# epoch: 333	train_loss: 0.00071	dev_loss: 0.00247	eltime:  25.10722
# epoch: 334	train_loss: 0.00092	dev_loss: 0.00407	eltime:  25.17763
# epoch: 335	train_loss: 0.00142	dev_loss: 0.00302	eltime:  25.25649
# epoch: 336	train_loss: 0.00300	dev_loss: 0.00488	eltime:  25.33301
# epoch: 337	train_loss: 0.00277	dev_loss: 0.00175	eltime:  25.40689
# epoch: 338	train_loss: 0.00169	dev_loss: 0.00446	eltime:  25.48337
# epoch: 339	train_loss: 0.00086	dev_loss: 0.00288	eltime:  25.55355
# epoch: 340	train_loss: 0.00175	dev_loss: 0.00327	eltime:  25.61477
# epoch: 341	train_loss: 0.00308	dev_loss: 0.00534	eltime:  25.69102
# epoch: 342	train_loss: 0.00202	dev_loss: 0.00135	eltime:  25.75871
# epoch: 343	train_loss: 0.00066	dev_loss: 0.00445	eltime:  25.83016
# epoch: 344	train_loss: 0.00104	dev_loss: 0.00209	eltime:  25.91678
# epoch: 345	train_loss: 0.00090	dev_loss: 0.00383	eltime:  25.98884
# epoch: 346	train_loss: 0.00254	dev_loss: 0.00432	eltime:  26.05907
# epoch: 347	train_loss: 0.00380	dev_loss: 0.00499	eltime:  26.12830
# epoch: 348	train_loss: 0.00109	dev_loss: 0.00461	eltime:  26.19882
# epoch: 349	train_loss: 0.00241	dev_loss: 0.00330	eltime:  26.26860
# epoch: 350	train_loss: 0.00522	dev_loss: 0.00331	eltime:  26.33000
# epoch: 351	train_loss: 0.00117	dev_loss: 0.00223	eltime:  26.40850
# epoch: 352	train_loss: 0.00159	dev_loss: 0.00324	eltime:  26.48822
# epoch: 353	train_loss: 0.00291	dev_loss: 0.00407	eltime:  26.58976
# epoch: 354	train_loss: 0.00265	dev_loss: 0.00368	eltime:  26.71206
# Early stopping!!!
# <All keys matched successfully>

# %% [markdown]
# ## Parameter estimation results

# %%
# update the rollout length based on the test data
dynamics_model.nsteps = test_data['X'].shape[1]

# %%
# Test set results
test_outputs = dynamics_model(test_data)

pred_traj = test_outputs['xn'][:, :-1, :].detach().numpy().reshape(-1, nx)
true_traj = test_data['X'].detach().numpy().reshape(-1, nx)
input_traj = test_data['U'].detach().numpy().reshape(-1, nu)
pred_traj, true_traj = pred_traj.transpose(1, 0), true_traj.transpose(1, 0)

# %%
# plot rollout
figsize = 25
fig, ax = plt.subplots(nx+nu, figsize=(figsize, figsize))
labels = [f'$y_{k}$' for k in range(len(true_traj))] 
for row, (t1, t2, label) in enumerate(zip(true_traj, pred_traj, labels)):
    if nx > 1:
        axe = ax[row]
    else:
        axe = ax
    axe.set_ylabel(label, rotation=0, labelpad=20, fontsize=figsize)
    axe.plot(t1, 'c', linewidth=4.0, label='True')
    axe.plot(t2, 'm--', linewidth=4.0, label='Pred')
    axe.tick_params(labelbottom=False, labelsize=figsize)
axe.tick_params(labelbottom=True, labelsize=figsize)
axe.legend(fontsize=figsize)
ax[-1].plot(input_traj, 'c', linewidth=4.0, label='inputs') 
ax[-1].legend(fontsize=figsize)
ax[-1].set_xlabel('$time$', fontsize=figsize)
ax[-1].set_ylabel('$u$', rotation=0, labelpad=20, fontsize=figsize)
ax[-1].tick_params(labelbottom=True, labelsize=figsize)
plt.tight_layout()
