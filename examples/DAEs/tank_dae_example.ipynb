# %% [markdown]
# # Learning Neural Differential Algebraic Equations via Operator Splitting
#
# Implementation of the Tank-Manifold Property Inference Example from the paper:
#
# [James Koch, Madelyn Shapiro, Himanshu Sharma, Draguna Vrabie, and Jan Drgona,Learning Neural Differential Algebraic Equations via Operator Splitting, Conference on Decision and Control (CDC), 2025.
# ](https://arxiv.org/abs/2403.12938)
#
#
# Neural Differential Algebraic Equations (Neural DAEs) are an extension of the canonical neural timestepper for systems with algebraic constraints. Inspired by fractional-step methods, this work leverages sequential sub-tasks to provide updates for algebraic states and differential states.
#
#
# Differential-Algebraic Equations (DAEs) are systems comprising differential and algebraic relationships that describe the evolution of a system's states. Specifically, we are concerned with semi-explicit DAEs written as:
# $$
# \begin{align}
#     \frac{dx}{dt}   = f\left( x, y, u \right), \\
#     0 = g\left(  x,y,u \right),
# \end{align}
# $$
#
# where $x \in \mathbb{R}^{n_x}$ are the differential states of a system that evolve according to the vector field defined by $f: \mathbb{R}^{n_x}\times \mathbb{R}^{n_y}\times\mathbb{R}^{n_u} \to \mathbb{R}^{n_x} $, $y \in \mathbb{R}^{n_y}$ are the algebraic states, and $u \in \mathbb{R}^{n_u}$ are exogenous inputs.
#
# In this example we aim to solve the following optimization problem:
# $$
# \begin{align}
# &\underset{\theta_f}{\text{min}}     && \int_{t_0}^{t_N} \Big( ||x - \hat{x}||_2^2   +||y - \hat{y}||_2^2   \Big) \\
# &\text{s.t}    &&
#     \frac{dx}{dt}  = f(x(t), y(t), u(t); \theta_f) , \\
#   &  &&  0  = g(x(t), y(t), u(t)), \\
#   &  &&  x({t_0}) = x_0, \, \, \,  y({t_0}) = y_0,
# \end{align}
# $$
#
# Here $\hat{x}, \hat{y}$ represent reference differentiable and algebraic variables generated by the unknown DAE system. The objective of the problem is to train the parameters $\theta_f$ of the neural DAE model such that the reference state trajectories in the time interval $[{t_0}, {t_N}]$ match the observed states.

# %% [markdown]
# ### Install (Colab only)
# Skip this step when running locally.

# %%
# !pip install neuromancer

# %% [markdown]
# ### Import necessary libraries

# %%
import numpy as np
import requests

import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

import neuromancer.slim as slim
from neuromancer.modules import blocks
from neuromancer.dynamics import integrators, ode
from neuromancer.trainer import Trainer
from neuromancer.problem import Problem
from neuromancer.dataset import DictDataset
from neuromancer.loss import PenaltyLoss
from neuromancer.constraint import variable
from neuromancer.system import Node, System
from neuromancer.loggers import BasicLogger

# %%
# Set device and random seed
device = 'cpu'
seed = 136
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# ### Dataset for DAE system
# In this example we consider **Tank-Manifold-Pump** system characterized by conservation relationship that manifests as an algebraic constraint in the DAE.
#
# Tank-Manifold-Pump schematics:
# <img src="../figs/manifold.png" width="600">
#
# differential equations:
# $$
# \begin{align}
#     \frac{dx_1}{dt} = \frac{y_1}{\phi_1(x_1)}, \\
#     \frac{dx_2}{dt} = \frac{y_2}{\phi_2(x_2)},
# \end{align}
# $$
#
# algebraic equations:
# $$
# \begin{align}
#   0 = y_{\text{in}} - y_1 - y_2, \\
#   0 = x_1 - x_2,
#  \end{align}
# $$
#
# Here $\phi_1$ and $\phi_2$ denote the area-height profiles for the two tanks. For this study, the area-height profiles are set to $\phi_1(x) = 3.0$ and $\phi_2(x) = \sqrt{x} + 0.1$ respectively. The goal of the learning task is to recover $\phi_2(x)$ given observations of tank heights $x$ and pump volumetric flow rates $y$.
#
# At the manifold, the inflow is exactly equal to the sum of the outflows; that is, $y_{\text{in}} = y_1 + y_2$, where $y$ represents volumetric flow rates and the subscripts $1$ and $2$ denote the two exit streams of the manifold. The two tanks have different area-height profiles but share a common datum such that the column heights are identical. As a fluid is pumped into the two tanks, the flow rates in the two streams vary to ensure (i) the conservation relationship of the manifold and (ii) identical pressure head of the tanks, i.e, $x_1 = x_2$, where $x$ is the height of the fluid.
#
# states - x:
# $x_1$ - height of tank 1
# $x_2$ - height of tank 2
# $y_1$ - mass flow into tank 1 - index 2
# $y_2$ - mass flow into tank 2 - index 3
#
# inputs - u:
# $y_{\text{in}}$   - mass flow into system

# %%
# Raw URL of area.dat
url = "https://raw.githubusercontent.com/pnnl/NeuralDAEs/master/training/area.dat"

# Download and save the file locally
response = requests.get(url)
with open("area.dat", "wb") as f:
    f.write(response.content)
area_data = np.loadtxt('area.dat')

# Raw URL of tanks_splits.dat
url = "https://raw.githubusercontent.com/pnnl/NeuralDAEs/master/training/tanks_splits.dat"

# Download and save the file locally
response = requests.get(url)
with open("tanks_splits.dat", "wb") as f:
    f.write(response.content)

# Load the data using numpy
tank_data = np.float32(np.loadtxt("tanks_splits.dat"))

# %%
# define problem dimensions
nx = 4
nu = 1
dt = 1.0

# %%
# add noise function
def add_snr(data, db):
    snr = 10 ** (db / 10)
    for i in range(data.shape[1]):
        signal_power = np.mean(data[:, i] ** 2)
        std_n = (signal_power / snr) ** 0.5
        if snr > 1e8:
            continue
        data[:, i] += np.random.normal(0, std_n, len(data[:, i]))
    return data

# %%
# load data from pre-computed DAE system
data = tank_data[:len(tank_data) // 2, :]
data = data[1:, :]
db = 90
data = add_snr(data, db)
time = np.linspace(0.0, len(data)-1, len(data)).reshape(-1, 1).astype(np.float32) * dt
U = np.full_like(time, 0.5, dtype=np.float32)

train_data = {'X': torch.tensor(data),
              'U': torch.tensor(U),
              'Time': torch.tensor(time)}
dev_data = train_data.copy()
test_data = train_data.copy()

# %%
# set simulation steps and prediction horizon for system ID loss
nsim = data.shape[0]
nstep = 5

# %%
# reshape the data and for system ID optimization
for d in [train_data, dev_data]:
    d['X'] = d['X'].reshape(nsim // nstep, nstep, nx)
    d['U'] = d['U'].reshape(nsim // nstep, nstep, nu)
    d['xn'] = d['X'][:, 0:1, :]
    d['Time'] = d['Time'].reshape(nsim // nstep, -1)

test_data['X'] = test_data['X'].reshape(1, nsim, nx)
test_data['U'] = test_data['U'].reshape(1, nsim, 1)
test_data['xn'] = test_data['X'][:, 0:1, :]
test_data['Time'] = test_data['Time'].reshape(nsim, -1)

# %% [markdown]
# We get the dataset in the form $\hat{X} = \{(\hat{x}^{(0)},\hat{y}^{(0)}), ..., (\hat{x}^{(N)},\hat{y}^{(N)})\}$ where  $\hat{x}^i, \hat{y}^i$ are differential and algebraic states respectively at the $t-th$ time step, and $N$ represent the length of the rollout.

# %%
# create data loaders
train_dataset, dev_dataset = [DictDataset(d, name=n) for d, n in zip([train_data, dev_data], ['train', 'dev'])]
train_loader, dev_loader, test_loader = [
    DataLoader(d, batch_size=nsim // nstep, collate_fn=d.collate_fn, shuffle=True)
    for d in [train_dataset, dev_dataset, dev_dataset]
]

# %% [markdown]
# ### Define DAE system dynamics model
#
#
# Using operator splitting to solve the semi-explicit DAE, we define the following neural time-stepper:
# $$
#     \begin{align}
#         y^{(t+\Delta t)} & = h\left( x^{(t)},y^{(t)},u^{(t)} ; \theta_h\right), \\
#         x^{(t+\Delta t)} &= \text{ODESolve}\left(f ,\{x^{(t)},y^{(t+\Delta t)}, u^{(t)}\}; \theta_f\right),
#     \end{align}
# $$
#
# where $ h: \mathbb{R}^{n_x} \times \mathbb{R}^{n_y} \times \mathbb{R}^{n_u} \rightarrow \mathbb{R}^{n_y} $ is a neural surrogate for the algebraic update, and $\text{ODESolve}$ is an ODE solver.
#
# Schematics of the Operator Splitting approach for Neural DAEs:
# <img src="../figs/fig_01.png" width="600">
#
# In the following we define the algebraic neural solver and the physics-structured ODE part of the system.

# %%
# Define the algebra surrogate
class AlgebraSolver(nn.Module):
    def __init__(self, net):
        super().__init__()
        self.net = net

    def forward(self, x, u):
        if x.ndim == 1:
            x = x.unsqueeze(0)  # Ensure batch dimension

        # get differential states
        h1 = x[:, 0].unsqueeze(-1)
        h2 = x[:, 1].unsqueeze(-1)
        # get the mass flow input
        m = u[:, 0].unsqueeze(-1)

        # get the mass flow outputs through the algebra solver
        in_algebra = torch.cat([h1, h2], dim=-1)
        param = torch.abs(self.net(in_algebra))
        m1 = m * param
        m2 = m * (1.0 - param)

        # update algebra states
        x_new = x.clone()
        x_new[:, 2] = m1.squeeze(-1)
        x_new[:, 3] = m2.squeeze(-1)
        return x_new

# %%
# define the physics-structured ODE part of the system
class TankManifoldDynamics(ode.ODESystem):
    def __init__(self, net, insize=nx, outsize=nx):
        super().__init__(insize=insize, outsize=outsize)
        self.net = net

    def ode_equations(self, x):
        # get the differential and algebraic states
        h1 = x[:, 0].unsqueeze(-1)
        h2 = x[:, 1].unsqueeze(-1)
        m1 = x[:, 2].unsqueeze(-1)
        m2 = x[:, 3].unsqueeze(-1)
        # get the area
        A1 = 3.0 * torch.ones_like(h1)
        A2 = self.net(h2)
        # compute the differential states
        dh1 = m1 / A1
        dh2 = m2 / A2
        # update differential states
        dx = torch.zeros_like(x)
        dx[:, 0] = dh1.squeeze(-1)
        dx[:, 1] = dh2.squeeze(-1)
        return dx

# %% [markdown]
# ### Instantiate the neural DAE model
#
# Puttings thing together we obtain neural DAE model in the form:
#
# $$
#  \{x^{(t+\Delta t)},y^{(t+\Delta t)}\} =
#         \text{DAESolve} \left(f,h,\{x^{(t)}, y^{(t)}, u^{(t)}\};\Theta\right),
# $$
#  where $\Theta = \{\theta_h,\theta_f\}$ is the set of all model parameters, and the temporal integration bounds are assumed to be  $[t, t+ \Delta t]$.

# %%
# define neural component of the algebra solver
algebra_net = blocks.MLP(insize=2, outsize=1, hsizes=[3],
                         linear_map=slim.maps['linear'], nonlin=nn.Sigmoid)
# instantiate the algebra solver and wrap it in a Node
algebra = Node(AlgebraSolver(algebra_net), ['xn', 'U'],
               ['x_alg'], name='algebra')

# %%
# define neural component of the ODE part
tank_profile = blocks.MLP(insize=1, outsize=1, hsizes=[5],
                          linear_map=slim.maps['linear'], nonlin=nn.Sigmoid)
# Instantiate ODE model
ode_dynamics = TankManifoldDynamics(tank_profile)
fx_int = integrators.RK4(ode_dynamics, h=dt)
ode_node = Node(fx_int, ['x_alg'],
                ['xn'], name='ode_node')

# %%
# Compose DAE system via operator splitting approach
dynamics_model = System([algebra, ode_node], nsteps=nstep)

# %% [markdown]
# ### Define the optimization problem
#
# We define the loss function to match the differential states and algebraic states of the modeled system $X$ with the observed states $\hat{X}$.
#
# $$
#  \mathcal{L}(\Theta) = \mathcal{L}_{\text{residual}}(X,\hat{X};\Theta)
# $$
#
# $\mathcal{L}_{\text{residual}}(X,\hat{X};\Theta) = \sum_{t=0}^{N} \left( ||x_t - \hat{x}_t ||_2^2  + ||y_t - \hat{y}_t ||_2^2  \right)$ is a measure of the residual between the model's differential and algebraic states ${X} = \{({x}^{(0)},{y}^{(0)}), ..., ({x}^{(N)},{y}^{(N)})\}$, and the training dataset $\hat{X} = \{(\hat{x}^{(0)},\hat{y}^{(0)}), ..., (\hat{x}^{(N)},\hat{y}^{(N)})\}$,
# where $N$ defines the length of a finite-horizon rollout.

# %%
# track differential and algebraic states
x = variable("X")
xhat = variable("xn")[:, :-1, :]
reference_loss = ((xhat == x) ^ 2)
reference_loss.name = "ref_loss"

# %%
# define the loss function
loss = PenaltyLoss([reference_loss], [])
problem = Problem([dynamics_model], loss)

# %% [markdown]
# ### Instantiate the Trainer and train the model

# %%
optimizer = torch.optim.Adam(problem.parameters(), lr=0.001)
logger = BasicLogger(args=None, savedir='test', verbosity=10,
                     stdout=["dev_loss", "train_loss"])

trainer = Trainer(
    problem, train_loader, dev_loader, test_loader, optimizer,
    epochs=20000, patience=100, warmup=100,
    eval_metric="dev_loss", train_metric="train_loss",
    dev_metric="dev_loss", test_metric="dev_loss",
    logger=logger,
)
# Out:
# None
# Number of parameters: 29

# %%
#train the model
trained_model_dict = trainer.train()
# Out:
# epoch: 0	train_loss: 1.08393	dev_loss: 1.05159	eltime:  0.13272
# epoch: 10	train_loss: 0.80642	dev_loss: 0.78379	eltime:  0.30664
# epoch: 20	train_loss: 0.61390	dev_loss: 0.59830	eltime:  0.48122
# epoch: 30	train_loss: 0.48077	dev_loss: 0.46989	eltime:  0.65255
# epoch: 40	train_loss: 0.38696	dev_loss: 0.37917	eltime:  0.81256
# epoch: 50	train_loss: 0.31883	dev_loss: 0.31306	eltime:  0.99603
# epoch: 60	train_loss: 0.26766	dev_loss: 0.26325	eltime:  1.16662
# epoch: 70	train_loss: 0.22804	dev_loss: 0.22457	eltime:  1.35730
# epoch: 80	train_loss: 0.19656	dev_loss: 0.19376	eltime:  1.53764
# epoch: 90	train_loss: 0.17103	dev_loss: 0.16874	eltime:  1.71134
# epoch: 100	train_loss: 0.14998	dev_loss: 0.14808	eltime:  1.90207
# epoch: 110	train_loss: 0.13241	dev_loss: 0.13081	eltime:  2.08218
# epoch: 120	train_loss: 0.11759	dev_loss: 0.11624	eltime:  2.27060
# epoch: 130	train_loss: 0.10498	dev_loss: 0.10383	eltime:  2.43786
# epoch: 140	train_loss: 0.09420	dev_loss: 0.09320	eltime:  2.60460
# epoch: 150	train_loss: 0.08491	dev_loss: 0.08406	eltime:  2.76756
# epoch: 160	train_loss: 0.07690	dev_loss: 0.07616	eltime:  2.95360
# epoch: 170	train_loss: 0.06995	dev_loss: 0.06931	eltime:  3.12838
# epoch: 180	train_loss: 0.06393	dev_loss: 0.06337	eltime:  3.29257
# epoch: 190	train_loss: 0.05868	dev_loss: 0.05819	eltime:  3.46751
# epoch: 200	train_loss: 0.05407	dev_loss: 0.05363	eltime:  3.64862
# epoch: 210	train_loss: 0.04997	dev_loss: 0.04959	eltime:  3.81911
# epoch: 220	train_loss: 0.04630	dev_loss: 0.04595	eltime:  3.98485
# epoch: 230	train_loss: 0.04299	dev_loss: 0.04268	eltime:  4.15844
# epoch: 240	train_loss: 0.04000	dev_loss: 0.03972	eltime:  4.32065
# epoch: 250	train_loss: 0.03732	dev_loss: 0.03707	eltime:  4.48543
# epoch: 260	train_loss: 0.03493	dev_loss: 0.03471	eltime:  4.65267
# epoch: 270	train_loss: 0.03283	dev_loss: 0.03264	eltime:  4.82826
# epoch: 280	train_loss: 0.03101	dev_loss: 0.03084	eltime:  4.99454
# epoch: 290	train_loss: 0.02944	dev_loss: 0.02930	eltime:  5.15700
# epoch: 300	train_loss: 0.02810	dev_loss: 0.02798	eltime:  5.31830
# epoch: 310	train_loss: 0.02697	dev_loss: 0.02687	eltime:  5.48522
# epoch: 320	train_loss: 0.02601	dev_loss: 0.02592	eltime:  5.66184
# epoch: 330	train_loss: 0.02520	dev_loss: 0.02512	eltime:  5.84150
# epoch: 340	train_loss: 0.02451	dev_loss: 0.02444	eltime:  6.00704
# epoch: 350	train_loss: 0.02392	dev_loss: 0.02386	eltime:  6.15911
# epoch: 360	train_loss: 0.02341	dev_loss: 0.02336	eltime:  6.34209
# epoch: 370	train_loss: 0.02296	dev_loss: 0.02292	eltime:  6.52003
# epoch: 380	train_loss: 0.02258	dev_loss: 0.02254	eltime:  6.68584
# epoch: 390	train_loss: 0.02223	dev_loss: 0.02220	eltime:  6.87239
# epoch: 400	train_loss: 0.02193	dev_loss: 0.02190	eltime:  7.05226
# epoch: 410	train_loss: 0.02166	dev_loss: 0.02163	eltime:  7.23513
# epoch: 420	train_loss: 0.02141	dev_loss: 0.02139	eltime:  7.41996
# epoch: 430	train_loss: 0.02119	dev_loss: 0.02116	eltime:  7.59169
# epoch: 440	train_loss: 0.02098	dev_loss: 0.02096	eltime:  7.78035
# epoch: 450	train_loss: 0.02079	dev_loss: 0.02077	eltime:  7.94925
# epoch: 460	train_loss: 0.02061	dev_loss: 0.02060	eltime:  8.11654
# epoch: 470	train_loss: 0.02045	dev_loss: 0.02043	eltime:  8.28597
# epoch: 480	train_loss: 0.02030	dev_loss: 0.02028	eltime:  8.45907
# epoch: 490	train_loss: 0.02015	dev_loss: 0.02014	eltime:  8.62879
# epoch: 500	train_loss: 0.02001	dev_loss: 0.02000	eltime:  8.79475
# epoch: 510	train_loss: 0.01988	dev_loss: 0.01987	eltime:  8.95579
# epoch: 520	train_loss: 0.01975	dev_loss: 0.01974	eltime:  9.15136
# epoch: 530	train_loss: 0.01963	dev_loss: 0.01962	eltime:  9.32108
# epoch: 540	train_loss: 0.01952	dev_loss: 0.01951	eltime:  9.49621
# epoch: 550	train_loss: 0.01940	dev_loss: 0.01939	eltime:  9.68807
# epoch: 560	train_loss: 0.01929	dev_loss: 0.01928	eltime:  9.86319
# epoch: 570	train_loss: 0.01919	dev_loss: 0.01918	eltime:  10.08629
# epoch: 580	train_loss: 0.01909	dev_loss: 0.01907	eltime:  10.27820
# epoch: 590	train_loss: 0.01898	dev_loss: 0.01897	eltime:  10.46503
# epoch: 600	train_loss: 0.01888	dev_loss: 0.01888	eltime:  10.63712
# epoch: 610	train_loss: 0.01879	dev_loss: 0.01878	eltime:  10.80668
# epoch: 620	train_loss: 0.01869	dev_loss: 0.01868	eltime:  10.98009
# epoch: 630	train_loss: 0.01860	dev_loss: 0.01859	eltime:  11.15871
# epoch: 640	train_loss: 0.01851	dev_loss: 0.01850	eltime:  11.33955
# epoch: 650	train_loss: 0.01842	dev_loss: 0.01841	eltime:  11.55829
# epoch: 660	train_loss: 0.01833	dev_loss: 0.01832	eltime:  11.77228
# epoch: 670	train_loss: 0.01824	dev_loss: 0.01823	eltime:  11.97573
# epoch: 680	train_loss: 0.01815	dev_loss: 0.01814	eltime:  12.18331
# epoch: 690	train_loss: 0.01806	dev_loss: 0.01805	eltime:  12.38725
# epoch: 700	train_loss: 0.01798	dev_loss: 0.01797	eltime:  12.60488
# epoch: 710	train_loss: 0.01789	dev_loss: 0.01788	eltime:  12.79278
# epoch: 720	train_loss: 0.01781	dev_loss: 0.01780	eltime:  13.00534
# epoch: 730	train_loss: 0.01772	dev_loss: 0.01772	eltime:  13.18938
# epoch: 740	train_loss: 0.01764	dev_loss: 0.01763	eltime:  13.36039
# epoch: 750	train_loss: 0.01756	dev_loss: 0.01755	eltime:  13.55055
# epoch: 760	train_loss: 0.01748	dev_loss: 0.01747	eltime:  13.74661
# epoch: 770	train_loss: 0.01740	dev_loss: 0.01739	eltime:  14.00831
# epoch: 780	train_loss: 0.01732	dev_loss: 0.01731	eltime:  14.22788
# epoch: 790	train_loss: 0.01724	dev_loss: 0.01723	eltime:  14.46644
# epoch: 800	train_loss: 0.01716	dev_loss: 0.01715	eltime:  14.69275
# epoch: 810	train_loss: 0.01708	dev_loss: 0.01707	eltime:  14.98875
# epoch: 820	train_loss: 0.01700	dev_loss: 0.01699	eltime:  15.35699
# epoch: 830	train_loss: 0.01692	dev_loss: 0.01691	eltime:  15.72297
# epoch: 840	train_loss: 0.01684	dev_loss: 0.01683	eltime:  16.11137
# epoch: 850	train_loss: 0.01676	dev_loss: 0.01676	eltime:  16.53914
# epoch: 860	train_loss: 0.01669	dev_loss: 0.01668	eltime:  16.95360
# epoch: 870	train_loss: 0.01661	dev_loss: 0.01660	eltime:  17.34486
# epoch: 880	train_loss: 0.01653	dev_loss: 0.01652	eltime:  17.75932
# epoch: 890	train_loss: 0.01646	dev_loss: 0.01645	eltime:  18.19261
# epoch: 900	train_loss: 0.01638	dev_loss: 0.01637	eltime:  18.60681
# epoch: 910	train_loss: 0.01630	dev_loss: 0.01630	eltime:  19.00501
# epoch: 920	train_loss: 0.01623	dev_loss: 0.01622	eltime:  19.38271
# epoch: 930	train_loss: 0.01615	dev_loss: 0.01614	eltime:  19.76855
# epoch: 940	train_loss: 0.01608	dev_loss: 0.01607	eltime:  20.13081
# epoch: 950	train_loss: 0.01600	dev_loss: 0.01599	eltime:  20.51541
# epoch: 960	train_loss: 0.01593	dev_loss: 0.01592	eltime:  20.89855
# epoch: 970	train_loss: 0.01585	dev_loss: 0.01584	eltime:  21.28797
# epoch: 980	train_loss: 0.01578	dev_loss: 0.01577	eltime:  21.67828
# epoch: 990	train_loss: 0.01570	dev_loss: 0.01570	eltime:  22.11174
# epoch: 1000	train_loss: 0.01563	dev_loss: 0.01562	eltime:  22.54451
# epoch: 1010	train_loss: 0.01555	dev_loss: 0.01555	eltime:  22.96549
# epoch: 1020	train_loss: 0.01548	dev_loss: 0.01547	eltime:  23.35967
# epoch: 1030	train_loss: 0.01541	dev_loss: 0.01540	eltime:  23.74527
# epoch: 1040	train_loss: 0.01533	dev_loss: 0.01533	eltime:  24.15390
# epoch: 1050	train_loss: 0.01526	dev_loss: 0.01525	eltime:  24.56264
# epoch: 1060	train_loss: 0.01519	dev_loss: 0.01518	eltime:  24.94505
# epoch: 1070	train_loss: 0.01511	dev_loss: 0.01511	eltime:  25.31382
# epoch: 1080	train_loss: 0.01504	dev_loss: 0.01503	eltime:  25.66928
# epoch: 1090	train_loss: 0.01497	dev_loss: 0.01496	eltime:  26.01567
# epoch: 1100	train_loss: 0.01490	dev_loss: 0.01489	eltime:  26.38496
# epoch: 1110	train_loss: 0.01482	dev_loss: 0.01482	eltime:  26.73140
# epoch: 1120	train_loss: 0.01475	dev_loss: 0.01475	eltime:  27.08778
# epoch: 1130	train_loss: 0.01468	dev_loss: 0.01467	eltime:  27.44938
# epoch: 1140	train_loss: 0.01461	dev_loss: 0.01460	eltime:  27.80927
# epoch: 1150	train_loss: 0.01454	dev_loss: 0.01453	eltime:  28.17253
# epoch: 1160	train_loss: 0.01447	dev_loss: 0.01446	eltime:  28.53515
# epoch: 1170	train_loss: 0.01439	dev_loss: 0.01439	eltime:  28.90605
# epoch: 1180	train_loss: 0.01432	dev_loss: 0.01432	eltime:  29.26349
# epoch: 1190	train_loss: 0.01425	dev_loss: 0.01425	eltime:  29.59232
# epoch: 1200	train_loss: 0.01418	dev_loss: 0.01417	eltime:  29.75972
# epoch: 1210	train_loss: 0.01411	dev_loss: 0.01410	eltime:  29.94030
# epoch: 1220	train_loss: 0.01404	dev_loss: 0.01403	eltime:  30.11530
# epoch: 1230	train_loss: 0.01397	dev_loss: 0.01396	eltime:  30.29355
# epoch: 1240	train_loss: 0.01390	dev_loss: 0.01389	eltime:  30.46072
# epoch: 1250	train_loss: 0.01383	dev_loss: 0.01382	eltime:  30.62293
# epoch: 1260	train_loss: 0.01376	dev_loss: 0.01375	eltime:  30.79210
# epoch: 1270	train_loss: 0.01369	dev_loss: 0.01368	eltime:  30.95172
# epoch: 1280	train_loss: 0.01362	dev_loss: 0.01361	eltime:  31.11185
# epoch: 1290	train_loss: 0.01355	dev_loss: 0.01354	eltime:  31.27736
# epoch: 1300	train_loss: 0.01348	dev_loss: 0.01347	eltime:  31.44695
# epoch: 1310	train_loss: 0.01341	dev_loss: 0.01341	eltime:  31.61552
# epoch: 1320	train_loss: 0.01334	dev_loss: 0.01334	eltime:  31.79316
# epoch: 1330	train_loss: 0.01327	dev_loss: 0.01327	eltime:  31.96217
# epoch: 1340	train_loss: 0.01321	dev_loss: 0.01320	eltime:  32.12876
# epoch: 1350	train_loss: 0.01314	dev_loss: 0.01313	eltime:  32.30879
# epoch: 1360	train_loss: 0.01307	dev_loss: 0.01306	eltime:  32.50665
# epoch: 1370	train_loss: 0.01300	dev_loss: 0.01299	eltime:  32.66936
# epoch: 1380	train_loss: 0.01293	dev_loss: 0.01293	eltime:  32.86168
# epoch: 1390	train_loss: 0.01287	dev_loss: 0.01286	eltime:  33.02538
# epoch: 1400	train_loss: 0.01280	dev_loss: 0.01279	eltime:  33.18889
# epoch: 1410	train_loss: 0.01273	dev_loss: 0.01272	eltime:  33.37046
# epoch: 1420	train_loss: 0.01266	dev_loss: 0.01266	eltime:  33.54496
# epoch: 1430	train_loss: 0.01260	dev_loss: 0.01259	eltime:  33.72546
# epoch: 1440	train_loss: 0.01253	dev_loss: 0.01252	eltime:  33.90116
# epoch: 1450	train_loss: 0.01246	dev_loss: 0.01246	eltime:  34.07853
# epoch: 1460	train_loss: 0.01240	dev_loss: 0.01239	eltime:  34.25219
# epoch: 1470	train_loss: 0.01233	dev_loss: 0.01232	eltime:  34.42816
# epoch: 1480	train_loss: 0.01227	dev_loss: 0.01226	eltime:  34.59825
# epoch: 1490	train_loss: 0.01220	dev_loss: 0.01219	eltime:  34.77003
# epoch: 1500	train_loss: 0.01213	dev_loss: 0.01213	eltime:  34.93932
# epoch: 1510	train_loss: 0.01207	dev_loss: 0.01206	eltime:  35.09881
# epoch: 1520	train_loss: 0.01200	dev_loss: 0.01200	eltime:  35.27282
# epoch: 1530	train_loss: 0.01194	dev_loss: 0.01193	eltime:  35.44078
# epoch: 1540	train_loss: 0.01187	dev_loss: 0.01187	eltime:  35.60332
# epoch: 1550	train_loss: 0.01181	dev_loss: 0.01180	eltime:  35.76806
# epoch: 1560	train_loss: 0.01174	dev_loss: 0.01174	eltime:  35.93428
# epoch: 1570	train_loss: 0.01168	dev_loss: 0.01167	eltime:  36.11186
# epoch: 1580	train_loss: 0.01162	dev_loss: 0.01161	eltime:  36.29064
# epoch: 1590	train_loss: 0.01155	dev_loss: 0.01155	eltime:  36.46503
# epoch: 1600	train_loss: 0.01149	dev_loss: 0.01148	eltime:  36.64123
# epoch: 1610	train_loss: 0.01143	dev_loss: 0.01142	eltime:  36.80056
# epoch: 1620	train_loss: 0.01136	dev_loss: 0.01136	eltime:  36.96628
# epoch: 1630	train_loss: 0.01130	dev_loss: 0.01129	eltime:  37.14241
# epoch: 1640	train_loss: 0.01124	dev_loss: 0.01123	eltime:  37.30638
# epoch: 1650	train_loss: 0.01117	dev_loss: 0.01117	eltime:  37.64564
# epoch: 1660	train_loss: 0.01111	dev_loss: 0.01110	eltime:  38.07703
# epoch: 1670	train_loss: 0.01105	dev_loss: 0.01104	eltime:  38.52376
# epoch: 1680	train_loss: 0.01099	dev_loss: 0.01098	eltime:  39.02791
# epoch: 1690	train_loss: 0.01092	dev_loss: 0.01092	eltime:  39.43663
# epoch: 1700	train_loss: 0.01086	dev_loss: 0.01086	eltime:  39.83777
# epoch: 1710	train_loss: 0.01080	dev_loss: 0.01080	eltime:  40.22634
# epoch: 1720	train_loss: 0.01074	dev_loss: 0.01073	eltime:  40.63893
# epoch: 1730	train_loss: 0.01068	dev_loss: 0.01067	eltime:  41.13936
# epoch: 1740	train_loss: 0.01062	dev_loss: 0.01061	eltime:  41.63169
# epoch: 1750	train_loss: 0.01056	dev_loss: 0.01055	eltime:  42.10824
# epoch: 1760	train_loss: 0.01050	dev_loss: 0.01049	eltime:  42.57969
# epoch: 1770	train_loss: 0.01044	dev_loss: 0.01043	eltime:  42.96761
# epoch: 1780	train_loss: 0.01038	dev_loss: 0.01037	eltime:  43.38116
# epoch: 1790	train_loss: 0.01032	dev_loss: 0.01031	eltime:  43.82951
# epoch: 1800	train_loss: 0.01026	dev_loss: 0.01025	eltime:  44.27329
# epoch: 1810	train_loss: 0.01020	dev_loss: 0.01019	eltime:  44.73737
# epoch: 1820	train_loss: 0.01014	dev_loss: 0.01013	eltime:  45.16859
# epoch: 1830	train_loss: 0.01008	dev_loss: 0.01007	eltime:  45.58007
# epoch: 1840	train_loss: 0.01002	dev_loss: 0.01001	eltime:  46.05920
# epoch: 1850	train_loss: 0.00996	dev_loss: 0.00995	eltime:  46.52469
# epoch: 1860	train_loss: 0.00990	dev_loss: 0.00989	eltime:  46.94259
# epoch: 1870	train_loss: 0.00984	dev_loss: 0.00983	eltime:  47.32478
# epoch: 1880	train_loss: 0.00978	dev_loss: 0.00977	eltime:  47.74373
# epoch: 1890	train_loss: 0.00972	dev_loss: 0.00971	eltime:  48.15143
# epoch: 1900	train_loss: 0.00966	dev_loss: 0.00965	eltime:  48.62692
# epoch: 1910	train_loss: 0.00960	dev_loss: 0.00960	eltime:  49.09715
# epoch: 1920	train_loss: 0.00954	dev_loss: 0.00954	eltime:  49.51626
# epoch: 1930	train_loss: 0.00948	dev_loss: 0.00948	eltime:  49.94042
# epoch: 1940	train_loss: 0.00943	dev_loss: 0.00942	eltime:  50.34148
# epoch: 1950	train_loss: 0.00937	dev_loss: 0.00936	eltime:  50.74840
# epoch: 1960	train_loss: 0.00931	dev_loss: 0.00930	eltime:  51.14690
# epoch: 1970	train_loss: 0.00925	dev_loss: 0.00925	eltime:  51.58593
# epoch: 1980	train_loss: 0.00919	dev_loss: 0.00919	eltime:  51.96464
# epoch: 1990	train_loss: 0.00914	dev_loss: 0.00913	eltime:  52.40364
# epoch: 2000	train_loss: 0.00908	dev_loss: 0.00907	eltime:  52.82970
# epoch: 2010	train_loss: 0.00902	dev_loss: 0.00902	eltime:  53.27423
# epoch: 2020	train_loss: 0.00897	dev_loss: 0.00896	eltime:  53.72989
# epoch: 2030	train_loss: 0.00891	dev_loss: 0.00891	eltime:  54.18388
# epoch: 2040	train_loss: 0.00885	dev_loss: 0.00885	eltime:  54.62423
# epoch: 2050	train_loss: 0.00880	dev_loss: 0.00879	eltime:  55.09546
# epoch: 2060	train_loss: 0.00874	dev_loss: 0.00874	eltime:  55.52478
# epoch: 2070	train_loss: 0.00869	dev_loss: 0.00868	eltime:  55.96327
# epoch: 2080	train_loss: 0.00863	dev_loss: 0.00863	eltime:  56.41340
# epoch: 2090	train_loss: 0.00858	dev_loss: 0.00857	eltime:  56.92754
# epoch: 2100	train_loss: 0.00853	dev_loss: 0.00852	eltime:  57.42018
# epoch: 2110	train_loss: 0.00847	dev_loss: 0.00847	eltime:  57.87907
# epoch: 2120	train_loss: 0.00842	dev_loss: 0.00841	eltime:  58.27850
# epoch: 2130	train_loss: 0.00837	dev_loss: 0.00836	eltime:  58.73470
# epoch: 2140	train_loss: 0.00831	dev_loss: 0.00831	eltime:  59.19946
# epoch: 2150	train_loss: 0.00826	dev_loss: 0.00826	eltime:  59.60343
# epoch: 2160	train_loss: 0.00821	dev_loss: 0.00820	eltime:  60.04248
# epoch: 2170	train_loss: 0.00816	dev_loss: 0.00815	eltime:  60.50199
# epoch: 2180	train_loss: 0.00811	dev_loss: 0.00810	eltime:  60.97405
# epoch: 2190	train_loss: 0.00805	dev_loss: 0.00805	eltime:  61.50404
# epoch: 2200	train_loss: 0.00800	dev_loss: 0.00800	eltime:  61.90424
# epoch: 2210	train_loss: 0.00795	dev_loss: 0.00795	eltime:  62.34858
# epoch: 2220	train_loss: 0.00790	dev_loss: 0.00790	eltime:  62.74396
# epoch: 2230	train_loss: 0.00785	dev_loss: 0.00785	eltime:  63.18256
# epoch: 2240	train_loss: 0.00780	dev_loss: 0.00780	eltime:  63.64527
# epoch: 2250	train_loss: 0.00776	dev_loss: 0.00775	eltime:  64.19473
# epoch: 2260	train_loss: 0.00771	dev_loss: 0.00770	eltime:  64.67165
# epoch: 2270	train_loss: 0.00766	dev_loss: 0.00765	eltime:  65.14776
# epoch: 2280	train_loss: 0.00761	dev_loss: 0.00761	eltime:  65.58594
# epoch: 2290	train_loss: 0.00756	dev_loss: 0.00756	eltime:  66.00126
# epoch: 2300	train_loss: 0.00752	dev_loss: 0.00751	eltime:  66.44289
# epoch: 2310	train_loss: 0.00747	dev_loss: 0.00746	eltime:  66.82415
# epoch: 2320	train_loss: 0.00742	dev_loss: 0.00742	eltime:  67.22639
# epoch: 2330	train_loss: 0.00737	dev_loss: 0.00737	eltime:  67.60451
# epoch: 2340	train_loss: 0.00733	dev_loss: 0.00732	eltime:  68.00232
# epoch: 2350	train_loss: 0.00728	dev_loss: 0.00728	eltime:  68.43925
# epoch: 2360	train_loss: 0.00724	dev_loss: 0.00723	eltime:  68.94288
# epoch: 2370	train_loss: 0.00719	dev_loss: 0.00719	eltime:  69.38945
# epoch: 2380	train_loss: 0.00715	dev_loss: 0.00714	eltime:  69.79612
# epoch: 2390	train_loss: 0.00710	dev_loss: 0.00710	eltime:  70.21453
# epoch: 2400	train_loss: 0.00706	dev_loss: 0.00705	eltime:  70.64358
# epoch: 2410	train_loss: 0.00701	dev_loss: 0.00701	eltime:  71.03631
# epoch: 2420	train_loss: 0.00697	dev_loss: 0.00697	eltime:  71.48711
# epoch: 2430	train_loss: 0.00693	dev_loss: 0.00692	eltime:  71.94398
# epoch: 2440	train_loss: 0.00688	dev_loss: 0.00688	eltime:  72.34514
# epoch: 2450	train_loss: 0.00684	dev_loss: 0.00684	eltime:  72.52315
# epoch: 2460	train_loss: 0.00680	dev_loss: 0.00679	eltime:  72.70464
# epoch: 2470	train_loss: 0.00675	dev_loss: 0.00675	eltime:  72.90356
# epoch: 2480	train_loss: 0.00671	dev_loss: 0.00671	eltime:  73.08835
# epoch: 2490	train_loss: 0.00667	dev_loss: 0.00667	eltime:  73.26566
# epoch: 2500	train_loss: 0.00663	dev_loss: 0.00662	eltime:  73.45970
# epoch: 2510	train_loss: 0.00659	dev_loss: 0.00658	eltime:  73.63187
# epoch: 2520	train_loss: 0.00655	dev_loss: 0.00654	eltime:  73.80185
# epoch: 2530	train_loss: 0.00651	dev_loss: 0.00650	eltime:  73.97940
# epoch: 2540	train_loss: 0.00647	dev_loss: 0.00646	eltime:  74.15590
# epoch: 2550	train_loss: 0.00643	dev_loss: 0.00642	eltime:  74.32098
# epoch: 2560	train_loss: 0.00639	dev_loss: 0.00638	eltime:  74.50008
# epoch: 2570	train_loss: 0.00635	dev_loss: 0.00634	eltime:  74.68035
# epoch: 2580	train_loss: 0.00631	dev_loss: 0.00630	eltime:  74.86823
# epoch: 2590	train_loss: 0.00627	dev_loss: 0.00626	eltime:  75.05115
# epoch: 2600	train_loss: 0.00623	dev_loss: 0.00622	eltime:  75.23065
# epoch: 2610	train_loss: 0.00619	dev_loss: 0.00619	eltime:  75.40085
# epoch: 2620	train_loss: 0.00615	dev_loss: 0.00615	eltime:  75.56735
# epoch: 2630	train_loss: 0.00611	dev_loss: 0.00611	eltime:  75.74515
# epoch: 2640	train_loss: 0.00608	dev_loss: 0.00607	eltime:  75.91697
# epoch: 2650	train_loss: 0.00604	dev_loss: 0.00603	eltime:  76.09103
# epoch: 2660	train_loss: 0.00600	dev_loss: 0.00600	eltime:  76.26237
# epoch: 2670	train_loss: 0.00596	dev_loss: 0.00596	eltime:  76.43161
# epoch: 2680	train_loss: 0.00593	dev_loss: 0.00592	eltime:  76.60435
# epoch: 2690	train_loss: 0.00589	dev_loss: 0.00589	eltime:  76.78700
# epoch: 2700	train_loss: 0.00585	dev_loss: 0.00585	eltime:  76.96128
# epoch: 2710	train_loss: 0.00582	dev_loss: 0.00581	eltime:  77.12296
# epoch: 2720	train_loss: 0.00578	dev_loss: 0.00578	eltime:  77.30252
# epoch: 2730	train_loss: 0.00575	dev_loss: 0.00574	eltime:  77.47194
# epoch: 2740	train_loss: 0.00571	dev_loss: 0.00571	eltime:  77.65745
# epoch: 2750	train_loss: 0.00568	dev_loss: 0.00567	eltime:  77.83037
# epoch: 2760	train_loss: 0.00564	dev_loss: 0.00564	eltime:  78.01312
# epoch: 2770	train_loss: 0.00561	dev_loss: 0.00560	eltime:  78.19217
# epoch: 2780	train_loss: 0.00557	dev_loss: 0.00557	eltime:  78.45335
# epoch: 2790	train_loss: 0.00554	dev_loss: 0.00553	eltime:  78.82514
# epoch: 2800	train_loss: 0.00550	dev_loss: 0.00550	eltime:  79.28140
# epoch: 2810	train_loss: 0.00547	dev_loss: 0.00547	eltime:  79.76664
# epoch: 2820	train_loss: 0.00544	dev_loss: 0.00543	eltime:  80.25748
# epoch: 2830	train_loss: 0.00540	dev_loss: 0.00540	eltime:  80.66394
# epoch: 2840	train_loss: 0.00537	dev_loss: 0.00537	eltime:  81.05866
# epoch: 2850	train_loss: 0.00534	dev_loss: 0.00534	eltime:  81.57163
# epoch: 2860	train_loss: 0.00531	dev_loss: 0.00530	eltime:  82.03115
# epoch: 2870	train_loss: 0.00527	dev_loss: 0.00527	eltime:  82.46772
# epoch: 2880	train_loss: 0.00524	dev_loss: 0.00524	eltime:  82.90919
# epoch: 2890	train_loss: 0.00521	dev_loss: 0.00521	eltime:  83.40626
# epoch: 2900	train_loss: 0.00518	dev_loss: 0.00517	eltime:  83.81859
# epoch: 2910	train_loss: 0.00515	dev_loss: 0.00514	eltime:  84.30477
# epoch: 2920	train_loss: 0.00512	dev_loss: 0.00511	eltime:  84.69998
# epoch: 2930	train_loss: 0.00508	dev_loss: 0.00508	eltime:  85.09084
# epoch: 2940	train_loss: 0.00505	dev_loss: 0.00505	eltime:  85.46629
# epoch: 2950	train_loss: 0.00502	dev_loss: 0.00502	eltime:  85.84476
# epoch: 2960	train_loss: 0.00499	dev_loss: 0.00499	eltime:  86.25453
# epoch: 2970	train_loss: 0.00496	dev_loss: 0.00496	eltime:  86.70581
# epoch: 2980	train_loss: 0.00493	dev_loss: 0.00493	eltime:  87.17390
# epoch: 2990	train_loss: 0.00490	dev_loss: 0.00490	eltime:  87.61463
# epoch: 3000	train_loss: 0.00487	dev_loss: 0.00487	eltime:  88.03257
# epoch: 3010	train_loss: 0.00484	dev_loss: 0.00484	eltime:  88.42976
# epoch: 3020	train_loss: 0.00482	dev_loss: 0.00481	eltime:  88.80618
# epoch: 3030	train_loss: 0.00479	dev_loss: 0.00478	eltime:  89.18535
# epoch: 3040	train_loss: 0.00476	dev_loss: 0.00475	eltime:  89.46045
# epoch: 3050	train_loss: 0.00473	dev_loss: 0.00473	eltime:  89.63469
# epoch: 3060	train_loss: 0.00470	dev_loss: 0.00470	eltime:  89.81675
# epoch: 3070	train_loss: 0.00467	dev_loss: 0.00467	eltime:  90.01020
# epoch: 3080	train_loss: 0.00464	dev_loss: 0.00464	eltime:  90.18953
# epoch: 3090	train_loss: 0.00462	dev_loss: 0.00461	eltime:  90.37844
# epoch: 3100	train_loss: 0.00459	dev_loss: 0.00459	eltime:  90.55054
# epoch: 3110	train_loss: 0.00456	dev_loss: 0.00456	eltime:  90.72316
# epoch: 3120	train_loss: 0.00453	dev_loss: 0.00453	eltime:  90.88958
# epoch: 3130	train_loss: 0.00451	dev_loss: 0.00451	eltime:  91.05578
# epoch: 3140	train_loss: 0.00448	dev_loss: 0.00448	eltime:  91.23045
# epoch: 3150	train_loss: 0.00445	dev_loss: 0.00445	eltime:  91.41430
# epoch: 3160	train_loss: 0.00443	dev_loss: 0.00443	eltime:  91.62438
# epoch: 3170	train_loss: 0.00440	dev_loss: 0.00440	eltime:  91.89589
# epoch: 3180	train_loss: 0.00438	dev_loss: 0.00437	eltime:  92.16986
# epoch: 3190	train_loss: 0.00435	dev_loss: 0.00435	eltime:  92.38317
# epoch: 3200	train_loss: 0.00432	dev_loss: 0.00432	eltime:  92.56107
# epoch: 3210	train_loss: 0.00430	dev_loss: 0.00430	eltime:  92.73282
# epoch: 3220	train_loss: 0.00427	dev_loss: 0.00427	eltime:  92.89809
# epoch: 3230	train_loss: 0.00425	dev_loss: 0.00425	eltime:  93.06536
# epoch: 3240	train_loss: 0.00422	dev_loss: 0.00422	eltime:  93.23591
# epoch: 3250	train_loss: 0.00420	dev_loss: 0.00420	eltime:  93.41636
# epoch: 3260	train_loss: 0.00417	dev_loss: 0.00417	eltime:  93.59916
# epoch: 3270	train_loss: 0.00415	dev_loss: 0.00415	eltime:  93.78832
# epoch: 3280	train_loss: 0.00412	dev_loss: 0.00412	eltime:  93.96249
# epoch: 3290	train_loss: 0.00410	dev_loss: 0.00410	eltime:  94.14343
# epoch: 3300	train_loss: 0.00408	dev_loss: 0.00407	eltime:  94.31946
# epoch: 3310	train_loss: 0.00405	dev_loss: 0.00405	eltime:  94.49919
# epoch: 3320	train_loss: 0.00403	dev_loss: 0.00403	eltime:  94.69648
# epoch: 3330	train_loss: 0.00401	dev_loss: 0.00400	eltime:  94.87365
# epoch: 3340	train_loss: 0.00398	dev_loss: 0.00398	eltime:  95.11162
# epoch: 3350	train_loss: 0.00396	dev_loss: 0.00396	eltime:  95.31215
# epoch: 3360	train_loss: 0.00394	dev_loss: 0.00393	eltime:  95.50196
# epoch: 3370	train_loss: 0.00391	dev_loss: 0.00391	eltime:  95.72475
# epoch: 3380	train_loss: 0.00389	dev_loss: 0.00389	eltime:  95.91710
# epoch: 3390	train_loss: 0.00387	dev_loss: 0.00387	eltime:  96.12647
# epoch: 3400	train_loss: 0.00385	dev_loss: 0.00384	eltime:  96.32358
# epoch: 3410	train_loss: 0.00382	dev_loss: 0.00382	eltime:  96.49907
# epoch: 3420	train_loss: 0.00380	dev_loss: 0.00380	eltime:  96.66450
# epoch: 3430	train_loss: 0.00378	dev_loss: 0.00378	eltime:  96.83719
# epoch: 3440	train_loss: 0.00376	dev_loss: 0.00376	eltime:  97.01355
# epoch: 3450	train_loss: 0.00374	dev_loss: 0.00373	eltime:  97.17768
# epoch: 3460	train_loss: 0.00371	dev_loss: 0.00371	eltime:  97.34746
# epoch: 3470	train_loss: 0.00369	dev_loss: 0.00369	eltime:  97.52076
# epoch: 3480	train_loss: 0.00367	dev_loss: 0.00367	eltime:  97.71724
# epoch: 3490	train_loss: 0.00365	dev_loss: 0.00365	eltime:  97.89425
# epoch: 3500	train_loss: 0.00363	dev_loss: 0.00363	eltime:  98.08445
# epoch: 3510	train_loss: 0.00361	dev_loss: 0.00361	eltime:  98.29300
# epoch: 3520	train_loss: 0.00359	dev_loss: 0.00359	eltime:  98.49877
# epoch: 3530	train_loss: 0.00357	dev_loss: 0.00357	eltime:  98.69532
# epoch: 3540	train_loss: 0.00355	dev_loss: 0.00355	eltime:  98.87564
# epoch: 3550	train_loss: 0.00353	dev_loss: 0.00353	eltime:  99.06693
# epoch: 3560	train_loss: 0.00351	dev_loss: 0.00351	eltime:  99.24986
# epoch: 3570	train_loss: 0.00349	dev_loss: 0.00349	eltime:  99.42890
# epoch: 3580	train_loss: 0.00347	dev_loss: 0.00347	eltime:  99.60924
# epoch: 3590	train_loss: 0.00345	dev_loss: 0.00345	eltime:  99.77986
# epoch: 3600	train_loss: 0.00343	dev_loss: 0.00343	eltime:  99.95973
# epoch: 3610	train_loss: 0.00341	dev_loss: 0.00341	eltime:  100.13333
# epoch: 3620	train_loss: 0.00339	dev_loss: 0.00339	eltime:  100.31556
# epoch: 3630	train_loss: 0.00337	dev_loss: 0.00337	eltime:  100.48693
# epoch: 3640	train_loss: 0.00335	dev_loss: 0.00335	eltime:  100.65529
# epoch: 3650	train_loss: 0.00333	dev_loss: 0.00333	eltime:  100.82591
# epoch: 3660	train_loss: 0.00331	dev_loss: 0.00331	eltime:  101.00326
# epoch: 3670	train_loss: 0.00330	dev_loss: 0.00329	eltime:  101.17834
# epoch: 3680	train_loss: 0.00328	dev_loss: 0.00328	eltime:  101.34512
# epoch: 3690	train_loss: 0.00326	dev_loss: 0.00326	eltime:  101.51635
# epoch: 3700	train_loss: 0.00324	dev_loss: 0.00324	eltime:  101.69610
# epoch: 3710	train_loss: 0.00322	dev_loss: 0.00322	eltime:  101.87709
# epoch: 3720	train_loss: 0.00321	dev_loss: 0.00320	eltime:  102.05742
# epoch: 3730	train_loss: 0.00319	dev_loss: 0.00319	eltime:  102.22858
# epoch: 3740	train_loss: 0.00317	dev_loss: 0.00317	eltime:  102.39370
# epoch: 3750	train_loss: 0.00315	dev_loss: 0.00315	eltime:  102.57414
# epoch: 3760	train_loss: 0.00313	dev_loss: 0.00313	eltime:  102.75832
# epoch: 3770	train_loss: 0.00312	dev_loss: 0.00312	eltime:  102.92899
# epoch: 3780	train_loss: 0.00310	dev_loss: 0.00310	eltime:  103.09634
# epoch: 3790	train_loss: 0.00308	dev_loss: 0.00308	eltime:  103.27299
# epoch: 3800	train_loss: 0.00307	dev_loss: 0.00306	eltime:  103.44912
# epoch: 3810	train_loss: 0.00305	dev_loss: 0.00305	eltime:  103.63124
# epoch: 3820	train_loss: 0.00303	dev_loss: 0.00303	eltime:  103.81074
# epoch: 3830	train_loss: 0.00302	dev_loss: 0.00301	eltime:  104.00551
# epoch: 3840	train_loss: 0.00300	dev_loss: 0.00300	eltime:  104.18153
# epoch: 3850	train_loss: 0.00298	dev_loss: 0.00298	eltime:  104.36057
# epoch: 3860	train_loss: 0.00297	dev_loss: 0.00296	eltime:  104.53867
# epoch: 3870	train_loss: 0.00295	dev_loss: 0.00295	eltime:  104.71454
# epoch: 3880	train_loss: 0.00293	dev_loss: 0.00293	eltime:  104.89085
# epoch: 3890	train_loss: 0.00292	dev_loss: 0.00292	eltime:  105.06673
# epoch: 3900	train_loss: 0.00290	dev_loss: 0.00290	eltime:  105.23536
# epoch: 3910	train_loss: 0.00289	dev_loss: 0.00288	eltime:  105.40216
# epoch: 3920	train_loss: 0.00287	dev_loss: 0.00287	eltime:  105.57854
# epoch: 3930	train_loss: 0.00285	dev_loss: 0.00285	eltime:  105.76050
# epoch: 3940	train_loss: 0.00284	dev_loss: 0.00284	eltime:  105.94599
# epoch: 3950	train_loss: 0.00282	dev_loss: 0.00282	eltime:  106.11890
# epoch: 3960	train_loss: 0.00281	dev_loss: 0.00281	eltime:  106.29084
# epoch: 3970	train_loss: 0.00279	dev_loss: 0.00279	eltime:  106.47295
# epoch: 3980	train_loss: 0.00278	dev_loss: 0.00278	eltime:  106.68960
# epoch: 3990	train_loss: 0.00276	dev_loss: 0.00276	eltime:  106.88117
# epoch: 4000	train_loss: 0.00275	dev_loss: 0.00275	eltime:  107.06158
# epoch: 4010	train_loss: 0.00273	dev_loss: 0.00273	eltime:  107.23348
# epoch: 4020	train_loss: 0.00272	dev_loss: 0.00272	eltime:  107.40472
# epoch: 4030	train_loss: 0.00271	dev_loss: 0.00270	eltime:  107.58958
# epoch: 4040	train_loss: 0.00269	dev_loss: 0.00269	eltime:  107.76757
# epoch: 4050	train_loss: 0.00268	dev_loss: 0.00267	eltime:  107.95227
# epoch: 4060	train_loss: 0.00266	dev_loss: 0.00266	eltime:  108.12704
# epoch: 4070	train_loss: 0.00265	dev_loss: 0.00265	eltime:  108.30944
# epoch: 4080	train_loss: 0.00263	dev_loss: 0.00263	eltime:  108.49073
# epoch: 4090	train_loss: 0.00262	dev_loss: 0.00262	eltime:  108.68240
# epoch: 4100	train_loss: 0.00261	dev_loss: 0.00260	eltime:  108.86149
# epoch: 4110	train_loss: 0.00259	dev_loss: 0.00259	eltime:  109.04551
# epoch: 4120	train_loss: 0.00258	dev_loss: 0.00258	eltime:  109.22281
# epoch: 4130	train_loss: 0.00257	dev_loss: 0.00256	eltime:  109.40443
# epoch: 4140	train_loss: 0.00255	dev_loss: 0.00255	eltime:  109.59172
# epoch: 4150	train_loss: 0.00254	dev_loss: 0.00254	eltime:  109.78432
# epoch: 4160	train_loss: 0.00252	dev_loss: 0.00252	eltime:  109.97710
# epoch: 4170	train_loss: 0.00251	dev_loss: 0.00251	eltime:  110.18101
# epoch: 4180	train_loss: 0.00250	dev_loss: 0.00250	eltime:  110.36885
# epoch: 4190	train_loss: 0.00249	dev_loss: 0.00248	eltime:  110.54557
# epoch: 4200	train_loss: 0.00247	dev_loss: 0.00247	eltime:  110.73534
# epoch: 4210	train_loss: 0.00246	dev_loss: 0.00246	eltime:  110.91709
# epoch: 4220	train_loss: 0.00245	dev_loss: 0.00245	eltime:  111.10441
# epoch: 4230	train_loss: 0.00243	dev_loss: 0.00243	eltime:  111.28122
# epoch: 4240	train_loss: 0.00242	dev_loss: 0.00242	eltime:  111.47851
# epoch: 4250	train_loss: 0.00241	dev_loss: 0.00241	eltime:  111.67415
# epoch: 4260	train_loss: 0.00240	dev_loss: 0.00240	eltime:  111.85509
# epoch: 4270	train_loss: 0.00238	dev_loss: 0.00238	eltime:  112.03740
# epoch: 4280	train_loss: 0.00237	dev_loss: 0.00237	eltime:  112.21558
# epoch: 4290	train_loss: 0.00236	dev_loss: 0.00236	eltime:  112.40403
# epoch: 4300	train_loss: 0.00235	dev_loss: 0.00235	eltime:  112.59173
# epoch: 4310	train_loss: 0.00234	dev_loss: 0.00233	eltime:  112.77317
# epoch: 4320	train_loss: 0.00232	dev_loss: 0.00232	eltime:  112.96243
# epoch: 4330	train_loss: 0.00231	dev_loss: 0.00231	eltime:  113.14483
# epoch: 4340	train_loss: 0.00230	dev_loss: 0.00230	eltime:  113.35017
# epoch: 4350	train_loss: 0.00229	dev_loss: 0.00229	eltime:  113.54052
# epoch: 4360	train_loss: 0.00228	dev_loss: 0.00228	eltime:  113.72705
# epoch: 4370	train_loss: 0.00227	dev_loss: 0.00226	eltime:  113.91582
# epoch: 4380	train_loss: 0.00225	dev_loss: 0.00225	eltime:  114.10526
# epoch: 4390	train_loss: 0.00224	dev_loss: 0.00224	eltime:  114.29168
# epoch: 4400	train_loss: 0.00223	dev_loss: 0.00223	eltime:  114.47701
# epoch: 4410	train_loss: 0.00222	dev_loss: 0.00222	eltime:  114.67423
# epoch: 4420	train_loss: 0.00221	dev_loss: 0.00221	eltime:  114.86778
# epoch: 4430	train_loss: 0.00220	dev_loss: 0.00220	eltime:  115.06661
# epoch: 4440	train_loss: 0.00219	dev_loss: 0.00219	eltime:  115.24884
# epoch: 4450	train_loss: 0.00218	dev_loss: 0.00218	eltime:  115.44502
# epoch: 4460	train_loss: 0.00217	dev_loss: 0.00216	eltime:  115.63787
# epoch: 4470	train_loss: 0.00216	dev_loss: 0.00215	eltime:  115.83326
# epoch: 4480	train_loss: 0.00214	dev_loss: 0.00214	eltime:  116.03228
# epoch: 4490	train_loss: 0.00213	dev_loss: 0.00213	eltime:  116.21463
# epoch: 4500	train_loss: 0.00212	dev_loss: 0.00212	eltime:  116.38958
# epoch: 4510	train_loss: 0.00211	dev_loss: 0.00211	eltime:  116.56870
# epoch: 4520	train_loss: 0.00210	dev_loss: 0.00210	eltime:  116.74991
# epoch: 4530	train_loss: 0.00209	dev_loss: 0.00209	eltime:  116.92693
# epoch: 4540	train_loss: 0.00208	dev_loss: 0.00208	eltime:  117.10928
# epoch: 4550	train_loss: 0.00207	dev_loss: 0.00207	eltime:  117.28177
# epoch: 4560	train_loss: 0.00206	dev_loss: 0.00206	eltime:  117.45613
# epoch: 4570	train_loss: 0.00205	dev_loss: 0.00205	eltime:  117.63127
# epoch: 4580	train_loss: 0.00204	dev_loss: 0.00204	eltime:  117.82198
# epoch: 4590	train_loss: 0.00203	dev_loss: 0.00203	eltime:  118.03961
# epoch: 4600	train_loss: 0.00202	dev_loss: 0.00202	eltime:  118.24480
# epoch: 4610	train_loss: 0.00201	dev_loss: 0.00201	eltime:  118.42455
# epoch: 4620	train_loss: 0.00200	dev_loss: 0.00200	eltime:  118.61865
# epoch: 4630	train_loss: 0.00199	dev_loss: 0.00199	eltime:  118.81055
# epoch: 4640	train_loss: 0.00198	dev_loss: 0.00198	eltime:  118.99192
# epoch: 4650	train_loss: 0.00197	dev_loss: 0.00197	eltime:  119.14738
# epoch: 4660	train_loss: 0.00196	dev_loss: 0.00196	eltime:  119.30786
# epoch: 4670	train_loss: 0.00196	dev_loss: 0.00195	eltime:  119.47125
# epoch: 4680	train_loss: 0.00195	dev_loss: 0.00194	eltime:  119.63680
# epoch: 4690	train_loss: 0.00194	dev_loss: 0.00194	eltime:  119.79023
# epoch: 4700	train_loss: 0.00193	dev_loss: 0.00193	eltime:  119.94803
# epoch: 4710	train_loss: 0.00192	dev_loss: 0.00192	eltime:  120.10444
# epoch: 4720	train_loss: 0.00191	dev_loss: 0.00191	eltime:  120.26214
# epoch: 4730	train_loss: 0.00190	dev_loss: 0.00190	eltime:  120.41904
# epoch: 4740	train_loss: 0.00189	dev_loss: 0.00189	eltime:  120.58928
# epoch: 4750	train_loss: 0.00188	dev_loss: 0.00188	eltime:  120.75198
# epoch: 4760	train_loss: 0.00187	dev_loss: 0.00187	eltime:  120.90851
# epoch: 4770	train_loss: 0.00186	dev_loss: 0.00186	eltime:  121.05135
# epoch: 4780	train_loss: 0.00186	dev_loss: 0.00186	eltime:  121.20719
# epoch: 4790	train_loss: 0.00185	dev_loss: 0.00185	eltime:  121.35376
# epoch: 4800	train_loss: 0.00184	dev_loss: 0.00184	eltime:  121.52497
# epoch: 4810	train_loss: 0.00183	dev_loss: 0.00183	eltime:  121.67847
# epoch: 4820	train_loss: 0.00182	dev_loss: 0.00182	eltime:  121.83327
# epoch: 4830	train_loss: 0.00181	dev_loss: 0.00181	eltime:  121.98438
# epoch: 4840	train_loss: 0.00180	dev_loss: 0.00180	eltime:  122.15991
# epoch: 4850	train_loss: 0.00180	dev_loss: 0.00180	eltime:  122.30412
# epoch: 4860	train_loss: 0.00179	dev_loss: 0.00179	eltime:  122.47650
# epoch: 4870	train_loss: 0.00178	dev_loss: 0.00178	eltime:  122.64066
# epoch: 4880	train_loss: 0.00177	dev_loss: 0.00177	eltime:  122.80401
# epoch: 4890	train_loss: 0.00176	dev_loss: 0.00176	eltime:  122.96852
# epoch: 4900	train_loss: 0.00176	dev_loss: 0.00175	eltime:  123.13116
# epoch: 4910	train_loss: 0.00175	dev_loss: 0.00175	eltime:  123.29782
# epoch: 4920	train_loss: 0.00174	dev_loss: 0.00174	eltime:  123.47545
# epoch: 4930	train_loss: 0.00173	dev_loss: 0.00173	eltime:  123.65630
# epoch: 4940	train_loss: 0.00172	dev_loss: 0.00172	eltime:  123.83241
# epoch: 4950	train_loss: 0.00172	dev_loss: 0.00172	eltime:  123.98654
# epoch: 4960	train_loss: 0.00171	dev_loss: 0.00171	eltime:  124.15263
# epoch: 4970	train_loss: 0.00170	dev_loss: 0.00170	eltime:  124.32603
# epoch: 4980	train_loss: 0.00169	dev_loss: 0.00169	eltime:  124.49685
# epoch: 4990	train_loss: 0.00169	dev_loss: 0.00168	eltime:  124.68260
# epoch: 5000	train_loss: 0.00168	dev_loss: 0.00168	eltime:  124.85274
# epoch: 5010	train_loss: 0.00167	dev_loss: 0.00167	eltime:  125.04480
# epoch: 5020	train_loss: 0.00166	dev_loss: 0.00166	eltime:  125.22353
# epoch: 5030	train_loss: 0.00166	dev_loss: 0.00165	eltime:  125.39227
# epoch: 5040	train_loss: 0.00165	dev_loss: 0.00165	eltime:  125.58203
# epoch: 5050	train_loss: 0.00164	dev_loss: 0.00164	eltime:  125.74781
# epoch: 5060	train_loss: 0.00163	dev_loss: 0.00163	eltime:  125.91844
# epoch: 5070	train_loss: 0.00163	dev_loss: 0.00163	eltime:  126.09430
# epoch: 5080	train_loss: 0.00162	dev_loss: 0.00162	eltime:  126.27378
# epoch: 5090	train_loss: 0.00161	dev_loss: 0.00161	eltime:  126.45092
# epoch: 5100	train_loss: 0.00161	dev_loss: 0.00160	eltime:  126.63835
# epoch: 5110	train_loss: 0.00160	dev_loss: 0.00160	eltime:  126.82607
# epoch: 5120	train_loss: 0.00159	dev_loss: 0.00159	eltime:  127.02302
# epoch: 5130	train_loss: 0.00158	dev_loss: 0.00158	eltime:  127.18208
# epoch: 5140	train_loss: 0.00158	dev_loss: 0.00158	eltime:  127.37419
# epoch: 5150	train_loss: 0.00157	dev_loss: 0.00157	eltime:  127.55176
# epoch: 5160	train_loss: 0.00156	dev_loss: 0.00156	eltime:  127.72938
# epoch: 5170	train_loss: 0.00156	dev_loss: 0.00156	eltime:  127.91716
# epoch: 5180	train_loss: 0.00155	dev_loss: 0.00155	eltime:  128.11500
# epoch: 5190	train_loss: 0.00154	dev_loss: 0.00154	eltime:  128.30017
# epoch: 5200	train_loss: 0.00154	dev_loss: 0.00154	eltime:  128.49004
# epoch: 5210	train_loss: 0.00153	dev_loss: 0.00153	eltime:  128.67648
# epoch: 5220	train_loss: 0.00152	dev_loss: 0.00152	eltime:  128.85393
# epoch: 5230	train_loss: 0.00152	dev_loss: 0.00152	eltime:  129.03002
# epoch: 5240	train_loss: 0.00151	dev_loss: 0.00151	eltime:  129.20735
# epoch: 5250	train_loss: 0.00150	dev_loss: 0.00150	eltime:  129.37595
# epoch: 5260	train_loss: 0.00150	dev_loss: 0.00150	eltime:  129.54375
# epoch: 5270	train_loss: 0.00149	dev_loss: 0.00149	eltime:  129.71226
# epoch: 5280	train_loss: 0.00148	dev_loss: 0.00148	eltime:  129.92684
# epoch: 5290	train_loss: 0.00148	dev_loss: 0.00148	eltime:  130.12581
# epoch: 5300	train_loss: 0.00147	dev_loss: 0.00147	eltime:  130.37858
# epoch: 5310	train_loss: 0.00147	dev_loss: 0.00147	eltime:  130.62763
# epoch: 5320	train_loss: 0.00146	dev_loss: 0.00146	eltime:  130.88457
# epoch: 5330	train_loss: 0.00145	dev_loss: 0.00145	eltime:  131.13021
# epoch: 5340	train_loss: 0.00145	dev_loss: 0.00145	eltime:  131.33991
# epoch: 5350	train_loss: 0.00144	dev_loss: 0.00144	eltime:  131.56063
# epoch: 5360	train_loss: 0.00144	dev_loss: 0.00143	eltime:  131.77877
# epoch: 5370	train_loss: 0.00143	dev_loss: 0.00143	eltime:  131.99400
# epoch: 5380	train_loss: 0.00142	dev_loss: 0.00142	eltime:  132.25604
# epoch: 5390	train_loss: 0.00142	dev_loss: 0.00142	eltime:  132.48537
# epoch: 5400	train_loss: 0.00141	dev_loss: 0.00141	eltime:  132.72896
# epoch: 5410	train_loss: 0.00141	dev_loss: 0.00141	eltime:  132.97124
# epoch: 5420	train_loss: 0.00140	dev_loss: 0.00140	eltime:  133.15703
# epoch: 5430	train_loss: 0.00139	dev_loss: 0.00139	eltime:  133.34965
# epoch: 5440	train_loss: 0.00139	dev_loss: 0.00139	eltime:  133.53934
# epoch: 5450	train_loss: 0.00138	dev_loss: 0.00138	eltime:  133.72365
# epoch: 5460	train_loss: 0.00138	dev_loss: 0.00138	eltime:  133.90177
# epoch: 5470	train_loss: 0.00137	dev_loss: 0.00137	eltime:  134.07827
# epoch: 5480	train_loss: 0.00137	dev_loss: 0.00137	eltime:  134.25488
# epoch: 5490	train_loss: 0.00136	dev_loss: 0.00136	eltime:  134.44200
# epoch: 5500	train_loss: 0.00135	dev_loss: 0.00135	eltime:  134.62732
# epoch: 5510	train_loss: 0.00135	dev_loss: 0.00135	eltime:  134.80710
# epoch: 5520	train_loss: 0.00134	dev_loss: 0.00134	eltime:  134.98862
# epoch: 5530	train_loss: 0.00134	dev_loss: 0.00134	eltime:  135.17323
# epoch: 5540	train_loss: 0.00133	dev_loss: 0.00133	eltime:  135.35812
# epoch: 5550	train_loss: 0.00133	dev_loss: 0.00133	eltime:  135.53934
# epoch: 5560	train_loss: 0.00132	dev_loss: 0.00132	eltime:  135.71521
# epoch: 5570	train_loss: 0.00132	dev_loss: 0.00132	eltime:  135.88971
# epoch: 5580	train_loss: 0.00131	dev_loss: 0.00131	eltime:  136.06526
# epoch: 5590	train_loss: 0.00131	dev_loss: 0.00131	eltime:  136.24047
# epoch: 5600	train_loss: 0.00130	dev_loss: 0.00130	eltime:  136.41012
# epoch: 5610	train_loss: 0.00130	dev_loss: 0.00129	eltime:  136.58445
# epoch: 5620	train_loss: 0.00129	dev_loss: 0.00129	eltime:  136.75662
# epoch: 5630	train_loss: 0.00128	dev_loss: 0.00128	eltime:  136.93005
# epoch: 5640	train_loss: 0.00128	dev_loss: 0.00128	eltime:  137.10089
# epoch: 5650	train_loss: 0.00127	dev_loss: 0.00127	eltime:  137.28201
# epoch: 5660	train_loss: 0.00127	dev_loss: 0.00127	eltime:  137.45149
# epoch: 5670	train_loss: 0.00126	dev_loss: 0.00126	eltime:  137.63179
# epoch: 5680	train_loss: 0.00126	dev_loss: 0.00126	eltime:  137.80244
# epoch: 5690	train_loss: 0.00125	dev_loss: 0.00125	eltime:  137.97968
# epoch: 5700	train_loss: 0.00125	dev_loss: 0.00125	eltime:  138.14918
# epoch: 5710	train_loss: 0.00124	dev_loss: 0.00124	eltime:  138.32108
# epoch: 5720	train_loss: 0.00124	dev_loss: 0.00124	eltime:  138.49433
# epoch: 5730	train_loss: 0.00123	dev_loss: 0.00123	eltime:  138.66298
# epoch: 5740	train_loss: 0.00123	dev_loss: 0.00123	eltime:  138.83269
# epoch: 5750	train_loss: 0.00122	dev_loss: 0.00122	eltime:  139.00058
# epoch: 5760	train_loss: 0.00122	dev_loss: 0.00122	eltime:  139.17577
# epoch: 5770	train_loss: 0.00121	dev_loss: 0.00121	eltime:  139.34944
# epoch: 5780	train_loss: 0.00121	dev_loss: 0.00121	eltime:  139.51962
# epoch: 5790	train_loss: 0.00120	dev_loss: 0.00120	eltime:  139.69789
# epoch: 5800	train_loss: 0.00120	dev_loss: 0.00120	eltime:  139.86746
# epoch: 5810	train_loss: 0.00119	dev_loss: 0.00119	eltime:  140.03830
# epoch: 5820	train_loss: 0.00119	dev_loss: 0.00119	eltime:  140.20679
# epoch: 5830	train_loss: 0.00118	dev_loss: 0.00118	eltime:  140.37017
# epoch: 5840	train_loss: 0.00118	dev_loss: 0.00118	eltime:  140.54023
# epoch: 5850	train_loss: 0.00118	dev_loss: 0.00117	eltime:  140.70246
# epoch: 5860	train_loss: 0.00117	dev_loss: 0.00117	eltime:  140.86382
# epoch: 5870	train_loss: 0.00117	dev_loss: 0.00117	eltime:  141.02574
# epoch: 5880	train_loss: 0.00116	dev_loss: 0.00116	eltime:  141.19353
# epoch: 5890	train_loss: 0.00116	dev_loss: 0.00116	eltime:  141.36424
# epoch: 5900	train_loss: 0.00115	dev_loss: 0.00115	eltime:  141.53545
# epoch: 5910	train_loss: 0.00115	dev_loss: 0.00115	eltime:  141.71128
# epoch: 5920	train_loss: 0.00114	dev_loss: 0.00114	eltime:  141.87205
# epoch: 5930	train_loss: 0.00114	dev_loss: 0.00114	eltime:  142.03808
# epoch: 5940	train_loss: 0.00113	dev_loss: 0.00113	eltime:  142.20247
# epoch: 5950	train_loss: 0.00113	dev_loss: 0.00113	eltime:  142.36382
# epoch: 5960	train_loss: 0.00112	dev_loss: 0.00112	eltime:  142.53401
# epoch: 5970	train_loss: 0.00112	dev_loss: 0.00112	eltime:  142.69934
# epoch: 5980	train_loss: 0.00111	dev_loss: 0.00111	eltime:  142.87013
# epoch: 5990	train_loss: 0.00111	dev_loss: 0.00111	eltime:  143.05746
# epoch: 6000	train_loss: 0.00111	dev_loss: 0.00111	eltime:  143.24835
# epoch: 6010	train_loss: 0.00110	dev_loss: 0.00110	eltime:  143.43122
# epoch: 6020	train_loss: 0.00110	dev_loss: 0.00110	eltime:  143.60982
# epoch: 6030	train_loss: 0.00109	dev_loss: 0.00109	eltime:  143.80854
# epoch: 6040	train_loss: 0.00109	dev_loss: 0.00109	eltime:  143.98216
# epoch: 6050	train_loss: 0.00108	dev_loss: 0.00108	eltime:  144.15380
# epoch: 6060	train_loss: 0.00108	dev_loss: 0.00108	eltime:  144.33648
# epoch: 6070	train_loss: 0.00107	dev_loss: 0.00107	eltime:  144.50573
# epoch: 6080	train_loss: 0.00107	dev_loss: 0.00107	eltime:  144.66840
# epoch: 6090	train_loss: 0.00107	dev_loss: 0.00107	eltime:  144.83819
# epoch: 6100	train_loss: 0.00106	dev_loss: 0.00106	eltime:  145.00026
# epoch: 6110	train_loss: 0.00106	dev_loss: 0.00106	eltime:  145.17138
# epoch: 6120	train_loss: 0.00105	dev_loss: 0.00105	eltime:  145.33934
# epoch: 6130	train_loss: 0.00105	dev_loss: 0.00105	eltime:  145.50255
# epoch: 6140	train_loss: 0.00104	dev_loss: 0.00104	eltime:  145.66862
# epoch: 6150	train_loss: 0.00104	dev_loss: 0.00104	eltime:  145.82846
# epoch: 6160	train_loss: 0.00104	dev_loss: 0.00103	eltime:  145.99069
# epoch: 6170	train_loss: 0.00103	dev_loss: 0.00103	eltime:  146.16144
# epoch: 6180	train_loss: 0.00103	dev_loss: 0.00103	eltime:  146.32402
# epoch: 6190	train_loss: 0.00102	dev_loss: 0.00102	eltime:  146.48975
# epoch: 6200	train_loss: 0.00102	dev_loss: 0.00102	eltime:  146.66110
# epoch: 6210	train_loss: 0.00101	dev_loss: 0.00101	eltime:  146.83258
# epoch: 6220	train_loss: 0.00101	dev_loss: 0.00101	eltime:  147.00025
# epoch: 6230	train_loss: 0.00101	dev_loss: 0.00100	eltime:  147.16729
# epoch: 6240	train_loss: 0.00100	dev_loss: 0.00100	eltime:  147.33415
# epoch: 6250	train_loss: 0.00100	dev_loss: 0.00100	eltime:  147.50436
# epoch: 6260	train_loss: 0.00099	dev_loss: 0.00099	eltime:  147.67581
# epoch: 6270	train_loss: 0.00099	dev_loss: 0.00099	eltime:  147.83958
# epoch: 6280	train_loss: 0.00098	dev_loss: 0.00098	eltime:  148.00689
# epoch: 6290	train_loss: 0.00098	dev_loss: 0.00098	eltime:  148.18245
# epoch: 6300	train_loss: 0.00098	dev_loss: 0.00098	eltime:  148.36276
# epoch: 6310	train_loss: 0.00097	dev_loss: 0.00097	eltime:  148.53418
# epoch: 6320	train_loss: 0.00097	dev_loss: 0.00097	eltime:  148.70101
# epoch: 6330	train_loss: 0.00096	dev_loss: 0.00096	eltime:  148.87225
# epoch: 6340	train_loss: 0.00096	dev_loss: 0.00096	eltime:  149.03638
# epoch: 6350	train_loss: 0.00095	dev_loss: 0.00095	eltime:  149.20398
# epoch: 6360	train_loss: 0.00095	dev_loss: 0.00095	eltime:  149.36936
# epoch: 6370	train_loss: 0.00095	dev_loss: 0.00095	eltime:  149.52914
# epoch: 6380	train_loss: 0.00094	dev_loss: 0.00094	eltime:  149.69564
# epoch: 6390	train_loss: 0.00094	dev_loss: 0.00094	eltime:  149.86892
# epoch: 6400	train_loss: 0.00093	dev_loss: 0.00093	eltime:  150.04755
# epoch: 6410	train_loss: 0.00093	dev_loss: 0.00093	eltime:  150.22721
# epoch: 6420	train_loss: 0.00093	dev_loss: 0.00093	eltime:  150.39347
# epoch: 6430	train_loss: 0.00092	dev_loss: 0.00092	eltime:  150.55940
# epoch: 6440	train_loss: 0.00092	dev_loss: 0.00092	eltime:  150.73788
# epoch: 6450	train_loss: 0.00091	dev_loss: 0.00091	eltime:  150.91233
# epoch: 6460	train_loss: 0.00091	dev_loss: 0.00091	eltime:  151.08321
# epoch: 6470	train_loss: 0.00091	dev_loss: 0.00090	eltime:  151.26381
# epoch: 6480	train_loss: 0.00090	dev_loss: 0.00090	eltime:  151.43453
# epoch: 6490	train_loss: 0.00090	dev_loss: 0.00090	eltime:  151.59479
# epoch: 6500	train_loss: 0.00089	dev_loss: 0.00089	eltime:  151.76232
# epoch: 6510	train_loss: 0.00089	dev_loss: 0.00089	eltime:  151.92716
# epoch: 6520	train_loss: 0.00088	dev_loss: 0.00088	eltime:  152.09317
# epoch: 6530	train_loss: 0.00088	dev_loss: 0.00088	eltime:  152.26824
# epoch: 6540	train_loss: 0.00088	dev_loss: 0.00088	eltime:  152.43356
# epoch: 6550	train_loss: 0.00087	dev_loss: 0.00087	eltime:  152.59816
# epoch: 6560	train_loss: 0.00087	dev_loss: 0.00087	eltime:  152.76299
# epoch: 6570	train_loss: 0.00086	dev_loss: 0.00086	eltime:  152.92618
# epoch: 6580	train_loss: 0.00086	dev_loss: 0.00086	eltime:  153.09248
# epoch: 6590	train_loss: 0.00086	dev_loss: 0.00086	eltime:  153.25542
# epoch: 6600	train_loss: 0.00085	dev_loss: 0.00085	eltime:  153.42263
# epoch: 6610	train_loss: 0.00085	dev_loss: 0.00085	eltime:  153.58641
# epoch: 6620	train_loss: 0.00084	dev_loss: 0.00084	eltime:  153.75040
# epoch: 6630	train_loss: 0.00084	dev_loss: 0.00084	eltime:  153.92395
# epoch: 6640	train_loss: 0.00083	dev_loss: 0.00083	eltime:  154.08796
# epoch: 6650	train_loss: 0.00083	dev_loss: 0.00083	eltime:  154.26354
# epoch: 6660	train_loss: 0.00083	dev_loss: 0.00083	eltime:  154.42954
# epoch: 6670	train_loss: 0.00082	dev_loss: 0.00082	eltime:  154.59674
# epoch: 6680	train_loss: 0.00082	dev_loss: 0.00082	eltime:  154.75925
# epoch: 6690	train_loss: 0.00081	dev_loss: 0.00081	eltime:  154.91939
# epoch: 6700	train_loss: 0.00081	dev_loss: 0.00081	eltime:  155.08212
# epoch: 6710	train_loss: 0.00080	dev_loss: 0.00080	eltime:  155.24085
# epoch: 6720	train_loss: 0.00080	dev_loss: 0.00080	eltime:  155.41397
# epoch: 6730	train_loss: 0.00079	dev_loss: 0.00079	eltime:  155.58131
# epoch: 6740	train_loss: 0.00079	dev_loss: 0.00079	eltime:  155.73901
# epoch: 6750	train_loss: 0.00078	dev_loss: 0.00078	eltime:  155.90497
# epoch: 6760	train_loss: 0.00078	dev_loss: 0.00078	eltime:  156.06557
# epoch: 6770	train_loss: 0.00078	dev_loss: 0.00077	eltime:  156.22701
# epoch: 6780	train_loss: 0.00077	dev_loss: 0.00077	eltime:  156.38730
# epoch: 6790	train_loss: 0.00077	dev_loss: 0.00076	eltime:  156.54973
# epoch: 6800	train_loss: 0.00076	dev_loss: 0.00076	eltime:  156.71142
# epoch: 6810	train_loss: 0.00076	dev_loss: 0.00075	eltime:  156.87571
# epoch: 6820	train_loss: 0.00075	dev_loss: 0.00075	eltime:  157.04106
# epoch: 6830	train_loss: 0.00075	dev_loss: 0.00074	eltime:  157.20830
# epoch: 6840	train_loss: 0.00074	dev_loss: 0.00074	eltime:  157.44313
# epoch: 6850	train_loss: 0.00074	dev_loss: 0.00073	eltime:  157.64779
# epoch: 6860	train_loss: 0.00073	dev_loss: 0.00073	eltime:  157.82814
# epoch: 6870	train_loss: 0.00072	dev_loss: 0.00072	eltime:  158.00361
# epoch: 6880	train_loss: 0.00072	dev_loss: 0.00072	eltime:  158.18720
# epoch: 6890	train_loss: 0.00071	dev_loss: 0.00071	eltime:  158.35802
# epoch: 6900	train_loss: 0.00071	dev_loss: 0.00071	eltime:  158.53535
# epoch: 6910	train_loss: 0.00070	dev_loss: 0.00070	eltime:  158.70801
# epoch: 6920	train_loss: 0.00070	dev_loss: 0.00070	eltime:  158.87655
# epoch: 6930	train_loss: 0.00070	dev_loss: 0.00069	eltime:  159.04534
# epoch: 6940	train_loss: 0.00069	dev_loss: 0.00069	eltime:  159.23009
# epoch: 6950	train_loss: 0.00069	dev_loss: 0.00069	eltime:  159.40107
# epoch: 6960	train_loss: 0.00068	dev_loss: 0.00068	eltime:  159.56976
# epoch: 6970	train_loss: 0.00068	dev_loss: 0.00068	eltime:  159.73186
# epoch: 6980	train_loss: 0.00067	dev_loss: 0.00067	eltime:  159.90303
# epoch: 6990	train_loss: 0.00067	dev_loss: 0.00067	eltime:  160.07424
# epoch: 7000	train_loss: 0.00066	dev_loss: 0.00066	eltime:  160.23571
# epoch: 7010	train_loss: 0.00066	dev_loss: 0.00066	eltime:  160.39945
# epoch: 7020	train_loss: 0.00065	dev_loss: 0.00065	eltime:  160.57345
# ...
# epoch: 17720	train_loss: 0.00000	dev_loss: 0.00000	eltime:  431.09702
# epoch: 17730	train_loss: 0.00000	dev_loss: 0.00000	eltime:  431.26517
# epoch: 17740	train_loss: 0.00000	dev_loss: 0.00000	eltime:  431.43673
# epoch: 17750	train_loss: 0.00000	dev_loss: 0.00000	eltime:  431.59764
# epoch: 17760	train_loss: 0.00000	dev_loss: 0.00000	eltime:  431.77245
# epoch: 17770	train_loss: 0.00000	dev_loss: 0.00000	eltime:  431.93769
# epoch: 17780	train_loss: 0.00000	dev_loss: 0.00000	eltime:  432.10815
# epoch: 17790	train_loss: 0.00000	dev_loss: 0.00000	eltime:  432.27199
# epoch: 17800	train_loss: 0.00000	dev_loss: 0.00000	eltime:  432.42833
# epoch: 17810	train_loss: 0.00000	dev_loss: 0.00000	eltime:  432.59149
# epoch: 17820	train_loss: 0.00000	dev_loss: 0.00000	eltime:  432.76691
# epoch: 17830	train_loss: 0.00000	dev_loss: 0.00000	eltime:  432.93697
# epoch: 17840	train_loss: 0.00000	dev_loss: 0.00000	eltime:  433.11700
# epoch: 17850	train_loss: 0.00000	dev_loss: 0.00000	eltime:  433.28698
# epoch: 17860	train_loss: 0.00000	dev_loss: 0.00000	eltime:  433.45123
# epoch: 17870	train_loss: 0.00000	dev_loss: 0.00000	eltime:  433.61753
# epoch: 17880	train_loss: 0.00000	dev_loss: 0.00000	eltime:  433.77734
# epoch: 17890	train_loss: 0.00000	dev_loss: 0.00000	eltime:  433.96239
# epoch: 17900	train_loss: 0.00000	dev_loss: 0.00000	eltime:  434.14733
# epoch: 17910	train_loss: 0.00000	dev_loss: 0.00000	eltime:  434.30682
# epoch: 17920	train_loss: 0.00000	dev_loss: 0.00000	eltime:  434.46580
# epoch: 17930	train_loss: 0.00000	dev_loss: 0.00000	eltime:  434.62988
# epoch: 17940	train_loss: 0.00000	dev_loss: 0.00000	eltime:  434.79024
# epoch: 17950	train_loss: 0.00000	dev_loss: 0.00000	eltime:  434.94611
# epoch: 17960	train_loss: 0.00000	dev_loss: 0.00000	eltime:  435.11320
# epoch: 17970	train_loss: 0.00000	dev_loss: 0.00000	eltime:  435.28225
# epoch: 17980	train_loss: 0.00000	dev_loss: 0.00000	eltime:  435.45367
# epoch: 17990	train_loss: 0.00000	dev_loss: 0.00000	eltime:  435.62555
# epoch: 18000	train_loss: 0.00000	dev_loss: 0.00000	eltime:  435.79155
# epoch: 18010	train_loss: 0.00000	dev_loss: 0.00000	eltime:  435.95576
# epoch: 18020	train_loss: 0.00000	dev_loss: 0.00000	eltime:  436.11798
# epoch: 18030	train_loss: 0.00000	dev_loss: 0.00000	eltime:  436.27700
# epoch: 18040	train_loss: 0.00000	dev_loss: 0.00000	eltime:  436.44684
# epoch: 18050	train_loss: 0.00000	dev_loss: 0.00000	eltime:  436.60684
# epoch: 18060	train_loss: 0.00000	dev_loss: 0.00000	eltime:  436.75396
# epoch: 18070	train_loss: 0.00000	dev_loss: 0.00000	eltime:  436.92743
# epoch: 18080	train_loss: 0.00000	dev_loss: 0.00000	eltime:  437.07796
# epoch: 18090	train_loss: 0.00000	dev_loss: 0.00000	eltime:  437.26241
# epoch: 18100	train_loss: 0.00000	dev_loss: 0.00000	eltime:  437.42805
# epoch: 18110	train_loss: 0.00000	dev_loss: 0.00000	eltime:  437.59417
# epoch: 18120	train_loss: 0.00000	dev_loss: 0.00000	eltime:  437.76022
# epoch: 18130	train_loss: 0.00000	dev_loss: 0.00000	eltime:  437.93639
# epoch: 18140	train_loss: 0.00000	dev_loss: 0.00000	eltime:  438.12190
# epoch: 18150	train_loss: 0.00000	dev_loss: 0.00000	eltime:  438.28484
# epoch: 18160	train_loss: 0.00000	dev_loss: 0.00000	eltime:  438.47525
# epoch: 18170	train_loss: 0.00000	dev_loss: 0.00000	eltime:  438.64341
# epoch: 18180	train_loss: 0.00000	dev_loss: 0.00000	eltime:  438.80915
# epoch: 18190	train_loss: 0.00000	dev_loss: 0.00000	eltime:  438.97252
# epoch: 18200	train_loss: 0.00000	dev_loss: 0.00000	eltime:  439.13071
# epoch: 18210	train_loss: 0.00000	dev_loss: 0.00000	eltime:  439.29596
# epoch: 18220	train_loss: 0.00000	dev_loss: 0.00000	eltime:  439.46227
# epoch: 18230	train_loss: 0.00000	dev_loss: 0.00000	eltime:  439.62141
# epoch: 18240	train_loss: 0.00000	dev_loss: 0.00000	eltime:  439.78066
# epoch: 18250	train_loss: 0.00000	dev_loss: 0.00000	eltime:  439.95812
# epoch: 18260	train_loss: 0.00000	dev_loss: 0.00000	eltime:  440.12483
# epoch: 18270	train_loss: 0.00000	dev_loss: 0.00000	eltime:  440.29230
# epoch: 18280	train_loss: 0.00000	dev_loss: 0.00000	eltime:  440.46236
# epoch: 18290	train_loss: 0.00000	dev_loss: 0.00000	eltime:  440.65479
# epoch: 18300	train_loss: 0.00000	dev_loss: 0.00000	eltime:  440.84662
# epoch: 18310	train_loss: 0.00000	dev_loss: 0.00000	eltime:  441.01981
# epoch: 18320	train_loss: 0.00000	dev_loss: 0.00000	eltime:  441.19159
# epoch: 18330	train_loss: 0.00000	dev_loss: 0.00000	eltime:  441.34360
# epoch: 18340	train_loss: 0.00000	dev_loss: 0.00000	eltime:  441.53583
# epoch: 18350	train_loss: 0.00000	dev_loss: 0.00000	eltime:  441.70028
# epoch: 18360	train_loss: 0.00000	dev_loss: 0.00000	eltime:  441.85412
# epoch: 18370	train_loss: 0.00000	dev_loss: 0.00000	eltime:  442.03499
# epoch: 18380	train_loss: 0.00000	dev_loss: 0.00000	eltime:  442.20003
# epoch: 18390	train_loss: 0.00000	dev_loss: 0.00000	eltime:  442.36060
# epoch: 18400	train_loss: 0.00000	dev_loss: 0.00000	eltime:  442.52276
# epoch: 18410	train_loss: 0.00000	dev_loss: 0.00000	eltime:  442.69633
# epoch: 18420	train_loss: 0.00000	dev_loss: 0.00000	eltime:  442.86325
# epoch: 18430	train_loss: 0.00000	dev_loss: 0.00000	eltime:  443.02078
# epoch: 18440	train_loss: 0.00000	dev_loss: 0.00000	eltime:  443.19516
# epoch: 18450	train_loss: 0.00000	dev_loss: 0.00000	eltime:  443.35074
# epoch: 18460	train_loss: 0.00000	dev_loss: 0.00000	eltime:  443.50538
# epoch: 18470	train_loss: 0.00000	dev_loss: 0.00000	eltime:  443.66130
# epoch: 18480	train_loss: 0.00000	dev_loss: 0.00000	eltime:  443.82110
# epoch: 18490	train_loss: 0.00000	dev_loss: 0.00000	eltime:  443.99772
# epoch: 18500	train_loss: 0.00000	dev_loss: 0.00000	eltime:  444.16249
# epoch: 18510	train_loss: 0.00000	dev_loss: 0.00000	eltime:  444.32950
# epoch: 18520	train_loss: 0.00000	dev_loss: 0.00000	eltime:  444.49484
# epoch: 18530	train_loss: 0.00000	dev_loss: 0.00000	eltime:  444.66809
# epoch: 18540	train_loss: 0.00000	dev_loss: 0.00000	eltime:  444.83993
# epoch: 18550	train_loss: 0.00000	dev_loss: 0.00000	eltime:  445.00342
# epoch: 18560	train_loss: 0.00000	dev_loss: 0.00000	eltime:  445.16317
# epoch: 18570	train_loss: 0.00000	dev_loss: 0.00000	eltime:  445.32918
# epoch: 18580	train_loss: 0.00000	dev_loss: 0.00000	eltime:  445.50385
# epoch: 18590	train_loss: 0.00000	dev_loss: 0.00000	eltime:  445.67220
# epoch: 18600	train_loss: 0.00000	dev_loss: 0.00000	eltime:  445.83747
# epoch: 18610	train_loss: 0.00000	dev_loss: 0.00000	eltime:  446.00577
# epoch: 18620	train_loss: 0.00000	dev_loss: 0.00000	eltime:  446.17395
# epoch: 18630	train_loss: 0.00000	dev_loss: 0.00000	eltime:  446.32457
# epoch: 18640	train_loss: 0.00000	dev_loss: 0.00000	eltime:  446.50198
# epoch: 18650	train_loss: 0.00000	dev_loss: 0.00000	eltime:  446.66104
# epoch: 18660	train_loss: 0.00000	dev_loss: 0.00000	eltime:  446.82010
# epoch: 18670	train_loss: 0.00000	dev_loss: 0.00000	eltime:  446.97864
# epoch: 18680	train_loss: 0.00000	dev_loss: 0.00000	eltime:  447.14179
# epoch: 18690	train_loss: 0.00000	dev_loss: 0.00000	eltime:  447.31047
# epoch: 18700	train_loss: 0.00000	dev_loss: 0.00000	eltime:  447.48022
# epoch: 18710	train_loss: 0.00000	dev_loss: 0.00000	eltime:  447.64768
# epoch: 18720	train_loss: 0.00000	dev_loss: 0.00000	eltime:  447.81654
# epoch: 18730	train_loss: 0.00000	dev_loss: 0.00000	eltime:  447.99951
# epoch: 18740	train_loss: 0.00000	dev_loss: 0.00000	eltime:  448.16895
# epoch: 18750	train_loss: 0.00000	dev_loss: 0.00000	eltime:  448.33833
# epoch: 18760	train_loss: 0.00000	dev_loss: 0.00000	eltime:  448.51218
# epoch: 18770	train_loss: 0.00000	dev_loss: 0.00000	eltime:  448.68753
# epoch: 18780	train_loss: 0.00000	dev_loss: 0.00000	eltime:  448.85514
# epoch: 18790	train_loss: 0.00000	dev_loss: 0.00000	eltime:  449.02791
# epoch: 18800	train_loss: 0.00000	dev_loss: 0.00000	eltime:  449.19981
# epoch: 18810	train_loss: 0.00000	dev_loss: 0.00000	eltime:  449.37477
# epoch: 18820	train_loss: 0.00000	dev_loss: 0.00000	eltime:  449.53845
# epoch: 18830	train_loss: 0.00000	dev_loss: 0.00000	eltime:  449.70396
# epoch: 18840	train_loss: 0.00000	dev_loss: 0.00000	eltime:  449.88865
# epoch: 18850	train_loss: 0.00000	dev_loss: 0.00000	eltime:  450.05118
# epoch: 18860	train_loss: 0.00000	dev_loss: 0.00000	eltime:  450.22854
# epoch: 18870	train_loss: 0.00000	dev_loss: 0.00000	eltime:  450.40672
# epoch: 18880	train_loss: 0.00000	dev_loss: 0.00000	eltime:  450.58591
# epoch: 18890	train_loss: 0.00000	dev_loss: 0.00000	eltime:  450.76153
# epoch: 18900	train_loss: 0.00000	dev_loss: 0.00000	eltime:  450.93917
# epoch: 18910	train_loss: 0.00000	dev_loss: 0.00000	eltime:  451.11370
# epoch: 18920	train_loss: 0.00000	dev_loss: 0.00000	eltime:  451.27576
# epoch: 18930	train_loss: 0.00000	dev_loss: 0.00000	eltime:  451.44555
# epoch: 18940	train_loss: 0.00000	dev_loss: 0.00000	eltime:  451.67083
# epoch: 18950	train_loss: 0.00000	dev_loss: 0.00000	eltime:  451.86446
# epoch: 18960	train_loss: 0.00000	dev_loss: 0.00000	eltime:  452.06206
# epoch: 18970	train_loss: 0.00000	dev_loss: 0.00000	eltime:  452.24634
# epoch: 18980	train_loss: 0.00000	dev_loss: 0.00000	eltime:  452.41819
# epoch: 18990	train_loss: 0.00000	dev_loss: 0.00000	eltime:  452.59879
# epoch: 19000	train_loss: 0.00000	dev_loss: 0.00000	eltime:  452.77162
# epoch: 19010	train_loss: 0.00000	dev_loss: 0.00000	eltime:  452.94735
# epoch: 19020	train_loss: 0.00000	dev_loss: 0.00000	eltime:  453.11710
# epoch: 19030	train_loss: 0.00000	dev_loss: 0.00000	eltime:  453.29665
# epoch: 19040	train_loss: 0.00000	dev_loss: 0.00000	eltime:  453.46177
# epoch: 19050	train_loss: 0.00000	dev_loss: 0.00000	eltime:  453.63210
# epoch: 19060	train_loss: 0.00000	dev_loss: 0.00000	eltime:  453.78628
# epoch: 19070	train_loss: 0.00000	dev_loss: 0.00000	eltime:  453.95922
# epoch: 19080	train_loss: 0.00000	dev_loss: 0.00000	eltime:  454.14744
# epoch: 19090	train_loss: 0.00000	dev_loss: 0.00000	eltime:  454.33110
# epoch: 19100	train_loss: 0.00000	dev_loss: 0.00000	eltime:  454.50104
# epoch: 19110	train_loss: 0.00000	dev_loss: 0.00000	eltime:  454.67703
# epoch: 19120	train_loss: 0.00000	dev_loss: 0.00000	eltime:  454.84711
# epoch: 19130	train_loss: 0.00000	dev_loss: 0.00000	eltime:  455.02316
# epoch: 19140	train_loss: 0.00000	dev_loss: 0.00000	eltime:  455.20175
# epoch: 19150	train_loss: 0.00000	dev_loss: 0.00000	eltime:  455.37662
# epoch: 19160	train_loss: 0.00000	dev_loss: 0.00000	eltime:  455.54618
# epoch: 19170	train_loss: 0.00000	dev_loss: 0.00000	eltime:  455.71501
# epoch: 19180	train_loss: 0.00000	dev_loss: 0.00000	eltime:  455.88152
# epoch: 19190	train_loss: 0.00000	dev_loss: 0.00000	eltime:  456.05090
# epoch: 19200	train_loss: 0.00000	dev_loss: 0.00000	eltime:  456.22040
# epoch: 19210	train_loss: 0.00000	dev_loss: 0.00000	eltime:  456.37200
# epoch: 19220	train_loss: 0.00000	dev_loss: 0.00000	eltime:  456.54571
# epoch: 19230	train_loss: 0.00000	dev_loss: 0.00000	eltime:  456.70846
# epoch: 19240	train_loss: 0.00000	dev_loss: 0.00000	eltime:  456.86247
# epoch: 19250	train_loss: 0.00000	dev_loss: 0.00000	eltime:  457.03365
# epoch: 19260	train_loss: 0.00000	dev_loss: 0.00000	eltime:  457.20081
# epoch: 19270	train_loss: 0.00000	dev_loss: 0.00000	eltime:  457.36365
# epoch: 19280	train_loss: 0.00000	dev_loss: 0.00000	eltime:  457.51096
# epoch: 19290	train_loss: 0.00000	dev_loss: 0.00000	eltime:  457.67747
# epoch: 19300	train_loss: 0.00000	dev_loss: 0.00000	eltime:  457.83153
# epoch: 19310	train_loss: 0.00000	dev_loss: 0.00000	eltime:  457.99782
# epoch: 19320	train_loss: 0.00000	dev_loss: 0.00000	eltime:  458.15485
# epoch: 19330	train_loss: 0.00000	dev_loss: 0.00000	eltime:  458.30659
# epoch: 19340	train_loss: 0.00000	dev_loss: 0.00000	eltime:  458.49613
# epoch: 19350	train_loss: 0.00000	dev_loss: 0.00000	eltime:  458.65096
# epoch: 19360	train_loss: 0.00000	dev_loss: 0.00000	eltime:  458.82250
# epoch: 19370	train_loss: 0.00000	dev_loss: 0.00000	eltime:  458.98608
# epoch: 19380	train_loss: 0.00000	dev_loss: 0.00000	eltime:  459.14631
# epoch: 19390	train_loss: 0.00000	dev_loss: 0.00000	eltime:  459.33212
# epoch: 19400	train_loss: 0.00000	dev_loss: 0.00000	eltime:  459.50206
# epoch: 19410	train_loss: 0.00000	dev_loss: 0.00000	eltime:  459.66635
# epoch: 19420	train_loss: 0.00000	dev_loss: 0.00000	eltime:  459.82454
# epoch: 19430	train_loss: 0.00000	dev_loss: 0.00000	eltime:  459.98917
# epoch: 19440	train_loss: 0.00000	dev_loss: 0.00000	eltime:  460.13252
# epoch: 19450	train_loss: 0.00000	dev_loss: 0.00000	eltime:  460.30284
# epoch: 19460	train_loss: 0.00000	dev_loss: 0.00000	eltime:  460.46499
# epoch: 19470	train_loss: 0.00000	dev_loss: 0.00000	eltime:  460.63638
# epoch: 19480	train_loss: 0.00000	dev_loss: 0.00000	eltime:  460.80105
# epoch: 19490	train_loss: 0.00000	dev_loss: 0.00000	eltime:  460.96615
# epoch: 19500	train_loss: 0.00000	dev_loss: 0.00000	eltime:  461.13234
# epoch: 19510	train_loss: 0.00000	dev_loss: 0.00000	eltime:  461.30827
# epoch: 19520	train_loss: 0.00000	dev_loss: 0.00000	eltime:  461.47692
# epoch: 19530	train_loss: 0.00000	dev_loss: 0.00000	eltime:  461.64856
# epoch: 19540	train_loss: 0.00000	dev_loss: 0.00000	eltime:  461.80895
# epoch: 19550	train_loss: 0.00000	dev_loss: 0.00000	eltime:  461.96581
# epoch: 19560	train_loss: 0.00000	dev_loss: 0.00000	eltime:  462.14227
# epoch: 19570	train_loss: 0.00000	dev_loss: 0.00000	eltime:  462.30988
# epoch: 19580	train_loss: 0.00000	dev_loss: 0.00000	eltime:  462.48062
# epoch: 19590	train_loss: 0.00000	dev_loss: 0.00000	eltime:  462.65152
# epoch: 19600	train_loss: 0.00000	dev_loss: 0.00000	eltime:  462.81541
# epoch: 19610	train_loss: 0.00000	dev_loss: 0.00000	eltime:  462.97183
# epoch: 19620	train_loss: 0.00000	dev_loss: 0.00000	eltime:  463.15254
# epoch: 19630	train_loss: 0.00000	dev_loss: 0.00000	eltime:  463.32015
# epoch: 19640	train_loss: 0.00000	dev_loss: 0.00000	eltime:  463.48812
# epoch: 19650	train_loss: 0.00000	dev_loss: 0.00000	eltime:  463.64928
# epoch: 19660	train_loss: 0.00000	dev_loss: 0.00000	eltime:  463.82905
# epoch: 19670	train_loss: 0.00000	dev_loss: 0.00000	eltime:  463.99748
# epoch: 19680	train_loss: 0.00000	dev_loss: 0.00000	eltime:  464.15834
# epoch: 19690	train_loss: 0.00000	dev_loss: 0.00000	eltime:  464.33814
# epoch: 19700	train_loss: 0.00000	dev_loss: 0.00000	eltime:  464.48695
# epoch: 19710	train_loss: 0.00000	dev_loss: 0.00000	eltime:  464.66205
# epoch: 19720	train_loss: 0.00000	dev_loss: 0.00000	eltime:  464.81252
# epoch: 19730	train_loss: 0.00000	dev_loss: 0.00000	eltime:  464.96653
# epoch: 19740	train_loss: 0.00000	dev_loss: 0.00000	eltime:  465.13439
# epoch: 19750	train_loss: 0.00000	dev_loss: 0.00000	eltime:  465.28114
# epoch: 19760	train_loss: 0.00000	dev_loss: 0.00000	eltime:  465.45856
# epoch: 19770	train_loss: 0.00000	dev_loss: 0.00000	eltime:  465.62263
# epoch: 19780	train_loss: 0.00000	dev_loss: 0.00000	eltime:  465.78852
# epoch: 19790	train_loss: 0.00000	dev_loss: 0.00000	eltime:  465.95164
# epoch: 19800	train_loss: 0.00000	dev_loss: 0.00000	eltime:  466.11576
# epoch: 19810	train_loss: 0.00000	dev_loss: 0.00000	eltime:  466.30046
# epoch: 19820	train_loss: 0.00000	dev_loss: 0.00000	eltime:  466.47393
# epoch: 19830	train_loss: 0.00000	dev_loss: 0.00000	eltime:  466.65602
# epoch: 19840	train_loss: 0.00000	dev_loss: 0.00000	eltime:  466.81719
# epoch: 19850	train_loss: 0.00000	dev_loss: 0.00000	eltime:  466.97689
# epoch: 19860	train_loss: 0.00000	dev_loss: 0.00000	eltime:  467.13452
# epoch: 19870	train_loss: 0.00000	dev_loss: 0.00000	eltime:  467.36677
# epoch: 19880	train_loss: 0.00000	dev_loss: 0.00000	eltime:  467.54163
# epoch: 19890	train_loss: 0.00000	dev_loss: 0.00000	eltime:  467.71607
# epoch: 19900	train_loss: 0.00000	dev_loss: 0.00000	eltime:  467.87408
# epoch: 19910	train_loss: 0.00000	dev_loss: 0.00000	eltime:  468.04064
# epoch: 19920	train_loss: 0.00000	dev_loss: 0.00000	eltime:  468.19383
# epoch: 19930	train_loss: 0.00000	dev_loss: 0.00000	eltime:  468.36736
# epoch: 19940	train_loss: 0.00000	dev_loss: 0.00000	eltime:  468.52894
# epoch: 19950	train_loss: 0.00000	dev_loss: 0.00000	eltime:  468.69423
# epoch: 19960	train_loss: 0.00000	dev_loss: 0.00000	eltime:  468.87186
# epoch: 19970	train_loss: 0.00000	dev_loss: 0.00000	eltime:  469.03367
# epoch: 19980	train_loss: 0.00000	dev_loss: 0.00000	eltime:  469.20660
# epoch: 19990	train_loss: 0.00000	dev_loss: 0.00000	eltime:  469.37884

# %% [markdown]
# ### Evaluate the trained model

# %%
# do the full simulation rollout
dynamics_model.nsteps = nsim
# Use model to predict trajectory on test data
test_outputs = dynamics_model(test_data)

# %%
# Retrieve predictions and ground truth
pred_traj = test_outputs['xn'][:, :-1, :]  # skip final since it's predicted
true_traj = test_data['X'][:, :-1, :]      # match prediction horizon

# Reshape to [nx, time]
pred_traj = pred_traj.detach().numpy().reshape(-1, nx).T
true_traj = true_traj.detach().numpy().reshape(-1, nx).T

# %%
# ---------------------------------------
# Plotting Style
# ---------------------------------------
plt.style.use('default')
plt.rcParams["font.family"] = "serif"
plt.rcParams['figure.dpi'] = 300
plt.rcParams.update({
    'font.size': 10,
    'legend.fontsize': 10,
    'axes.labelsize': 10,
    'axes.titlesize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10
})

# %%
# ---------------------------------------
# Tank Heights
# ---------------------------------------
plt.figure()
plt.plot(time, pred_traj[0], label="Tank #1")
plt.plot(time, pred_traj[1], label="Tank #2")
plt.plot(time[:-1], data[1:, 0], linestyle='--', label="Data Tank #1")
plt.xlim([0, 500])
plt.ylim([0, 40])
plt.xlabel("Time")
plt.ylabel("Height")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# ---------------------------------------
# Mass Flows
# ---------------------------------------
plt.figure()
plt.plot(time, pred_traj[2], label="Inflow #1")
plt.plot(time, pred_traj[3], label="Inflow #2")
plt.plot(time, pred_traj[2] + pred_traj[3], label="In_1 + In_2")
plt.plot(time[:-1], data[1:, 2], linestyle='--', label="Data Inflow #1")
plt.plot(time[:-1], data[1:, 3], linestyle='--', label="Data Inflow #2")
plt.xlim([0, 500])
plt.ylim([0, 0.6])
plt.xlabel("Time")
plt.ylabel("Volumetric Flow")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# ---------------------------------------
# Area-Height Relationship
# ---------------------------------------
h = torch.linspace(0, 40, 401).unsqueeze(-1).float()
area = tank_profile(h).detach().numpy()

plt.figure()
plt.plot(h.numpy(), area, label="Model")
plt.plot(h.numpy(), area_data, label="Actual")
plt.ylim([0, 6])
plt.xlim([0, 35])
plt.xlabel("Height")
plt.ylabel("Area(h)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Extrapolation to unseen data

# %%
# Eval on new conditions with sinusoidal input
nsteps = 501
data = tank_data[nsteps:, ]
time = np.float32(np.linspace(0.0, len(data[:, 0]) - 1, len(data[:, 0])).reshape(-1, 1)) * dt
U = time * 0.0 + 0.5 + 0.25 * np.sin(time / 100.0)
U_torch = torch.tensor(U).reshape(1, -1, nu)
# update dictionary dataset
test_data['U'] = U_torch
test_data['X'] = torch.tensor(data).reshape(1, -1, nx)
test_data['xn'] = test_data['X'][:, 0:1, :]  # new initial state

# %%
# Use model to predict trajectory on test data
test_outputs = dynamics_model(test_data)

# Retrieve predictions and ground truth
pred_traj = test_outputs['xn'][:, :-1, :]  # skip final since it's predicted
true_traj = test_data['X'][:, :-1, :]      # match prediction horizon

# Reshape to [nx, time]
pred_traj = pred_traj.detach().numpy().reshape(-1, nx).T
true_traj = true_traj.detach().numpy().reshape(-1, nx).T

# %%
# ---------------------------------------
# Tank Heights
# ---------------------------------------
plt.figure()
plt.plot(time[:-1], pred_traj[0], label="Tank #1")
plt.plot(time[:-1], pred_traj[1], label="Tank #2")
plt.plot(time[:-1], data[1:, 0], linestyle='--', label="Data Tank #1")
plt.xlim([0, 500])
plt.ylim([0, 40])
plt.xlabel("Time")
plt.ylabel("Height")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# ---------------------------------------
# Mass Flows
# ---------------------------------------
plt.figure()
plt.plot(time[:-1], pred_traj[2], label="Inflow #1")
plt.plot(time[:-1], pred_traj[3], label="Inflow #2")
plt.plot(time[:-1], pred_traj[2] + pred_traj[3], label="In_1 + In_2")
plt.plot(time[:-1], data[1:, 2], linestyle='--', label="Data Inflow #1")
plt.plot(time[:-1], data[1:, 3], linestyle='--', label="Data Inflow #2")
plt.xlim([0, 500])
plt.ylim([0, 0.8])
plt.xlabel("Time")
plt.ylabel("Volumetric Flow")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Algebraic relationship is satisfied as hard constraint for new time-varying input signal of the inflow thanks to the architectural design of the algebra solver. This enables generalization out of distribution of the training data without violating the conservation relationship.

# %%
# ---------------------------------------
# Area-Height Relationship
# ---------------------------------------
h = torch.linspace(0, 40, 401).unsqueeze(-1).float()
area = tank_profile(h).detach().numpy()

plt.figure()
plt.plot(h.numpy(), area, label="Model")
plt.plot(h.numpy(), area_data, label="Actual")
plt.ylim([0, 6])
plt.xlim([0, 35])
plt.xlabel("Height")
plt.ylabel("Area(h)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion
#
# This work presents a data-driven framework for modeling differential algebraic equations (DAEs) using a novel operator splitting (OS) method for Neural DAEs.  Inspired by Lie-Trotter splitting, our approach sequentially updates algebraic states via a differentiable surrogate and integrates differential states using an ODE solver.
# The effectiveness of the proposed method is demonstrated by (i) modeling networked dynamical systems with algebraic constraints and (ii) showing generalization to unseen process conditions or component variation. Furthermore, demonstrate robustness to noise and extrapolation to (i) learn the behaviors of the DAE system components and their interaction physics and (ii) disambiguate between data trends and mechanistic relationships contained in the DAE system.
