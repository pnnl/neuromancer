# %% [markdown]
# # Neural ODEs in NeuroMANCER
#
#
# This tutorial demonstrates the use of [Neural Ordinary Differential Equations](https://arxiv.org/abs/1806.07366) (NODE) for system identificaiton of dynamical systems.
#
#
# ## System Identification Problem Setup
#
# <img src="../figs/NODE.PNG" width="600">
#
#
# Starting from a given initial condition  $x_{0}$, the next state of the system  $x_{k+1}$
# is obtained by feeding the current state $x_{k}$ into the neural network $N$ that generates a derivative to be
# integrated using an integration scheme $\int$. In system identification, the loss $\mathcal{L}$ is evaluated by comparing the  trajectory generated by the model with the training trajectory. The process can be repeated for multiple trajectories to improve the generalization of the model.
#
#
# ### References
#
# [1] [Ricky T. Q. Chen, Yulia Rubanova, Jesse Bettencourt, David Duvenaud, Neural Ordinary Differential Equations, NeurIPS 2018](https://arxiv.org/abs/1806.07366)
# [2] http://implicit-layers-tutorial.org/neural_odes/
# [3] https://github.com/Zymrael/awesome-neural-ode
# [4] https://rkevingibson.github.io/blog/neural-networks-as-ordinary-differential-equations/
# [5] [Christian Legaard, Thomas Schranz, Gerald Schweiger, Ján Drgoňa, Basak Falay, Cláudio Gomes, Alexandros Iosifidis, Mahdi Abkar, and Peter Larsen. 2023. Constructing Neural Network Based Models for Simulating Dynamical Systems. ACM Comput. Surv. 55, 11, Article 236 (November 2023), 34 pages.](https://dl.acm.org/doi/10.1145/3567591)

# %% [markdown]
# ## NeuroMANCER and Dependencies

# %% [markdown]
# ### Install (Colab only)
# Skip this step when running locally.

# %%
# !pip install "neuromancer[examples] @ git+https://github.com/pnnl/neuromancer.git@master"

# %%
import torch
from neuromancer.psl import plot
from neuromancer import psl
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

from neuromancer.system import Node, System
from neuromancer.dynamics import integrators, ode
from neuromancer.trainer import Trainer
from neuromancer.problem import Problem
from neuromancer.loggers import BasicLogger
from neuromancer.dataset import DictDataset
from neuromancer.constraint import variable
from neuromancer.loss import PenaltyLoss
from neuromancer.modules import blocks

torch.manual_seed(0)

# %% [markdown]
# ## Generate trajectories from ODE system
#
# Consider the [VanDerPol system](https://en.wikipedia.org/wiki/Van_der_Pol_oscillator) defined by the [ordinary differential equations](https://en.wikipedia.org/wiki/Ordinary_differential_equation):
#
# $$
#  \frac{dx_1}{dt} = \mu (x_1 - \frac{1}{3}x_1^3 - x_2)   \\
#  \frac{dx_2}{dt} = \frac{x_1}{\mu}
# $$
#
# In this example we don't assume any prior knowledge on the system dynamics. We will only have access to limited measurements of the system states $x$.

# %%
# %%  ground truth system
system = psl.systems['VanDerPol']
modelSystem = system()
ts = modelSystem.ts
nx = modelSystem.nx
raw = modelSystem.simulate(nsim=1000, ts=ts)
plot.pltOL(Y=raw['Y'])
plot.pltPhase(X=raw['Y'])

# %% [markdown]
# ## Create training data of sampled trajectories
#
# We will obtain a dataset of sampled trajectories of the system dynamics to model:
# $$\hat{X} = [\hat{x}^i_0, ..., \hat{x}^i_{N}], \, \, i \in [1, ..., m]$$
# where $N$ represents the prediction horizon, $m$ represents number of measured trajectories, and $i$ represents an index of the sampled trajectory.

# %%
def get_data(sys, nsim, nsteps, ts, bs):
    """
    :param nsteps: (int) Number of timesteps for each batch of training data
    :param sys: (psl.system)
    :param ts: (float) step size
    :param bs: (int) batch size

    """
    train_sim, dev_sim, test_sim = [sys.simulate(nsim=nsim, ts=ts) for i in range(3)]
    nx = sys.nx
    nbatch = nsim//nsteps
    length = (nsim//nsteps) * nsteps

    trainX = train_sim['X'][:length].reshape(nbatch, nsteps, nx)
    trainX = torch.tensor(trainX, dtype=torch.float32)
    train_data = DictDataset({'X': trainX, 'xn': trainX[:, 0:1, :]}, name='train')
    train_loader = DataLoader(train_data, batch_size=bs,
                              collate_fn=train_data.collate_fn, shuffle=True)

    devX = dev_sim['X'][:length].reshape(nbatch, nsteps, nx)
    devX = torch.tensor(devX, dtype=torch.float32)
    dev_data = DictDataset({'X': devX, 'xn': devX[:, 0:1, :]}, name='dev')
    dev_loader = DataLoader(dev_data, batch_size=bs,
                            collate_fn=dev_data.collate_fn, shuffle=True)

    testX = test_sim['X'][:length].reshape(1, nsim, nx)
    testX = torch.tensor(testX, dtype=torch.float32)
    test_data = {'X': testX, 'xn': testX[:, 0:1, :]}

    return train_loader, dev_loader, test_data

# %%
nsim = 600   # number of simulation steps in the dataset
nsteps = 2   # number of prediction horizon steps in the loss function
bs = 100     # minibatching batch size
train_loader, dev_loader, test_data = get_data(modelSystem, nsim, nsteps, ts, bs)

# %% [markdown]
# ## NODE system model in Neuromancer
#
# Here we construct a continuous-time NODE model  $\dot{x} = f_{\theta}(x)$ with trainable parameters $\theta$.

# %%
# define neural network of the NODE
fx = blocks.MLP(nx, nx, bias=True,
                 linear_map=torch.nn.Linear,
                 nonlin=torch.nn.ReLU,
                 hsizes=[60, 60, 60])

# %% [markdown]
# Next we need to solve the continuous-time NODE model with suitable ODE solver, e.g., [Runge–Kutta integrator](https://en.wikipedia.org/wiki/Runge%E2%80%93Kutta_methods).
# $x_{k+1} = \text{ODESolve}(f_{\theta}(x_k))$
#
# For training we need to obtain accurate reverse-mode gradients of the integrated NODE system. This can be done in two ways, either by unrolling the operations of the ODE solver and using the [backpropagation through time](https://en.wikipedia.org/wiki/Backpropagation_through_time) (BPTT) algorithm, or via [Adjoint state method](https://en.wikipedia.org/wiki/Adjoint_state_method).
#
# Schematics illustrating the adjoing method used in the [Neural Ordinary Differential Equations](https://arxiv.org/abs/1806.07366) paper:
# <img src="../figs/NODE_backprop.png" width="500">
#
# Neuromancer provides a set of ODE solvers implemented in [integrators.py](https://github.com/pnnl/neuromancer/blob/master/src/neuromancer/dynamics/integrators.py).
# For adjoint method we provide the interface to the [open-source implementation](https://github.com/rtqichen/torchdiffeq) via DiffEqIntegrator class.

# %%
# integrate NODE with adjoint-based solver
fxRK4 = integrators.DiffEqIntegrator(fx, h=ts, method='rk4')

# %% [markdown]
# Next we construct an open-loop system composed of a smbolic NODE model

# %%
# create symbolic system model in Neuromancer
model = Node(fxRK4, ['xn'], ['xn'], name='NODE')
dynamics_model = System([model], name='system', nsteps=nsteps)

# %%
# visualize the system
# dynamics_model.show()

# %% [markdown]
# ## Define system identification loss function terms
#
# Here we define loss function terms to fit the ODE parameters from given time-series data.
#
# **Tracking loss:**
# $$\ell_x = Q_x||x^i_k - \hat{x}^i_k||_2^2$$
# **Finite difference loss:**
# $$\ell_{dx} =  Q_{dx}||\Delta x^i_k - \Delta \hat{x}^i_k||_2^2$$
# where $\Delta x^i_k = x^i_{k+1} - x^i_k$

# %%
# %% Constraints + losses:
x = variable("X")
xhat = variable('xn')[:, :-1, :]
# finite difference variables
xFD = (x[:, 1:, :] - x[:, :-1, :])
xhatFD = (xhat[:, 1:, :] - xhat[:, :-1, :])

# trajectory tracking loss
reference_loss = (xhat == x)^2
reference_loss.name = "ref_loss"

# finite difference loss
fd_loss = 2.*(xFD == xhatFD)^2
fd_loss.name = 'FD_loss'

# %% [markdown]
# ## Construct System ID learning problem
#
# Given the training dataset $\hat{X} = [\hat{x}^i_0, ..., \hat{x}^i_{N}]$ we want to solve the following problem:
#
# $$
# \begin{align}
# &\underset{\theta}{\text{minimize}}     && \sum_{i=1}^m \Big(\sum_{k=1}^{N}  Q_x||x^i_k - \hat{x}^i_k||_2^2  +  \sum_{k=1}^{N-1}  Q_{dx}||\Delta x^i_k - \Delta \hat{x}^i_k||_2^2  \Big) \\
# &\text{subject to}    && x^i_{k+1} =  \text{ODESolve}(f_{\theta}(x^i_k)) \\
# \end{align}
# $$

# %%
# aggregate list of objective terms and constraints
objectives = [reference_loss, fd_loss]
constraints = []
# create constrained optimization loss
loss = PenaltyLoss(objectives, constraints)
# construct constrained optimization problem
problem = Problem([dynamics_model], loss)

# %%
# plot computational graph
# problem.show()

# %% [markdown]
# ## Solve the problem
#
# We fit the unknown NODE parameters $\theta$ using stochastic gradient descent.

# %%
optimizer = torch.optim.Adam(problem.parameters(), lr=0.001)
logger = BasicLogger(args=None, savedir='test', verbosity=1,
                     stdout=['dev_loss', 'train_loss'])
# define neuromancer trainer
trainer = Trainer(
    problem,
    train_loader,
    dev_loader,
    test_data,
    optimizer,
    patience=50,
    warmup=100,
    epochs=500,
    eval_metric="dev_loss",
    train_metric="train_loss",
    dev_metric="dev_loss",
    test_metric="dev_loss",
    logger=logger,
)
# Out:
# None
# Number of parameters: 7622

# %%
# %% train
best_model = trainer.train()
problem.load_state_dict(best_model)
# Out:
# epoch: 0	train_loss: 0.05299	dev_loss: 0.04981	eltime:  0.26313
# epoch: 1	train_loss: 0.04773	dev_loss: 0.04448	eltime:  0.30239
# epoch: 2	train_loss: 0.04463	dev_loss: 0.04257	eltime:  0.35556
# epoch: 3	train_loss: 0.04238	dev_loss: 0.04293	eltime:  0.39245
# epoch: 4	train_loss: 0.03718	dev_loss: 0.03591	eltime:  0.44357
# epoch: 5	train_loss: 0.03363	dev_loss: 0.03224	eltime:  0.50316
# epoch: 6	train_loss: 0.02932	dev_loss: 0.02565	eltime:  0.53550
# epoch: 7	train_loss: 0.02327	dev_loss: 0.02095	eltime:  0.58292
# epoch: 8	train_loss: 0.02062	dev_loss: 0.01686	eltime:  0.62516
# epoch: 9	train_loss: 0.01389	dev_loss: 0.01120	eltime:  0.67774
# epoch: 10	train_loss: 0.01046	dev_loss: 0.00921	eltime:  0.72911
# epoch: 11	train_loss: 0.00684	dev_loss: 0.00553	eltime:  0.79293
# epoch: 12	train_loss: 0.00469	dev_loss: 0.00305	eltime:  0.82957
# epoch: 13	train_loss: 0.00287	dev_loss: 0.00270	eltime:  0.87044
# epoch: 14	train_loss: 0.00265	dev_loss: 0.00231	eltime:  0.91143
# epoch: 15	train_loss: 0.00254	dev_loss: 0.00258	eltime:  0.96453
# epoch: 16	train_loss: 0.00232	dev_loss: 0.00213	eltime:  1.01454
# epoch: 17	train_loss: 0.00220	dev_loss: 0.00219	eltime:  1.05482
# epoch: 18	train_loss: 0.00160	dev_loss: 0.00142	eltime:  1.12327
# epoch: 19	train_loss: 0.00131	dev_loss: 0.00115	eltime:  1.16757
# epoch: 20	train_loss: 0.00106	dev_loss: 0.00115	eltime:  1.21429
# epoch: 21	train_loss: 0.00103	dev_loss: 0.00093	eltime:  1.26216
# epoch: 22	train_loss: 0.00108	dev_loss: 0.00073	eltime:  1.30917
# epoch: 23	train_loss: 0.00080	dev_loss: 0.00074	eltime:  1.35611
# epoch: 24	train_loss: 0.00056	dev_loss: 0.00062	eltime:  1.39268
# epoch: 25	train_loss: 0.00055	dev_loss: 0.00058	eltime:  1.44474
# epoch: 26	train_loss: 0.00061	dev_loss: 0.00055	eltime:  1.49402
# epoch: 27	train_loss: 0.00048	dev_loss: 0.00041	eltime:  1.54560
# epoch: 28	train_loss: 0.00044	dev_loss: 0.00033	eltime:  1.58539
# epoch: 29	train_loss: 0.00036	dev_loss: 0.00032	eltime:  1.62559
# epoch: 30	train_loss: 0.00028	dev_loss: 0.00025	eltime:  1.67622
# epoch: 31	train_loss: 0.00025	dev_loss: 0.00028	eltime:  1.72478
# epoch: 32	train_loss: 0.00024	dev_loss: 0.00020	eltime:  1.76770
# epoch: 33	train_loss: 0.00017	dev_loss: 0.00018	eltime:  1.80842
# epoch: 34	train_loss: 0.00017	dev_loss: 0.00015	eltime:  1.85685
# epoch: 35	train_loss: 0.00015	dev_loss: 0.00013	eltime:  1.89920
# epoch: 36	train_loss: 0.00013	dev_loss: 0.00012	eltime:  1.94834
# epoch: 37	train_loss: 0.00013	dev_loss: 0.00011	eltime:  1.98992
# epoch: 38	train_loss: 0.00012	dev_loss: 0.00009	eltime:  2.03535
# epoch: 39	train_loss: 0.00010	dev_loss: 0.00008	eltime:  2.08241
# epoch: 40	train_loss: 0.00007	dev_loss: 0.00007	eltime:  2.13225
# epoch: 41	train_loss: 0.00008	dev_loss: 0.00007	eltime:  2.16244
# epoch: 42	train_loss: 0.00006	dev_loss: 0.00007	eltime:  2.21042
# epoch: 43	train_loss: 0.00006	dev_loss: 0.00006	eltime:  2.24174
# epoch: 44	train_loss: 0.00005	dev_loss: 0.00005	eltime:  2.28462
# epoch: 45	train_loss: 0.00005	dev_loss: 0.00006	eltime:  2.33898
# epoch: 46	train_loss: 0.00004	dev_loss: 0.00004	eltime:  2.38662
# epoch: 47	train_loss: 0.00004	dev_loss: 0.00004	eltime:  2.43019
# epoch: 48	train_loss: 0.00004	dev_loss: 0.00004	eltime:  2.47331
# epoch: 49	train_loss: 0.00003	dev_loss: 0.00004	eltime:  2.52052
# epoch: 50	train_loss: 0.00004	dev_loss: 0.00003	eltime:  2.56173
# epoch: 51	train_loss: 0.00003	dev_loss: 0.00003	eltime:  2.61789
# epoch: 52	train_loss: 0.00003	dev_loss: 0.00003	eltime:  2.69059
# epoch: 53	train_loss: 0.00003	dev_loss: 0.00003	eltime:  2.75139
# epoch: 54	train_loss: 0.00003	dev_loss: 0.00003	eltime:  2.79508
# epoch: 55	train_loss: 0.00002	dev_loss: 0.00003	eltime:  2.84045
# epoch: 56	train_loss: 0.00003	dev_loss: 0.00003	eltime:  2.89138
# epoch: 57	train_loss: 0.00002	dev_loss: 0.00003	eltime:  2.94141
# epoch: 58	train_loss: 0.00003	dev_loss: 0.00002	eltime:  2.99310
# epoch: 59	train_loss: 0.00002	dev_loss: 0.00003	eltime:  3.04063
# epoch: 60	train_loss: 0.00003	dev_loss: 0.00002	eltime:  3.09577
# epoch: 61	train_loss: 0.00002	dev_loss: 0.00002	eltime:  3.13724
# epoch: 62	train_loss: 0.00002	dev_loss: 0.00002	eltime:  3.17790
# epoch: 63	train_loss: 0.00002	dev_loss: 0.00002	eltime:  3.23580
# epoch: 64	train_loss: 0.00003	dev_loss: 0.00002	eltime:  3.29688
# epoch: 65	train_loss: 0.00002	dev_loss: 0.00002	eltime:  3.36139
# epoch: 66	train_loss: 0.00002	dev_loss: 0.00002	eltime:  3.42645
# epoch: 67	train_loss: 0.00002	dev_loss: 0.00002	eltime:  3.48035
# epoch: 68	train_loss: 0.00002	dev_loss: 0.00002	eltime:  3.52993
# epoch: 69	train_loss: 0.00001	dev_loss: 0.00002	eltime:  3.58402
# epoch: 70	train_loss: 0.00001	dev_loss: 0.00002	eltime:  3.64778
# epoch: 71	train_loss: 0.00001	dev_loss: 0.00002	eltime:  3.70946
# epoch: 72	train_loss: 0.00001	dev_loss: 0.00002	eltime:  3.77194
# epoch: 73	train_loss: 0.00001	dev_loss: 0.00002	eltime:  3.83296
# epoch: 74	train_loss: 0.00001	dev_loss: 0.00002	eltime:  3.89420
# epoch: 75	train_loss: 0.00001	dev_loss: 0.00001	eltime:  3.95486
# epoch: 76	train_loss: 0.00002	dev_loss: 0.00001	eltime:  3.99647
# epoch: 77	train_loss: 0.00002	dev_loss: 0.00001	eltime:  4.04468
# epoch: 78	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.08572
# epoch: 79	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.12862
# epoch: 80	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.16945
# epoch: 81	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.21876
# epoch: 82	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.26077
# epoch: 83	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.31208
# epoch: 84	train_loss: 0.00001	dev_loss: 0.00002	eltime:  4.35295
# epoch: 85	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.39371
# epoch: 86	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.44470
# epoch: 87	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.49157
# epoch: 88	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.53450
# epoch: 89	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.58245
# epoch: 90	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.64459
# epoch: 91	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.70931
# epoch: 92	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.76210
# epoch: 93	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.80083
# epoch: 94	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.83328
# epoch: 95	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.88204
# epoch: 96	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.92979
# epoch: 97	train_loss: 0.00001	dev_loss: 0.00001	eltime:  4.98896
# epoch: 98	train_loss: 0.00001	dev_loss: 0.00001	eltime:  5.04925
# epoch: 99	train_loss: 0.00001	dev_loss: 0.00001	eltime:  5.11355
# epoch: 100	train_loss: 0.00000	dev_loss: 0.00001	eltime:  5.16488
# epoch: 101	train_loss: 0.00001	dev_loss: 0.00000	eltime:  5.19477
# epoch: 102	train_loss: 0.00000	dev_loss: 0.00000	eltime:  5.24862
# epoch: 103	train_loss: 0.00000	dev_loss: 0.00001	eltime:  5.28548
# epoch: 104	train_loss: 0.00001	dev_loss: 0.00001	eltime:  5.32841
# epoch: 105	train_loss: 0.00001	dev_loss: 0.00001	eltime:  5.38402
# epoch: 106	train_loss: 0.00001	dev_loss: 0.00000	eltime:  5.46102
# epoch: 107	train_loss: 0.00000	dev_loss: 0.00001	eltime:  5.52728
# epoch: 108	train_loss: 0.00000	dev_loss: 0.00001	eltime:  5.59249
# epoch: 109	train_loss: 0.00001	dev_loss: 0.00000	eltime:  5.64435
# epoch: 110	train_loss: 0.00001	dev_loss: 0.00001	eltime:  5.67787
# epoch: 111	train_loss: 0.00001	dev_loss: 0.00001	eltime:  5.72769
# epoch: 112	train_loss: 0.00000	dev_loss: 0.00001	eltime:  5.77824
# epoch: 113	train_loss: 0.00000	dev_loss: 0.00001	eltime:  5.83336
# epoch: 114	train_loss: 0.00001	dev_loss: 0.00000	eltime:  5.87437
# epoch: 115	train_loss: 0.00001	dev_loss: 0.00001	eltime:  5.91516
# epoch: 116	train_loss: 0.00001	dev_loss: 0.00001	eltime:  5.95982
# epoch: 117	train_loss: 0.00000	dev_loss: 0.00000	eltime:  6.00161
# epoch: 118	train_loss: 0.00000	dev_loss: 0.00001	eltime:  6.05417
# epoch: 119	train_loss: 0.00000	dev_loss: 0.00000	eltime:  6.10826
# epoch: 120	train_loss: 0.00000	dev_loss: 0.00000	eltime:  6.14636
# epoch: 121	train_loss: 0.00000	dev_loss: 0.00000	eltime:  6.18261
# epoch: 122	train_loss: 0.00001	dev_loss: 0.00000	eltime:  6.23578
# epoch: 123	train_loss: 0.00000	dev_loss: 0.00000	eltime:  6.30346
# epoch: 124	train_loss: 0.00000	dev_loss: 0.00001	eltime:  6.36386
# epoch: 125	train_loss: 0.00000	dev_loss: 0.00001	eltime:  6.41231
# epoch: 126	train_loss: 0.00001	dev_loss: 0.00001	eltime:  6.46343
# epoch: 127	train_loss: 0.00000	dev_loss: 0.00001	eltime:  6.49469
# epoch: 128	train_loss: 0.00001	dev_loss: 0.00000	eltime:  6.54428
# epoch: 129	train_loss: 0.00001	dev_loss: 0.00000	eltime:  6.57998
# epoch: 130	train_loss: 0.00001	dev_loss: 0.00001	eltime:  6.62744
# epoch: 131	train_loss: 0.00000	dev_loss: 0.00001	eltime:  6.67614
# epoch: 132	train_loss: 0.00001	dev_loss: 0.00001	eltime:  6.73731
# epoch: 133	train_loss: 0.00001	dev_loss: 0.00000	eltime:  6.79647
# epoch: 134	train_loss: 0.00001	dev_loss: 0.00001	eltime:  6.85361
# epoch: 135	train_loss: 0.00001	dev_loss: 0.00001	eltime:  6.89497
# epoch: 136	train_loss: 0.00001	dev_loss: 0.00000	eltime:  6.94457
# epoch: 137	train_loss: 0.00000	dev_loss: 0.00001	eltime:  6.97752
# epoch: 138	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.03608
# epoch: 139	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.07750
# epoch: 140	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.12438
# epoch: 141	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.16707
# epoch: 142	train_loss: 0.00001	dev_loss: 0.00000	eltime:  7.22027
# epoch: 143	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.28833
# epoch: 144	train_loss: 0.00001	dev_loss: 0.00000	eltime:  7.34881
# epoch: 145	train_loss: 0.00000	dev_loss: 0.00001	eltime:  7.41288
# epoch: 146	train_loss: 0.00001	dev_loss: 0.00001	eltime:  7.46977
# epoch: 147	train_loss: 0.00001	dev_loss: 0.00000	eltime:  7.51901
# epoch: 148	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.56512
# epoch: 149	train_loss: 0.00001	dev_loss: 0.00001	eltime:  7.60974
# epoch: 150	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.65380
# epoch: 151	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.70012
# epoch: 152	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.74674
# epoch: 153	train_loss: 0.00000	dev_loss: 0.00001	eltime:  7.79139
# epoch: 154	train_loss: 0.00001	dev_loss: 0.00001	eltime:  7.84681
# epoch: 155	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.90845
# epoch: 156	train_loss: 0.00000	dev_loss: 0.00000	eltime:  7.96628
# epoch: 157	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.01970
# epoch: 158	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.07775
# epoch: 159	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.13592
# epoch: 160	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.19370
# epoch: 161	train_loss: 0.00001	dev_loss: 0.00000	eltime:  8.24192
# epoch: 162	train_loss: 0.00001	dev_loss: 0.00000	eltime:  8.28465
# epoch: 163	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.31648
# epoch: 164	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.36915
# epoch: 165	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.42824
# epoch: 166	train_loss: 0.00000	dev_loss: 0.00001	eltime:  8.49844
# epoch: 167	train_loss: 0.00000	dev_loss: 0.00001	eltime:  8.56098
# epoch: 168	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.62145
# epoch: 169	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.66915
# epoch: 170	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.72423
# epoch: 171	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.77511
# epoch: 172	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.82699
# epoch: 173	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.86545
# epoch: 174	train_loss: 0.00001	dev_loss: 0.00000	eltime:  8.91818
# epoch: 175	train_loss: 0.00000	dev_loss: 0.00000	eltime:  8.95984
# epoch: 176	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.00089
# epoch: 177	train_loss: 0.00001	dev_loss: 0.00000	eltime:  9.05999
# epoch: 178	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.11244
# epoch: 179	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.16299
# epoch: 180	train_loss: 0.00001	dev_loss: 0.00001	eltime:  9.21403
# epoch: 181	train_loss: 0.00001	dev_loss: 0.00001	eltime:  9.25443
# epoch: 182	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.31253
# epoch: 183	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.35684
# epoch: 184	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.41399
# epoch: 185	train_loss: 0.00001	dev_loss: 0.00000	eltime:  9.46902
# epoch: 186	train_loss: 0.00000	dev_loss: 0.00001	eltime:  9.52000
# epoch: 187	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.58933
# epoch: 188	train_loss: 0.00001	dev_loss: 0.00000	eltime:  9.63333
# epoch: 189	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.68007
# epoch: 190	train_loss: 0.00000	dev_loss: 0.00001	eltime:  9.73864
# epoch: 191	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.79686
# epoch: 192	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.85745
# epoch: 193	train_loss: 0.00000	dev_loss: 0.00001	eltime:  9.89589
# epoch: 194	train_loss: 0.00001	dev_loss: 0.00000	eltime:  9.93876
# epoch: 195	train_loss: 0.00000	dev_loss: 0.00000	eltime:  9.97969
# epoch: 196	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.02399
# epoch: 197	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.06919
# epoch: 198	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.11303
# epoch: 199	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.15371
# epoch: 200	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.19453
# epoch: 201	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.23711
# epoch: 202	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.28782
# epoch: 203	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.34520
# epoch: 204	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.39623
# epoch: 205	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.44001
# epoch: 206	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.48414
# epoch: 207	train_loss: 0.00000	dev_loss: 0.00001	eltime:  10.53009
# epoch: 208	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.59609
# epoch: 209	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.64607
# epoch: 210	train_loss: 0.00001	dev_loss: 0.00000	eltime:  10.69528
# epoch: 211	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.74450
# epoch: 212	train_loss: 0.00001	dev_loss: 0.00000	eltime:  10.79604
# epoch: 213	train_loss: 0.00000	dev_loss: 0.00000	eltime:  10.84430
# epoch: 214	train_loss: 0.00000	dev_loss: 0.00001	eltime:  10.88772
# epoch: 215	train_loss: 0.00001	dev_loss: 0.00000	eltime:  10.94737
# epoch: 216	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.00839
# epoch: 217	train_loss: 0.00001	dev_loss: 0.00000	eltime:  11.06028
# epoch: 218	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.11303
# epoch: 219	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.16531
# epoch: 220	train_loss: 0.00001	dev_loss: 0.00000	eltime:  11.22252
# epoch: 221	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.27968
# epoch: 222	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.32896
# epoch: 223	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.38255
# epoch: 224	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.42998
# epoch: 225	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.48114
# epoch: 226	train_loss: 0.00001	dev_loss: 0.00000	eltime:  11.54491
# epoch: 227	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.59481
# epoch: 228	train_loss: 0.00000	dev_loss: 0.00001	eltime:  11.64055
# epoch: 229	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.68301
# epoch: 230	train_loss: 0.00000	dev_loss: 0.00001	eltime:  11.73408
# epoch: 231	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.78845
# epoch: 232	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.84566
# epoch: 233	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.89432
# epoch: 234	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.94026
# epoch: 235	train_loss: 0.00000	dev_loss: 0.00000	eltime:  11.98913
# epoch: 236	train_loss: 0.00000	dev_loss: 0.00001	eltime:  12.02951
# epoch: 237	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.07974
# epoch: 238	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.12612
# epoch: 239	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.17036
# epoch: 240	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.21339
# epoch: 241	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.25428
# epoch: 242	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.30345
# epoch: 243	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.35111
# epoch: 244	train_loss: 0.00000	dev_loss: 0.00001	eltime:  12.40788
# epoch: 245	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.45195
# epoch: 246	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.50754
# epoch: 247	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.55142
# epoch: 248	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.59179
# epoch: 249	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.64220
# epoch: 250	train_loss: 0.00001	dev_loss: 0.00000	eltime:  12.69883
# epoch: 251	train_loss: 0.00000	dev_loss: 0.00001	eltime:  12.76399
# epoch: 252	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.81769
# epoch: 253	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.88200
# epoch: 254	train_loss: 0.00000	dev_loss: 0.00000	eltime:  12.94413
# epoch: 255	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.00149
# epoch: 256	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.06113
# epoch: 257	train_loss: 0.00001	dev_loss: 0.00000	eltime:  13.09948
# epoch: 258	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.14186
# epoch: 259	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.19718
# epoch: 260	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.23373
# epoch: 261	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.27499
# epoch: 262	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.31453
# epoch: 263	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.35485
# epoch: 264	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.40571
# epoch: 265	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.46482
# epoch: 266	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.52760
# epoch: 267	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.58203
# epoch: 268	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.64385
# epoch: 269	train_loss: 0.00001	dev_loss: 0.00000	eltime:  13.69852
# epoch: 270	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.74124
# epoch: 271	train_loss: 0.00001	dev_loss: 0.00000	eltime:  13.78163
# epoch: 272	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.82203
# epoch: 273	train_loss: 0.00000	dev_loss: 0.00001	eltime:  13.86248
# epoch: 274	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.90293
# epoch: 275	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.95194
# epoch: 276	train_loss: 0.00000	dev_loss: 0.00000	eltime:  13.99377
# epoch: 277	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.03444
# epoch: 278	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.07508
# epoch: 279	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.11626
# epoch: 280	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.15684
# epoch: 281	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.20766
# epoch: 282	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.26766
# epoch: 283	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.30944
# epoch: 284	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.36887
# epoch: 285	train_loss: 0.00000	dev_loss: 0.00001	eltime:  14.41739
# epoch: 286	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.45271
# epoch: 287	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.49321
# epoch: 288	train_loss: 0.00001	dev_loss: 0.00000	eltime:  14.54403
# epoch: 289	train_loss: 0.00000	dev_loss: 0.00001	eltime:  14.58434
# epoch: 290	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.62466
# epoch: 291	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.66593
# epoch: 292	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.71404
# epoch: 293	train_loss: 0.00001	dev_loss: 0.00000	eltime:  14.75702
# epoch: 294	train_loss: 0.00000	dev_loss: 0.00001	eltime:  14.79801
# epoch: 295	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.83888
# epoch: 296	train_loss: 0.00000	dev_loss: 0.00001	eltime:  14.87976
# epoch: 297	train_loss: 0.00001	dev_loss: 0.00000	eltime:  14.92244
# epoch: 298	train_loss: 0.00000	dev_loss: 0.00000	eltime:  14.96659
# epoch: 299	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.00286
# epoch: 300	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.04126
# epoch: 301	train_loss: 0.00000	dev_loss: 0.00001	eltime:  15.07379
# epoch: 302	train_loss: 0.00001	dev_loss: 0.00000	eltime:  15.11451
# epoch: 303	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.16719
# epoch: 304	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.20604
# epoch: 305	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.24660
# epoch: 306	train_loss: 0.00001	dev_loss: 0.00000	eltime:  15.29657
# epoch: 307	train_loss: 0.00001	dev_loss: 0.00000	eltime:  15.35970
# epoch: 308	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.42048
# epoch: 309	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.48726
# epoch: 310	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.54187
# epoch: 311	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.58017
# epoch: 312	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.63434
# epoch: 313	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.68275
# epoch: 314	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.73338
# epoch: 315	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.78397
# epoch: 316	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.82482
# epoch: 317	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.87557
# epoch: 318	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.91631
# epoch: 319	train_loss: 0.00000	dev_loss: 0.00000	eltime:  15.98440
# epoch: 320	train_loss: 0.00000	dev_loss: 0.00001	eltime:  16.04486
# epoch: 321	train_loss: 0.00001	dev_loss: 0.00001	eltime:  16.11047
# epoch: 322	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.16057
# epoch: 323	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.20909
# epoch: 324	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.26345
# epoch: 325	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.30076
# epoch: 326	train_loss: 0.00001	dev_loss: 0.00000	eltime:  16.35569
# epoch: 327	train_loss: 0.00001	dev_loss: 0.00001	eltime:  16.41283
# epoch: 328	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.47719
# epoch: 329	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.54713
# epoch: 330	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.62243
# epoch: 331	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.67781
# epoch: 332	train_loss: 0.00000	dev_loss: 0.00001	eltime:  16.72829
# epoch: 333	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.77585
# epoch: 334	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.80782
# epoch: 335	train_loss: 0.00000	dev_loss: 0.00001	eltime:  16.87659
# epoch: 336	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.93242
# epoch: 337	train_loss: 0.00000	dev_loss: 0.00000	eltime:  16.97635
# epoch: 338	train_loss: 0.00000	dev_loss: 0.00001	eltime:  17.02384
# epoch: 339	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.07834
# epoch: 340	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.11984
# epoch: 341	train_loss: 0.00001	dev_loss: 0.00000	eltime:  17.17082
# epoch: 342	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.22301
# epoch: 343	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.27283
# epoch: 344	train_loss: 0.00001	dev_loss: 0.00000	eltime:  17.32594
# epoch: 345	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.37591
# epoch: 346	train_loss: 0.00001	dev_loss: 0.00000	eltime:  17.41638
# epoch: 347	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.46806
# epoch: 348	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.51953
# epoch: 349	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.57109
# epoch: 350	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.61147
# epoch: 351	train_loss: 0.00001	dev_loss: 0.00000	eltime:  17.66238
# epoch: 352	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.71280
# epoch: 353	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.76179
# epoch: 354	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.81470
# epoch: 355	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.87106
# epoch: 356	train_loss: 0.00000	dev_loss: 0.00000	eltime:  17.93928
# epoch: 357	train_loss: 0.00001	dev_loss: 0.00000	eltime:  18.00544
# epoch: 358	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.06088
# epoch: 359	train_loss: 0.00001	dev_loss: 0.00000	eltime:  18.11844
# epoch: 360	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.16915
# epoch: 361	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.21996
# epoch: 362	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.25063
# epoch: 363	train_loss: 0.00001	dev_loss: 0.00000	eltime:  18.30554
# epoch: 364	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.36376
# epoch: 365	train_loss: 0.00001	dev_loss: 0.00000	eltime:  18.42734
# epoch: 366	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.49241
# epoch: 367	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.55579
# epoch: 368	train_loss: 0.00001	dev_loss: 0.00001	eltime:  18.61054
# epoch: 369	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.65896
# epoch: 370	train_loss: 0.00001	dev_loss: 0.00000	eltime:  18.70973
# epoch: 371	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.75984
# epoch: 372	train_loss: 0.00001	dev_loss: 0.00001	eltime:  18.82748
# epoch: 373	train_loss: 0.00000	dev_loss: 0.00000	eltime:  18.90032
# epoch: 374	train_loss: 0.00000	dev_loss: 0.00001	eltime:  18.96051
# epoch: 375	train_loss: 0.00000	dev_loss: 0.00001	eltime:  19.00461
# epoch: 376	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.05852
# epoch: 377	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.11544
# epoch: 378	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.15731
# epoch: 379	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.20592
# epoch: 380	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.25555
# epoch: 381	train_loss: 0.00000	dev_loss: 0.00001	eltime:  19.29907
# epoch: 382	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.35089
# epoch: 383	train_loss: 0.00000	dev_loss: 0.00001	eltime:  19.39135
# epoch: 384	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.44208
# epoch: 385	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.49108
# epoch: 386	train_loss: 0.00000	dev_loss: 0.00001	eltime:  19.54372
# epoch: 387	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.59700
# epoch: 388	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.65579
# epoch: 389	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.72270
# epoch: 390	train_loss: 0.00000	dev_loss: 0.00001	eltime:  19.78881
# epoch: 391	train_loss: 0.00000	dev_loss: 0.00000	eltime:  19.84426
# Early stopping!!!
# <All keys matched successfully>

# %% [markdown]
# ## Parameter estimation results

# %%
# update the rollout length based on the test data
dynamics_model.nsteps = test_data['X'].shape[1]

# %%
# Test set results
test_outputs = dynamics_model(test_data)

pred_traj = test_outputs['xn'][:, :-1, :]
true_traj = test_data['X']
pred_traj = pred_traj.detach().numpy().reshape(-1, nx)
true_traj = true_traj.detach().numpy().reshape(-1, nx)
pred_traj, true_traj = pred_traj.transpose(1, 0), true_traj.transpose(1, 0)

# %%
# plot rollout
figsize = 25
fig, ax = plt.subplots(nx, figsize=(figsize, figsize))
labels = [f'$y_{k}$' for k in range(len(true_traj))]
for row, (t1, t2, label) in enumerate(zip(true_traj, pred_traj, labels)):
    if nx > 1:
        axe = ax[row]
    else:
        axe = ax
    axe.set_ylabel(label, rotation=0, labelpad=20, fontsize=figsize)
    axe.plot(t1, 'c', linewidth=4.0, label='True')
    axe.plot(t2, 'm--', linewidth=4.0, label='Pred')
    axe.tick_params(labelbottom=False, labelsize=figsize)
axe.tick_params(labelbottom=True, labelsize=figsize)
axe.legend(fontsize=figsize)
axe.set_xlabel('$time$', fontsize=figsize)
plt.tight_layout()
