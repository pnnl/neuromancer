# %%
from neuromancer import dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f9d543c16571> in <module>
# ----> 1 from neuromancer import dataset
#
# ModuleNotFoundError: No module named 'neuromancer'

# %%
# loading arbitrary data from a CSV file
data = dataset.read_file("../../../psl/psl/datasets/EED_building/EED_building.csv")

# %%
train, val, test = dataset.split_data(data)

# %%
train, stats = dataset.normalize_data(train, "zscore")
val, _ = dataset.normalize_data(val, "zscore", stats=stats)
test, _ = dataset.normalize_data(test, "zscore", stats=stats)

# %%
train_dset = dataset.SequenceDataset(train, nsteps=16)

# %%
nstep, loop, dims = dataset.get_sequence_dataloaders(data, 16, norm_type="zscore")

# %%
train_nstep, val_nstep, test_nstep = nstep

# %%
next(iter(train_nstep))
# Out:
# {'Yp': tensor([[[ 1.7550,  1.6387,  1.7318,  ...,  1.5433,  1.1727,  0.8076],
#           [ 1.6011,  1.5037,  1.7318,  ...,  1.1060,  0.6424,  0.8594],
#           [ 0.8854,  0.2476,  0.6388,  ...,  0.4899,  0.6424,  0.2980],
#           ...,
#           [ 0.2673, -0.0579,  0.5163,  ...,  0.7523,  0.9488,  0.2491],
#           [ 0.0313, -0.3107,  0.5929,  ...,  0.8055,  1.3524, -0.1165],
#           [ 0.0493, -0.1401,  0.7444,  ...,  0.4937,  0.7985,  0.4074]],
#
#          [[ 1.7550,  1.6294,  1.7318,  ...,  1.5205,  1.1521,  0.8968],
#           [ 1.5703,  1.4696,  1.7318,  ...,  1.0375,  0.6100,  0.8594],
#           [ 0.9085,  0.2879,  0.8317,  ...,  0.4633,  0.6483,  0.1915],
#           ...,
#           [ 0.2981, -0.1091,  0.3831,  ...,  0.7599,  0.9694,  0.1282],
#           [ 0.0467, -0.3107,  0.6755,  ...,  0.8017,  1.4232, -0.1856],
#           [ 0.0929, -0.0812,  0.8041,  ...,  0.4861,  0.6601,  0.5168]],
#
#          [[ 1.7550,  1.6201,  1.7318,  ...,  1.5015,  1.1108,  0.9083],
#           [ 1.5805,  1.4572,  1.7318,  ...,  0.9957,  0.6070,  0.8076],
#           [ 0.9085,  0.2724,  0.9526,  ...,  0.4481,  0.7190,  0.1858],
#           ...,
#           [ 0.2493, -0.1556,  0.4168,  ...,  0.7827,  1.0843,  0.0418],
#           [ 0.0698, -0.3014,  0.7306,  ...,  0.8208,  1.4408, -0.2662],
#           [ 0.1006, -0.0052,  0.8133,  ...,  0.4519,  0.6453,  0.5485]],
#
#          ...,
#
#          [[ 1.6652,  1.5472,  1.7318,  ...,  1.1440,  0.7426,  0.8939],
#           [ 0.9265,  0.4104,  0.8133,  ...,  0.5089,  0.5599,  0.6118],
#           [ 0.7264,  0.2972,  0.7214,  ...,  0.9653,  1.0077,  0.3009],
#           ...,
#           [ 0.0082, -0.3448,  0.4260,  ...,  0.8284,  1.2081, -0.0129],
#           [-0.0302, -0.4689,  0.4719,  ...,  0.5127,  0.8781, -0.3353],
#           [ 0.2263,  0.3174,  0.9281,  ...,  0.4138,  0.3743,  0.6348]],
#
#          [[ 1.6088,  1.5037,  1.7318,  ...,  1.1402,  0.6542,  0.8709],
#           [ 0.9316,  0.3732,  0.7658,  ...,  0.5431,  0.5864,  0.4506],
#           [ 0.7264,  0.3391,  0.7061,  ...,  0.9957,  0.9694,  0.4736],
#           ...,
#           [ 0.0108, -0.3107,  0.5025,  ...,  0.8436,  1.2228, -0.0186],
#           [ 0.0159, -0.2812,  0.6633,  ...,  0.5051,  0.8663, -0.0560],
#           [ 0.2519,  0.3174,  0.9281,  ...,  0.4177,  0.3654,  0.6233]],
#
#          [[ 1.6190,  1.5037,  1.7318,  ...,  1.1288,  0.6453,  0.8363],
#           [ 0.9008,  0.2895,  0.5745,  ...,  0.5089,  0.6159,  0.3326],
#           [ 0.7187,  0.3639,  0.6755,  ...,  1.0033,  0.9547,  0.5254],
#           ...,
#           [ 0.0236, -0.3107,  0.5607,  ...,  0.8208,  1.2523, -0.0992],
#           [ 0.0236, -0.1897,  0.7352,  ...,  0.5051,  0.8663,  0.2203],
#           [ 0.2288,  0.3205,  0.9281,  ...,  0.3796,  0.3242,  0.5485]]]),
#  'Up': tensor([[[-0.0801,  0.7969,  0.3364,  ..., -0.7268,  0.4797, -0.7499],
#           [-0.2230,  0.4132,  0.3119,  ..., -0.7268,  0.4181, -0.7499],
#           [-1.0374, -0.7253, -0.9153,  ...,  1.5145,  0.8588,  1.2575],
#           ...,
#           [-1.4034, -1.2348, -1.3996,  ...,  1.3965,  0.6813,  1.2867],
#           [-0.9410, -0.5539, -0.6679,  ...,  1.2140,  0.3792,  0.9948],
#           [-0.7826, -0.3620, -0.3875,  ..., -0.7268,  0.3397,  0.4020]],
#
#          [[-0.0919,  0.7678,  0.3403,  ..., -0.7268,  0.3618, -0.7499],
#           [-0.2351,  0.3862,  0.3060,  ..., -0.7268,  0.7590, -0.7499],
#           [-1.0469, -0.6831, -0.7557,  ...,  1.2510,  0.3799,  1.0060],
#           ...,
#           [-1.4220, -1.2836, -1.4320,  ...,  1.1755,  0.3316,  1.1609],
#           [-0.9410, -0.5532, -0.6679,  ...,  1.4377,  0.7202,  1.2193],
#           [-0.7530, -0.3647, -0.3261,  ..., -0.6719,  0.4562,  0.1124]],
#
#          [[-0.1023,  0.7388,  0.3416,  ..., -0.7268,  0.8059, -0.7499],
#           [-0.2403,  0.3723,  0.3020,  ..., -0.7268,  0.3457, -0.7499],
#           [-1.4042, -1.2408, -1.2723,  ...,  1.1989,  0.3832,  1.0015],
#           ...,
#           [-1.4190, -1.2882, -1.4333,  ...,  1.3526,  0.4871,  1.5112],
#           [-0.9332, -0.5433, -0.6679,  ...,  1.3224,  0.4321,  1.0397],
#           [-0.7287, -0.3522, -0.3287,  ..., -0.7268,  0.8367, -0.1818]],
#
#          ...,
#
#          [[-0.1882,  0.4837,  0.3258,  ..., -0.6692,  0.4288, -0.7499],
#           [-1.1737, -0.9224, -1.0684,  ...,  1.4775,  0.7925,  1.2126],
#           [-1.5329, -1.3693, -1.4683,  ...,  1.1975,  0.3531,  1.0015],
#           ...,
#           [-0.9488, -0.5466, -0.7015,  ...,  1.2057,  0.3296,  1.0060],
#           [-0.9449, -0.5657, -0.7134,  ..., -0.7268,  0.7054,  0.5524],
#           [-0.6306, -0.2111, -0.1374,  ..., -0.7268,  0.6311, -0.7499]],
#
#          [[-0.2017,  0.4527,  0.3119,  ..., -0.7268,  0.7764, -0.7499],
#           [-1.2345, -0.9672, -1.1285,  ...,  1.2455,  0.3558,  0.9813],
#           [-1.5162, -1.3608, -1.4656,  ...,  1.2510,  0.4341,  1.0464],
#           ...,
#           [-0.9393, -0.5506, -0.6778,  ...,  1.4143,  0.7483,  1.2193],
#           [-0.8707, -0.4629, -0.6019,  ..., -0.7268,  0.3517,  0.6535],
#           [-0.6276, -0.1926, -0.1334,  ..., -0.6692,  0.3243, -0.7499]],
#
#          [[-0.2121,  0.4310,  0.3119,  ..., -0.7268,  0.3203, -0.7499],
#           [-1.4351, -1.2777, -1.4029,  ...,  1.2112,  0.3779,  1.0038],
#           [-1.5093, -1.3667, -1.4557,  ...,  1.4720,  0.8059,  1.1946],
#           ...,
#           [-0.9289, -0.5367, -0.6587,  ...,  1.2359,  0.3826,  1.0554],
#           [-0.8186, -0.4003, -0.5142,  ..., -0.7268,  0.7825,  0.7882],
#           [-0.6280, -0.1939, -0.1301,  ..., -0.7268,  0.6740, -0.7499]]]),
#  'Dp': tensor([[[0.9848],
#           [0.7470],
#           [1.0216],
#           ...,
#           [0.9194],
#           [1.1224],
#           [0.8873]],
#
#          [[0.9652],
#           [0.7510],
#           [1.0620],
#           ...,
#           [0.9396],
#           [1.1041],
#           [0.8866]],
#
#          [[0.9445],
#           [0.7362],
#           [1.1005],
#           ...,
#           [0.9667],
#           [1.0973],
#           [0.8749]],
#
#          ...,
#
#          [[0.7655],
#           [0.9334],
#           [1.5461],
#           ...,
#           [1.0801],
#           [0.9515],
#           [0.7648]],
#
#          [[0.7773],
#           [0.9602],
#           [1.5741],
#           ...,
#           [1.0920],
#           [0.9302],
#           [0.7402]],
#
#          [[0.7644],
#           [0.9925],
#           [1.6163],
#           ...,
#           [1.1157],
#           [0.9055],
#           [0.7159]]]),
#  'Yf': tensor([[[ 1.6011,  1.5037,  1.7318,  ...,  1.1060,  0.6424,  0.8594],
#           [ 0.8854,  0.2476,  0.6388,  ...,  0.4899,  0.6424,  0.2980],
#           [ 0.7162,  0.3856,  0.6449,  ...,  1.0337,  0.9547,  0.4420],
#           ...,
#           [ 0.0313, -0.3107,  0.5929,  ...,  0.8055,  1.3524, -0.1165],
#           [ 0.0493, -0.1401,  0.7444,  ...,  0.4937,  0.7985,  0.4074],
#           [ 0.2237,  0.3608,  0.9312,  ...,  0.3454,  0.3183,  0.6176]],
#
#          [[ 1.5703,  1.4696,  1.7318,  ...,  1.0375,  0.6100,  0.8594],
#           [ 0.9085,  0.2879,  0.8317,  ...,  0.4633,  0.6483,  0.1915],
#           [ 0.7187,  0.4228,  0.6296,  ...,  1.0641,  0.9547,  0.5053],
#           ...,
#           [ 0.0467, -0.3107,  0.6755,  ...,  0.8017,  1.4232, -0.1856],
#           [ 0.0929, -0.0812,  0.8041,  ...,  0.4861,  0.6601,  0.5168],
#           [ 0.2391,  0.3639,  0.9587,  ...,  0.3416,  0.3271,  0.6348]],
#
#          [[ 1.5805,  1.4572,  1.7318,  ...,  0.9957,  0.6070,  0.8076],
#           [ 0.9085,  0.2724,  0.9526,  ...,  0.4481,  0.7190,  0.1858],
#           [ 0.7290,  0.4802,  0.6204,  ...,  1.0908,  0.9783,  0.4823],
#           ...,
#           [ 0.0698, -0.3014,  0.7306,  ...,  0.8208,  1.4408, -0.2662],
#           [ 0.1006, -0.0052,  0.8133,  ...,  0.4519,  0.6453,  0.5485],
#           [ 0.2186,  0.3639,  0.9740,  ...,  0.3188,  0.3213,  0.6348]],
#
#          ...,
#
#          [[ 0.9265,  0.4104,  0.8133,  ...,  0.5089,  0.5599,  0.6118],
#           [ 0.7264,  0.2972,  0.7214,  ...,  0.9653,  1.0077,  0.3009],
#           [ 0.9650,  1.3052,  0.7214,  ...,  2.0111,  1.5970,  0.5485],
#           ...,
#           [-0.0302, -0.4689,  0.4719,  ...,  0.5127,  0.8781, -0.3353],
#           [ 0.2263,  0.3174,  0.9281,  ...,  0.4138,  0.3743,  0.6348],
#           [ 0.2545,  0.3639,  0.9970,  ...,  0.1172,  0.1327,  0.6003]],
#
#          [[ 0.9316,  0.3732,  0.7658,  ...,  0.5431,  0.5864,  0.4506],
#           [ 0.7264,  0.3391,  0.7061,  ...,  0.9957,  0.9694,  0.4736],
#           [ 0.9675,  1.2525,  0.7352,  ...,  2.0301,  1.4880,  0.5485],
#           ...,
#           [ 0.0159, -0.2812,  0.6633,  ...,  0.5051,  0.8663, -0.0560],
#           [ 0.2519,  0.3174,  0.9281,  ...,  0.4177,  0.3654,  0.6233],
#           [ 0.2545,  0.3515,  0.9970,  ...,  0.0982,  0.0973,  0.5686]],
#
#          [[ 0.9008,  0.2895,  0.5745,  ...,  0.5089,  0.6159,  0.3326],
#           [ 0.7187,  0.3639,  0.6755,  ...,  1.0033,  0.9547,  0.5254],
#           [ 0.9957,  1.3115,  0.7812,  ...,  1.9578,  1.4791,  0.6176],
#           ...,
#           [ 0.0236, -0.1897,  0.7352,  ...,  0.5051,  0.8663,  0.2203],
#           [ 0.2288,  0.3205,  0.9281,  ...,  0.3796,  0.3242,  0.5485],
#           [ 0.2493,  0.3639,  0.9970,  ...,  0.0830,  0.0738,  0.4995]]]),
#  'Uf': tensor([[[-0.2230,  0.4132,  0.3119,  ..., -0.7268,  0.4181, -0.7499],
#           [-1.0374, -0.7253, -0.9153,  ...,  1.5145,  0.8588,  1.2575],
#           [-1.5197, -1.3891, -1.4762,  ...,  1.1947,  0.3142,  0.9746],
#           ...,
#           [-0.9410, -0.5539, -0.6679,  ...,  1.2140,  0.3792,  0.9948],
#           [-0.7826, -0.3620, -0.3875,  ..., -0.7268,  0.3397,  0.4020],
#           [-0.6293, -0.2131, -0.1209,  ..., -0.7268,  0.4623, -0.7499]],
#
#          [[-0.2351,  0.3862,  0.3060,  ..., -0.7268,  0.7590, -0.7499],
#           [-1.0469, -0.6831, -0.7557,  ...,  1.2510,  0.3799,  1.0060],
#           [-1.5097, -1.3819, -1.4696,  ...,  1.2661,  0.4750,  1.0666],
#           ...,
#           [-0.9410, -0.5532, -0.6679,  ...,  1.4377,  0.7202,  1.2193],
#           [-0.7530, -0.3647, -0.3261,  ..., -0.6719,  0.4562,  0.1124],
#           [-0.6258, -0.2025, -0.1136,  ..., -0.7268,  0.4395, -0.7499]],
#
#          [[-0.2403,  0.3723,  0.3020,  ..., -0.7268,  0.3457, -0.7499],
#           [-1.4042, -1.2408, -1.2723,  ...,  1.1989,  0.3832,  1.0015],
#           [-1.4941, -1.3621, -1.4570,  ...,  1.4404,  0.7892,  1.1901],
#           ...,
#           [-0.9332, -0.5433, -0.6679,  ...,  1.3224,  0.4321,  1.0397],
#           [-0.7287, -0.3522, -0.3287,  ..., -0.7268,  0.8367, -0.1818],
#           [-0.6289, -0.2256, -0.1136,  ..., -0.6610,  0.8113, -0.7499]],
#
#          ...,
#
#          [[-1.1737, -0.9224, -1.0684,  ...,  1.4775,  0.7925,  1.2126],
#           [-1.5329, -1.3693, -1.4683,  ...,  1.1975,  0.3531,  1.0015],
#           [-1.5106, -1.3733, -1.4399,  ...,  1.3402,  5.0557,  1.0374],
#           ...,
#           [-0.9449, -0.5657, -0.7134,  ..., -0.7268,  0.7054,  0.5524],
#           [-0.6306, -0.2111, -0.1374,  ..., -0.7268,  0.6311, -0.7499],
#           [-0.6280, -0.2289, -0.0813,  ..., -0.7268,  0.7121, -0.7499]],
#
#          [[-1.2345, -0.9672, -1.1285,  ...,  1.2455,  0.3558,  0.9813],
#           [-1.5162, -1.3608, -1.4656,  ...,  1.2510,  0.4341,  1.0464],
#           [-1.3482, -1.1465, -1.3119,  ...,  1.3787,  5.2734,  1.0846],
#           ...,
#           [-0.8707, -0.4629, -0.6019,  ..., -0.7268,  0.3517,  0.6535],
#           [-0.6276, -0.1926, -0.1334,  ..., -0.6692,  0.3243, -0.7499],
#           [-0.6302, -0.2137, -0.0747,  ..., -0.7268,  0.2961, -0.7499]],
#
#          [[-1.4351, -1.2777, -1.4029,  ...,  1.2112,  0.3779,  1.0038],
#           [-1.5093, -1.3667, -1.4557,  ...,  1.4720,  0.8059,  1.1946],
#           [-1.4151, -1.2072, -1.2241,  ...,  1.2400,  5.1796,  1.0038],
#           ...,
#           [-0.8186, -0.4003, -0.5142,  ..., -0.7268,  0.7825,  0.7882],
#           [-0.6280, -0.1939, -0.1301,  ..., -0.7268,  0.6740, -0.7499],
#           [-0.6306, -0.2197, -0.0741,  ..., -0.6733,  0.5815, -0.7499]]]),
#  'Df': tensor([[[0.7470],
#           [1.0216],
#           [1.6553],
#           ...,
#           [1.1224],
#           [0.8873],
#           [0.7070]],
#
#          [[0.7510],
#           [1.0620],
#           [1.7020],
#           ...,
#           [1.1041],
#           [0.8866],
#           [0.7035]],
#
#          [[0.7362],
#           [1.1005],
#           [1.7364],
#           ...,
#           [1.0973],
#           [0.8749],
#           [0.6957]],
#
#          ...,
#
#          [[0.9334],
#           [1.5461],
#           [2.0668],
#           ...,
#           [0.9515],
#           [0.7648],
#           [0.5833]],
#
#          [[0.9602],
#           [1.5741],
#           [2.0805],
#           ...,
#           [0.9302],
#           [0.7402],
#           [0.5821]],
#
#          [[0.9925],
#           [1.6163],
#           [2.0904],
#           ...,
#           [0.9055],
#           [0.7159],
#           [0.5533]]]),
#  'name': 'nstep_train'}
