# %% [markdown]
# # Differentiable Predictive Control (DPC) with NeuroMANCER: Double Integrator
#
# This is an interactive notebook based on the python script `double_integrator_DPC_ol_fixed_ref.py`. The NeuroMANCER toolbox can be used to learn closed-loop control policies with Linear State Space Models (LSSM). We demonstrate by learning to stabilize the unstable double integrator:
#
# $$
# \mathbf{x}_{k+1}=
# \begin{bmatrix}
# 1.2 & 1.0 \\
# 0.0 & 1.0
# \end{bmatrix}
# \mathbf{x}_k+
# \begin{bmatrix}
# 1.0 \\
# 0.5
# \end{bmatrix}
# \mathbf{u}_k
# $$

# %% [markdown]
# ## NeuroMANCER and Dependencies

# %% [markdown]
# ### Install (Colab only)
# Skip this step when running locally.

# %%
# !pip install setuptools==61.0.0 pyts mlflow plum-dispatch torchdiffeq
# !pip install git+https://github.com/pnnl/neuromancer.git@master --ignore-requires-python --no-deps

# %% [markdown]
# ### Import

# %%
from IPython.display import Image
import matplotlib.pyplot as plt
import numpy as np

import torch
from neuromancer import psl, slim

# %%
from neuromancer.activations import activations
from neuromancer import estimators, dynamics
from neuromancer.trainer import Trainer
from neuromancer.problem import Problem
from neuromancer.constraint import variable
from neuromancer import policies
import neuromancer.arg as arg
from neuromancer.dataset import get_sequence_dataloaders
from neuromancer.loss import PenaltyLoss
import neuromancer.simulator as sim

# %% [markdown]
# # Dataset

# %%
device = "cpu"
data_seed = 408  # random seed used for simulated data
np.random.seed(data_seed)
torch.manual_seed(data_seed);

# %%
# problem dimensions
nx = 2
nu = 1
# number of datapoints
nsim = 10000
# prediction horizon
nsteps = 1

# %% [markdown]
# Randomly sample input and output trajectories from a standard normal distribution for training.

# %%
#  we treat states as observables, i.e. Y = X
sequences = {"Y": 3*np.random.randn(nsim, nx)}
nstep_data, loop_data, dims = get_sequence_dataloaders(sequences, nsteps)
train_data, dev_data, test_data = nstep_data
train_loop, dev_loop, test_loop = loop_data

# %% [markdown]
# # System Model and Control Policy

# %%
n_layers = 4    # number of hidden layers
nx_hidden = 20  # hidden layer size

# %% [markdown]
# ## State Estimator

# %%
# Fully observable estimator as identity map: x0 = Yp[-1]
# x_0 = e(Yp)
# Yp = [y_-N, ..., y_0]
estimator = estimators.FullyObservable(
                {**dims, "x0": (nx,)},
                input_keys=["Yp"], name='est')

# %% [markdown]
# ## Control Policy

# %%
# full state feedback control policy
# [u_0, ..., u_N] = p(x_0)
policy = policies.MLPPolicy(
    {estimator.output_keys[0]: (nx,), 'U': (nsim, nu)},
    nsteps=nsteps,
    linear_map=slim.maps['linear'],
    nonlin=activations['relu'],
    hsizes=[nx_hidden] * n_layers,
    input_keys=[estimator.output_keys[0]],
    name='pol',
)

# %% [markdown]
# ## Linear Time-Invariant (LTI) SSM

# %%
# x_k+1 = Ax_k + Bu_k
# y_k+1 = Cx_k+1
A = torch.tensor([[1.2, 1.0],
                  [0.0, 1.0]])
B = torch.tensor([[1.0],
                  [0.5]])
C = torch.tensor([[1.0, 0.0],
                  [0.0, 1.0]])
dynamics_model = dynamics.LinearSSM(A, B, C, name='mod',
                          input_key_map={'x0': estimator.output_keys[0],
                                          'Uf': policy.output_keys[0]})
dynamics_model.requires_grad_(False)  # fix model parameters
# Out:
# mod(Yf, x0_est, U_pred_pol) -> reg_error_mod, X_pred_mod, Y_pred_mod, fU_mod

# %% [markdown]
# # Objectives

# %%
Qx = 5.   # state weight
Qu = 0.1  # control action weight
Qn = 1.   # terminal penalty weight

# %%
u = variable(policy.output_keys[0])
y = variable(dynamics_model.output_keys[2])

# objectives
action_loss = Qu * ((u == 0.) ^ 2)      # control penalty
regulation_loss = Qx * ((y == 0.) ^ 2)  # target position
objectives = [regulation_loss, action_loss]

# set objective names for nicer plot
action_loss.name = "action_loss"
regulation_loss.name = 'state_loss'

# %%
# set objective names for nicer plot
action_loss.name = "action_loss"
regulation_loss.name = 'state_loss'

# %% [markdown]
# # Constraints

# %%
umin = -1.
umax = 1.
xmin = -2.
xmax = 2.
xN_min = -0.1
xN_max = 0.1

Q_con_x = 10.   # state constraints penalty weight
Q_con_u = 100.  # input constraints penalty weight

# %%
# constraints
state_lower_bound_penalty = Q_con_x*(y > xmin)
state_upper_bound_penalty = Q_con_x*(y < xmax)
inputs_lower_bound_penalty = Q_con_u*(u > umin)
inputs_upper_bound_penalty = Q_con_u*(u < umax)
terminal_lower_bound_penalty = Qn*(y[:, [-1], :] > xN_min)
terminal_upper_bound_penalty = Qn*(y[:, [-1], :] < xN_max)
constraints = [
    state_lower_bound_penalty,
    state_upper_bound_penalty,
    inputs_lower_bound_penalty,
    inputs_upper_bound_penalty,
    terminal_lower_bound_penalty,
    terminal_upper_bound_penalty,
]

# set constraint names for nicer plot
state_lower_bound_penalty.name = 'x_min'
state_upper_bound_penalty.name = 'x_max'
inputs_lower_bound_penalty.name = 'u_min'
inputs_upper_bound_penalty.name = 'u_max'
terminal_lower_bound_penalty.name = 'y_N_min'
terminal_upper_bound_penalty.name = 'y_N_max'

# %% [markdown]
# # DPC Problem
# Combine objectives, constraints, and trainable components

# %%
# data (y_k) -> estimator (x_k) -> policy (u_k) -> dynamics (x_k+1, y_k+1)
components = [estimator, policy, dynamics_model]
# create constrained optimization loss
loss = PenaltyLoss(objectives, constraints)
# construct constrained optimization problem
problem = Problem(components, loss)
problem.to(device)
# plot computational graph
problem.plot_graph()

# %%
Image('problem_graph.png')

# %% [markdown]
# # Stabilize the System

# %% [markdown]
# ## Train Control Policy

# %%
lr = 0.001      # step size for gradient descent
epochs = 400    # number of training epochs
warmup = 10     # number of epochs to wait before enacting early stopping policy
patience = 100  # number of epochs with no improvement in eval metric to allow 
                #   before early stopping

# %%
optimizer = torch.optim.AdamW(problem.parameters(), lr=lr)

# define trainer
trainer = Trainer(
    problem,
    train_data,
    dev_data,
    test_data,
    optimizer,
    epochs=epochs,
    patience=patience,
    train_metric="nstep_train_loss",
    dev_metric="nstep_dev_loss",
    test_metric="nstep_test_loss",
    eval_metric='nstep_dev_loss',
    warmup=warmup,
)

# %%
# Train closed-loop control policy
best_model = trainer.train()
best_outputs = trainer.test(best_model)
# Out:
# epoch: 0  nstep_train_loss: 93.78044128417969
# epoch: 1  nstep_train_loss: 93.58987426757812
# epoch: 2  nstep_train_loss: 93.39422607421875
# epoch: 3  nstep_train_loss: 93.192626953125
# epoch: 4  nstep_train_loss: 92.98308563232422
# epoch: 5  nstep_train_loss: 92.76470947265625
# epoch: 6  nstep_train_loss: 92.53855895996094
# epoch: 7  nstep_train_loss: 92.30409240722656
# epoch: 8  nstep_train_loss: 92.05909729003906
# epoch: 9  nstep_train_loss: 91.8035888671875
# epoch: 10  nstep_train_loss: 91.53752136230469
# epoch: 11  nstep_train_loss: 91.26121520996094
# epoch: 12  nstep_train_loss: 90.97489929199219
# epoch: 13  nstep_train_loss: 90.6783447265625
# epoch: 14  nstep_train_loss: 90.37018585205078
# epoch: 15  nstep_train_loss: 90.04766845703125
# epoch: 16  nstep_train_loss: 89.70755767822266
# epoch: 17  nstep_train_loss: 89.34925842285156
# epoch: 18  nstep_train_loss: 88.97285461425781
# epoch: 19  nstep_train_loss: 88.57914733886719
# epoch: 20  nstep_train_loss: 88.16817474365234
# epoch: 21  nstep_train_loss: 87.74230194091797
# epoch: 22  nstep_train_loss: 87.30156707763672
# epoch: 23  nstep_train_loss: 86.8482666015625
# epoch: 24  nstep_train_loss: 86.39036560058594
# epoch: 25  nstep_train_loss: 85.92923736572266
# epoch: 26  nstep_train_loss: 85.45648193359375
# epoch: 27  nstep_train_loss: 84.98692321777344
# epoch: 28  nstep_train_loss: 84.52436065673828
# epoch: 29  nstep_train_loss: 84.07655334472656
# epoch: 30  nstep_train_loss: 83.63916778564453
# epoch: 31  nstep_train_loss: 83.20777130126953
# epoch: 32  nstep_train_loss: 82.76856994628906
# epoch: 33  nstep_train_loss: 82.31908416748047
# epoch: 34  nstep_train_loss: 81.85371398925781
# epoch: 35  nstep_train_loss: 81.37332153320312
# epoch: 36  nstep_train_loss: 80.88536071777344
# epoch: 37  nstep_train_loss: 80.39295959472656
# epoch: 38  nstep_train_loss: 79.89270782470703
# epoch: 39  nstep_train_loss: 79.38328552246094
# epoch: 40  nstep_train_loss: 78.86677551269531
# epoch: 41  nstep_train_loss: 78.34799194335938
# epoch: 42  nstep_train_loss: 77.83245086669922
# epoch: 43  nstep_train_loss: 77.3338851928711
# epoch: 44  nstep_train_loss: 76.87420654296875
# epoch: 45  nstep_train_loss: 76.48383331298828
# epoch: 46  nstep_train_loss: 76.15800476074219
# epoch: 47  nstep_train_loss: 75.88690948486328
# epoch: 48  nstep_train_loss: 75.70187377929688
# epoch: 49  nstep_train_loss: 75.59432983398438
# epoch: 50  nstep_train_loss: 75.56657409667969
# epoch: 51  nstep_train_loss: 75.59114074707031
# epoch: 52  nstep_train_loss: 75.6263427734375
# epoch: 53  nstep_train_loss: 75.64037322998047
# epoch: 54  nstep_train_loss: 75.61631774902344
# epoch: 55  nstep_train_loss: 75.54563903808594
# epoch: 56  nstep_train_loss: 75.43058776855469
# epoch: 57  nstep_train_loss: 75.28187561035156
# epoch: 58  nstep_train_loss: 75.1146469116211
# epoch: 59  nstep_train_loss: 74.94366455078125
# epoch: 60  nstep_train_loss: 74.78231811523438
# epoch: 61  nstep_train_loss: 74.64112091064453
# epoch: 62  nstep_train_loss: 74.52528381347656
# epoch: 63  nstep_train_loss: 74.43397521972656
# epoch: 64  nstep_train_loss: 74.36747741699219
# epoch: 65  nstep_train_loss: 74.31497955322266
# epoch: 66  nstep_train_loss: 74.27397155761719
# epoch: 67  nstep_train_loss: 74.23895263671875
# epoch: 68  nstep_train_loss: 74.20222473144531
# epoch: 69  nstep_train_loss: 74.15850830078125
# epoch: 70  nstep_train_loss: 74.1030502319336
# epoch: 71  nstep_train_loss: 74.03730010986328
# epoch: 72  nstep_train_loss: 73.96575927734375
# epoch: 73  nstep_train_loss: 73.89662170410156
# epoch: 74  nstep_train_loss: 73.83470916748047
# epoch: 75  nstep_train_loss: 73.78060150146484
# epoch: 76  nstep_train_loss: 73.73356628417969
# epoch: 77  nstep_train_loss: 73.689453125
# epoch: 78  nstep_train_loss: 73.6478042602539
# epoch: 79  nstep_train_loss: 73.60684204101562
# epoch: 80  nstep_train_loss: 73.56631469726562
# epoch: 81  nstep_train_loss: 73.52600860595703
# epoch: 82  nstep_train_loss: 73.48566436767578
# epoch: 83  nstep_train_loss: 73.44634246826172
# epoch: 84  nstep_train_loss: 73.4076919555664
# epoch: 85  nstep_train_loss: 73.36888885498047
# epoch: 86  nstep_train_loss: 73.33088684082031
# epoch: 87  nstep_train_loss: 73.29495239257812
# epoch: 88  nstep_train_loss: 73.26101684570312
# epoch: 89  nstep_train_loss: 73.22805786132812
# epoch: 90  nstep_train_loss: 73.19467163085938
# epoch: 91  nstep_train_loss: 73.16049194335938
# epoch: 92  nstep_train_loss: 73.12541198730469
# epoch: 93  nstep_train_loss: 73.089111328125
# epoch: 94  nstep_train_loss: 73.05133819580078
# epoch: 95  nstep_train_loss: 73.01222229003906
# epoch: 96  nstep_train_loss: 72.9721450805664
# epoch: 97  nstep_train_loss: 72.93196105957031
# epoch: 98  nstep_train_loss: 72.89254760742188
# epoch: 99  nstep_train_loss: 72.8529052734375
# epoch: 100  nstep_train_loss: 72.81231689453125
# epoch: 101  nstep_train_loss: 72.7708740234375
# epoch: 102  nstep_train_loss: 72.7287826538086
# epoch: 103  nstep_train_loss: 72.68586730957031
# epoch: 104  nstep_train_loss: 72.64219665527344
# epoch: 105  nstep_train_loss: 72.59819030761719
# epoch: 106  nstep_train_loss: 72.55427551269531
# epoch: 107  nstep_train_loss: 72.51009368896484
# epoch: 108  nstep_train_loss: 72.46508026123047
# epoch: 109  nstep_train_loss: 72.41852569580078
# epoch: 110  nstep_train_loss: 72.37061309814453
# epoch: 111  nstep_train_loss: 72.32154846191406
# epoch: 112  nstep_train_loss: 72.27174377441406
# epoch: 113  nstep_train_loss: 72.22208404541016
# epoch: 114  nstep_train_loss: 72.17164611816406
# epoch: 115  nstep_train_loss: 72.12055969238281
# epoch: 116  nstep_train_loss: 72.06842803955078
# epoch: 117  nstep_train_loss: 72.01486206054688
# epoch: 118  nstep_train_loss: 71.96028137207031
# epoch: 119  nstep_train_loss: 71.90471649169922
# epoch: 120  nstep_train_loss: 71.84808349609375
# epoch: 121  nstep_train_loss: 71.790283203125
# epoch: 122  nstep_train_loss: 71.73210144042969
# epoch: 123  nstep_train_loss: 71.67276000976562
# epoch: 124  nstep_train_loss: 71.61354064941406
# epoch: 125  nstep_train_loss: 71.55492401123047
# epoch: 126  nstep_train_loss: 71.49810791015625
# epoch: 127  nstep_train_loss: 71.47821807861328
# epoch: 128  nstep_train_loss: 71.55955505371094
# epoch: 129  nstep_train_loss: 71.37149810791016
# epoch: 130  nstep_train_loss: 71.41663360595703
# epoch: 131  nstep_train_loss: 71.4008560180664
# epoch: 132  nstep_train_loss: 71.28413391113281
# epoch: 133  nstep_train_loss: 71.32504272460938
# epoch: 134  nstep_train_loss: 71.22352600097656
# epoch: 135  nstep_train_loss: 71.23380279541016
# epoch: 136  nstep_train_loss: 71.17493438720703
# epoch: 137  nstep_train_loss: 71.1220474243164
# epoch: 138  nstep_train_loss: 71.11685943603516
# epoch: 139  nstep_train_loss: 71.01980590820312
# epoch: 140  nstep_train_loss: 71.04798126220703
# epoch: 141  nstep_train_loss: 70.95027160644531
# epoch: 142  nstep_train_loss: 70.9079818725586
# epoch: 143  nstep_train_loss: 70.9161376953125
# epoch: 144  nstep_train_loss: 70.82568359375
# epoch: 145  nstep_train_loss: 70.78367614746094
# epoch: 146  nstep_train_loss: 70.79212951660156
# epoch: 147  nstep_train_loss: 70.70128631591797
# epoch: 148  nstep_train_loss: 70.66644287109375
# epoch: 149  nstep_train_loss: 70.66316986083984
# epoch: 150  nstep_train_loss: 70.57953643798828
# epoch: 151  nstep_train_loss: 70.59095764160156
# epoch: 152  nstep_train_loss: 70.50829315185547
# epoch: 153  nstep_train_loss: 70.4915542602539
# epoch: 154  nstep_train_loss: 70.44342041015625
# epoch: 155  nstep_train_loss: 70.38422393798828
# epoch: 156  nstep_train_loss: 70.36445617675781
# epoch: 157  nstep_train_loss: 70.32100677490234
# epoch: 158  nstep_train_loss: 70.29058837890625
# epoch: 159  nstep_train_loss: 70.2807388305664
# epoch: 160  nstep_train_loss: 70.26934051513672
# epoch: 161  nstep_train_loss: 70.23428344726562
# epoch: 162  nstep_train_loss: 70.21544647216797
# epoch: 163  nstep_train_loss: 70.20590209960938
# epoch: 164  nstep_train_loss: 70.19928741455078
# epoch: 165  nstep_train_loss: 70.1985855102539
# epoch: 166  nstep_train_loss: 70.187255859375
# epoch: 167  nstep_train_loss: 70.16517639160156
# epoch: 168  nstep_train_loss: 70.1364974975586
# epoch: 169  nstep_train_loss: 70.1103515625
# epoch: 170  nstep_train_loss: 70.09590148925781
# epoch: 171  nstep_train_loss: 70.08584594726562
# epoch: 172  nstep_train_loss: 70.08500671386719
# epoch: 173  nstep_train_loss: 70.11849212646484
# epoch: 174  nstep_train_loss: 70.1529541015625
# epoch: 175  nstep_train_loss: 70.07904052734375
# epoch: 176  nstep_train_loss: 70.07742309570312
# epoch: 177  nstep_train_loss: 70.07788848876953
# epoch: 178  nstep_train_loss: 70.12831115722656
# epoch: 179  nstep_train_loss: 70.05390167236328
# epoch: 180  nstep_train_loss: 70.24394989013672
# epoch: 181  nstep_train_loss: 70.01411437988281
# epoch: 182  nstep_train_loss: 70.27310180664062
# epoch: 183  nstep_train_loss: 70.32161712646484
# epoch: 184  nstep_train_loss: 70.02940368652344
# epoch: 185  nstep_train_loss: 70.358642578125
# epoch: 186  nstep_train_loss: 70.2857437133789
# epoch: 187  nstep_train_loss: 70.00633239746094
# epoch: 188  nstep_train_loss: 70.1903305053711
# epoch: 189  nstep_train_loss: 70.10363006591797
# epoch: 190  nstep_train_loss: 70.00244140625
# epoch: 191  nstep_train_loss: 70.07467651367188
# epoch: 192  nstep_train_loss: 69.93631744384766
# epoch: 193  nstep_train_loss: 69.99974060058594
# epoch: 194  nstep_train_loss: 69.96715545654297
# epoch: 195  nstep_train_loss: 69.98408508300781
# epoch: 196  nstep_train_loss: 69.96977233886719
# epoch: 197  nstep_train_loss: 69.93771362304688
# epoch: 198  nstep_train_loss: 69.94621276855469
# epoch: 199  nstep_train_loss: 69.89106750488281
# epoch: 200  nstep_train_loss: 69.98533630371094
# epoch: 201  nstep_train_loss: 69.92646026611328
# epoch: 202  nstep_train_loss: 69.98296356201172
# epoch: 203  nstep_train_loss: 69.89397430419922
# epoch: 204  nstep_train_loss: 70.07865142822266
# epoch: 205  nstep_train_loss: 69.86038970947266
# epoch: 206  nstep_train_loss: 70.0149154663086
# epoch: 207  nstep_train_loss: 69.94571685791016
# epoch: 208  nstep_train_loss: 70.00669860839844
# epoch: 209  nstep_train_loss: 69.93951416015625
# epoch: 210  nstep_train_loss: 69.96353149414062
# epoch: 211  nstep_train_loss: 69.94197082519531
# epoch: 212  nstep_train_loss: 69.92850494384766
# epoch: 213  nstep_train_loss: 69.86137390136719
# epoch: 214  nstep_train_loss: 69.92509460449219
# epoch: 215  nstep_train_loss: 69.91010284423828
# epoch: 216  nstep_train_loss: 69.90007019042969
# epoch: 217  nstep_train_loss: 69.86880493164062
# epoch: 218  nstep_train_loss: 69.8769760131836
# epoch: 219  nstep_train_loss: 69.8307876586914
# epoch: 220  nstep_train_loss: 69.93889617919922
# epoch: 221  nstep_train_loss: 69.83781433105469
# epoch: 222  nstep_train_loss: 69.84696197509766
# epoch: 223  nstep_train_loss: 69.88381958007812
# epoch: 224  nstep_train_loss: 69.823486328125
# epoch: 225  nstep_train_loss: 69.83049011230469
# epoch: 226  nstep_train_loss: 69.85100555419922
# epoch: 227  nstep_train_loss: 69.8171157836914
# epoch: 228  nstep_train_loss: 69.82376098632812
# epoch: 229  nstep_train_loss: 69.84561920166016
# epoch: 230  nstep_train_loss: 69.86741638183594
# epoch: 231  nstep_train_loss: 69.85348510742188
# epoch: 232  nstep_train_loss: 69.82066345214844
# epoch: 233  nstep_train_loss: 69.94930267333984
# epoch: 234  nstep_train_loss: 69.82196807861328
# epoch: 235  nstep_train_loss: 69.82240295410156
# epoch: 236  nstep_train_loss: 69.84732055664062
# epoch: 237  nstep_train_loss: 69.87910461425781
# epoch: 238  nstep_train_loss: 69.84642028808594
# epoch: 239  nstep_train_loss: 69.81958770751953
# epoch: 240  nstep_train_loss: 69.88078308105469
# epoch: 241  nstep_train_loss: 69.86817932128906
# epoch: 242  nstep_train_loss: 69.83511352539062
# epoch: 243  nstep_train_loss: 69.8440933227539
# epoch: 244  nstep_train_loss: 69.88184356689453
# epoch: 245  nstep_train_loss: 69.78974151611328
# epoch: 246  nstep_train_loss: 69.8100814819336
# epoch: 247  nstep_train_loss: 69.82038116455078
# epoch: 248  nstep_train_loss: 69.82181549072266
# epoch: 249  nstep_train_loss: 69.8072509765625
# epoch: 250  nstep_train_loss: 69.79132843017578
# epoch: 251  nstep_train_loss: 69.79293823242188
# epoch: 252  nstep_train_loss: 69.79637145996094
# epoch: 253  nstep_train_loss: 69.77930450439453
# epoch: 254  nstep_train_loss: 69.77587127685547
# epoch: 255  nstep_train_loss: 69.78954315185547
# epoch: 256  nstep_train_loss: 69.78199768066406
# epoch: 257  nstep_train_loss: 69.79259490966797
# epoch: 258  nstep_train_loss: 69.81375122070312
# epoch: 259  nstep_train_loss: 69.80291748046875
# epoch: 260  nstep_train_loss: 69.79080200195312
# epoch: 261  nstep_train_loss: 69.81877899169922
# epoch: 262  nstep_train_loss: 69.81122589111328
# epoch: 263  nstep_train_loss: 69.76911163330078
# epoch: 264  nstep_train_loss: 69.83663177490234
# epoch: 265  nstep_train_loss: 69.82913970947266
# epoch: 266  nstep_train_loss: 69.87335968017578
# epoch: 267  nstep_train_loss: 69.8277587890625
# epoch: 268  nstep_train_loss: 69.95569610595703
# epoch: 269  nstep_train_loss: 69.77885437011719
# epoch: 270  nstep_train_loss: 69.96917724609375
# epoch: 271  nstep_train_loss: 69.98580932617188
# epoch: 272  nstep_train_loss: 69.8443603515625
# epoch: 273  nstep_train_loss: 69.95111846923828
# epoch: 274  nstep_train_loss: 69.82598876953125
# epoch: 275  nstep_train_loss: 69.96690368652344
# epoch: 276  nstep_train_loss: 70.00077819824219
# epoch: 277  nstep_train_loss: 69.77865600585938
# epoch: 278  nstep_train_loss: 70.10812377929688
# epoch: 279  nstep_train_loss: 69.9866943359375
# epoch: 280  nstep_train_loss: 69.90319061279297
# epoch: 281  nstep_train_loss: 70.03617858886719
# epoch: 282  nstep_train_loss: 69.90135192871094
# epoch: 283  nstep_train_loss: 69.88481140136719
# epoch: 284  nstep_train_loss: 69.94129943847656
# epoch: 285  nstep_train_loss: 69.80522918701172
# epoch: 286  nstep_train_loss: 69.93348693847656
# epoch: 287  nstep_train_loss: 69.88825988769531
# epoch: 288  nstep_train_loss: 69.80609130859375
# epoch: 289  nstep_train_loss: 69.88614654541016
# epoch: 290  nstep_train_loss: 69.77528381347656
# epoch: 291  nstep_train_loss: 69.84688568115234
# epoch: 292  nstep_train_loss: 69.8144760131836
# epoch: 293  nstep_train_loss: 69.79505157470703
# epoch: 294  nstep_train_loss: 69.79337310791016
# epoch: 295  nstep_train_loss: 69.8321304321289
# epoch: 296  nstep_train_loss: 69.82919311523438
# epoch: 297  nstep_train_loss: 69.77528381347656
# epoch: 298  nstep_train_loss: 69.8331069946289
# epoch: 299  nstep_train_loss: 69.80530548095703
# epoch: 300  nstep_train_loss: 69.81033325195312
# epoch: 301  nstep_train_loss: 69.76814270019531
# epoch: 302  nstep_train_loss: 69.75543975830078
# epoch: 303  nstep_train_loss: 69.777587890625
# epoch: 304  nstep_train_loss: 69.75298309326172
# epoch: 305  nstep_train_loss: 69.8116226196289
# epoch: 306  nstep_train_loss: 69.80428314208984
# epoch: 307  nstep_train_loss: 69.83846282958984
# epoch: 308  nstep_train_loss: 69.79608154296875
# epoch: 309  nstep_train_loss: 69.89889526367188
# epoch: 310  nstep_train_loss: 69.7474136352539
# epoch: 311  nstep_train_loss: 69.85977172851562
# epoch: 312  nstep_train_loss: 69.85454559326172
# epoch: 313  nstep_train_loss: 69.79669189453125
# epoch: 314  nstep_train_loss: 69.89067840576172
# epoch: 315  nstep_train_loss: 69.76932525634766
# epoch: 316  nstep_train_loss: 69.81227111816406
# epoch: 317  nstep_train_loss: 69.79745483398438
# epoch: 318  nstep_train_loss: 69.9527816772461
# epoch: 319  nstep_train_loss: 69.81796264648438
# epoch: 320  nstep_train_loss: 70.0231704711914
# epoch: 321  nstep_train_loss: 70.01189422607422
# epoch: 322  nstep_train_loss: 70.03108215332031
# epoch: 323  nstep_train_loss: 69.94595336914062
# epoch: 324  nstep_train_loss: 69.91219329833984
# epoch: 325  nstep_train_loss: 69.98709869384766
# epoch: 326  nstep_train_loss: 69.95337677001953
# epoch: 327  nstep_train_loss: 69.85801696777344
# epoch: 328  nstep_train_loss: 69.98483276367188
# epoch: 329  nstep_train_loss: 69.86088562011719
# epoch: 330  nstep_train_loss: 69.8514404296875
# epoch: 331  nstep_train_loss: 69.85250854492188
# epoch: 332  nstep_train_loss: 69.82159423828125
# epoch: 333  nstep_train_loss: 69.85945129394531
# epoch: 334  nstep_train_loss: 69.83792877197266
# epoch: 335  nstep_train_loss: 69.80427551269531
# epoch: 336  nstep_train_loss: 69.91246795654297
# epoch: 337  nstep_train_loss: 69.76744842529297
# epoch: 338  nstep_train_loss: 69.85968780517578
# epoch: 339  nstep_train_loss: 69.8570327758789
# epoch: 340  nstep_train_loss: 69.76492309570312
# epoch: 341  nstep_train_loss: 69.86583709716797
# epoch: 342  nstep_train_loss: 69.8208236694336
# epoch: 343  nstep_train_loss: 69.79595184326172
# epoch: 344  nstep_train_loss: 69.78323364257812
# epoch: 345  nstep_train_loss: 69.79541778564453
# epoch: 346  nstep_train_loss: 69.74047088623047
# epoch: 347  nstep_train_loss: 69.77159118652344
# epoch: 348  nstep_train_loss: 69.73932647705078
# epoch: 349  nstep_train_loss: 69.77908325195312
# epoch: 350  nstep_train_loss: 69.75436401367188
# epoch: 351  nstep_train_loss: 69.75828552246094
# epoch: 352  nstep_train_loss: 69.77176666259766
# epoch: 353  nstep_train_loss: 69.73467254638672
# epoch: 354  nstep_train_loss: 69.73941040039062
# epoch: 355  nstep_train_loss: 69.75765228271484
# epoch: 356  nstep_train_loss: 69.75308227539062
# epoch: 357  nstep_train_loss: 69.73474884033203
# epoch: 358  nstep_train_loss: 69.78968811035156
# epoch: 359  nstep_train_loss: 69.7801284790039
# epoch: 360  nstep_train_loss: 69.81857299804688
# epoch: 361  nstep_train_loss: 69.79795837402344
# epoch: 362  nstep_train_loss: 69.82793426513672
# epoch: 363  nstep_train_loss: 69.74099731445312
# epoch: 364  nstep_train_loss: 69.81060028076172
# epoch: 365  nstep_train_loss: 69.76974487304688
# epoch: 366  nstep_train_loss: 69.83587646484375
# epoch: 367  nstep_train_loss: 69.82646179199219
# epoch: 368  nstep_train_loss: 69.76177215576172
# epoch: 369  nstep_train_loss: 69.7704849243164
# epoch: 370  nstep_train_loss: 69.73226928710938
# epoch: 371  nstep_train_loss: 69.740966796875
# epoch: 372  nstep_train_loss: 69.77010345458984
# epoch: 373  nstep_train_loss: 69.77922058105469
# epoch: 374  nstep_train_loss: 69.77371215820312
# epoch: 375  nstep_train_loss: 69.87631225585938
# epoch: 376  nstep_train_loss: 69.72486114501953
# epoch: 377  nstep_train_loss: 69.81819152832031
# epoch: 378  nstep_train_loss: 69.74978637695312
# epoch: 379  nstep_train_loss: 69.88911437988281
# epoch: 380  nstep_train_loss: 69.7813491821289
# epoch: 381  nstep_train_loss: 69.869384765625
# epoch: 382  nstep_train_loss: 69.91790771484375
# epoch: 383  nstep_train_loss: 69.7597885131836
# epoch: 384  nstep_train_loss: 69.95697021484375
# epoch: 385  nstep_train_loss: 69.89897918701172
# epoch: 386  nstep_train_loss: 69.80266571044922
# epoch: 387  nstep_train_loss: 69.90130615234375
# epoch: 388  nstep_train_loss: 69.83333587646484
# epoch: 389  nstep_train_loss: 69.7648696899414
# epoch: 390  nstep_train_loss: 69.85167694091797
# epoch: 391  nstep_train_loss: 69.75975799560547
# epoch: 392  nstep_train_loss: 69.80900573730469
# epoch: 393  nstep_train_loss: 69.7955322265625
# epoch: 394  nstep_train_loss: 69.81956481933594
# epoch: 395  nstep_train_loss: 69.77566528320312
# epoch: 396  nstep_train_loss: 69.89628601074219
# epoch: 397  nstep_train_loss: 69.78302764892578
# epoch: 398  nstep_train_loss: 69.84803771972656
# epoch: 399  nstep_train_loss: 69.86705780029297

# %% [markdown]
# # Test Closed-Loop System

# %%
policy_cl = sim.ControllerPytorch(policy=policy.net,
                                  nsteps=nsteps, input_keys=['x'])
system_cl = sim.DynamicsLinSSM(A.numpy(), B.numpy(), C.numpy())
components = [policy_cl, system_cl]
cl_sim = sim.SystemSimulator(components)
cl_sim.plot_graph()

# %% [markdown]
# ## Plot Closed-Loop Trajectories

# %%
data = {'x': np.ones(nx)}
trajectories = cl_sim.simulate(nsim=50, data_init=data)

Umin = umin * np.ones([trajectories['y'].shape[0], 1])
Umax = umax * np.ones([trajectories['y'].shape[0], 1])
Ymin = xmin * np.ones([trajectories['y'].shape[0], 1])
Ymax = xmax * np.ones([trajectories['y'].shape[0], 1])
R = np.zeros([trajectories['y'].shape[0], 1])
psl.plot.pltCL(Y=trajectories['x'], U=trajectories['u'], R=R,
                Umin=Umin, Umax=Umax, Ymin=Ymin, Ymax=Ymax)
fig = plt.gcf()
fig.set_size_inches((10,10))
fig.tight_layout()
psl.plot.pltPhase(X=trajectories['y'])
